# %%
import numpy as np
np.random.seed(42)
np.set_printoptions(suppress=True)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
    
import glob, time, os

from scapy.all import *

# %%
NOTEBOOK_PATH = "D:/Delta Stuff/Scifair20/"

# %%
packets = []
i=0
def readPacket(pkt):
    global i
    if i >= 62000 and i <= 62020:
        packets.append(pkt)
    i += 1

# %%
scp.sniff(offline=NOTEBOOK_PATH+"IDS2017/PCAPs/Tuesday-WorkingHours.pcap", prn=readPacket, store=0)
# Out:
# <Sniffed: TCP:0 UDP:0 ICMP:0 Other:0>

# %%
len(packets)
# Out:
# 21

# %%
import pickle

# %%
save_file = open(NOTEBOOK_PATH + "test_packets.pkl", "wb")
saved_model = pickle.dump(packets, save_file)
save_file.close()

# %%
packets = pickle.load(open(NOTEBOOK_PATH + "test_packets.pkl", "rb"))

# %%
packets[0].time
# Out:
# 1570903313.609805

# %%
[x.display() for x in packets]
# Out:
# ###[ Ethernet ]###
#   dst       = b8:ac:6f:1d:1f:6c
#   src       = 18:66:da:9b:e3:7d
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 9356
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x40e7
#      src       = 192.168.10.3
#      dst       = 192.168.10.9
#      \options   \
# ###[ TCP ]###
#         sport     = epmap
#         dport     = 1627
#         seq       = 3886427326
#         ack       = 1784597541
#         dataofs   = 5
#         reserved  = 0
#         flags     = FA
#         window    = 2052
#         chksum    = 0xc0a7
#         urgptr    = 0
#         options   = []
# ###[ Padding ]###
#            load      = '\x00\x00\x00\x00\x00\x00'
#
# ###[ Ethernet ]###
#   dst       = b8:ac:6f:1d:1f:6c
#   src       = 18:66:da:9b:e3:7d
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
# ...

# %%
p = packets[0]

# %%
p[TCP].time
# Out:
# 1570837011.098194

# %%
p.display()
# Out:
# ###[ Ethernet ]###
#   dst       = b8:ac:6f:1d:1f:6c
#   src       = 18:66:da:9b:e3:7d
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 9356
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x40e7
#      src       = 192.168.10.3
#      dst       = 192.168.10.9
#      \options   \
# ###[ TCP ]###
#         sport     = epmap
#         dport     = 1627
#         seq       = 3886427326
#         ack       = 1784597541
#         dataofs   = 5
#         reserved  = 0
#         flags     = FA
#         window    = 2052
#         chksum    = 0xc0a7
#         urgptr    = 0
#         options   = []
# ###[ Padding ]###
#            load      = '\x00\x00\x00\x00\x00\x00'

# %%
str(p)
# Out:
# "b'\\xb8\\xaco\\x1d\\x1fl\\x18f\\xda\\x9b\\xe3}\\x08\\x00E\\x00\\x00($\\x8c@\\x00\\x80\\x06@\\xe7\\xc0\\xa8\\n\\x03\\xc0\\xa8\\n\\t\\x00\\x87\\x06[\\xe7\\xa6,\\xbej^\\xcc%P\\x11\\x08\\x04\\xc0\\xa7\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00'"

# %%
hexdump(p)
# Out:
# 0000  B8 AC 6F 1D 1F 6C 18 66 DA 9B E3 7D 08 00 45 00  ..o..l.f...}..E.
# 0010  00 28 24 8C 40 00 80 06 40 E7 C0 A8 0A 03 C0 A8  .($.@...@.......
# 0020  0A 09 00 87 06 5B E7 A6 2C BE 6A 5E CC 25 50 11  .....[..,.j^.%P.
# 0030  08 04 C0 A7 00 00 00 00 00 00 00 00              ............

# %%
[print(str(p)) for p in packets]
# Out:
# b'\xb8\xaco\x1d\x1fl\x18f\xda\x9b\xe3}\x08\x00E\x00\x00($\x8c@\x00\x80\x06@\xe7\xc0\xa8\n\x03\xc0\xa8\n\t\x00\x87\x06[\xe7\xa6,\xbej^\xcc%P\x11\x08\x04\xc0\xa7\x00\x00\x00\x00\x00\x00\x00\x00'
# b'\xb8\xaco\x1d\x1fl\x18f\xda\x9b\xe3}\x08\x00E\x00\x00($\x8d@\x00\x80\x06@\xe6\xc0\xa8\n\x03\xc0\xa8\n\t\xc2\x02\x06\\haY{\xea9\xe7pP\x10\x08\x04\xb6\x8d\x00\x00\x00\x00\x00\x00\x00\x00'
# b'\xb8\xaco\x1d\x1fl\x18f\xda\x9b\xe3}\x08\x00E\x00\x00($\x8d@\x00\x80\x06@\xe6\xc0\xa8\n\x03\xc0\xa8\n\t\xc2\x02\x06\\haY{\xea9\xe7pP\x10\x08\x04\xb6\x8d\x00\x00\x00\x00\x00\x00\x00\x00'
# b'\xb8\xaco\x1d\x1fl\x18f\xda\x9b\xe3}\x08\x00E\x00\x00($\x8e@\x00\x80\x06@\xe5\xc0\xa8\n\x03\xc0\xa8\n\t\xc2\x02\x06\\haY{\xea9\xe7pP\x11\x08\x04\xb6\x8c\x00\x00\x00\x00\x00\x00\x00\x00'
# b'\xb8\xaco\x1d\x1fl\x18f\xda\x9b\xe3}\x08\x00E\x00\x00($\x8e@\x00\x80\x06@\xe5\xc0\xa8\n\x03\xc0\xa8\n\t\xc2\x02\x06\\haY{\xea9\xe7pP\x11\x08\x04\xb6\x8c\x00\x00\x00\x00\x00\x00\x00\x00'
# ...

# %%
df = pd.read_csv(NOTEBOOK_PATH + "IDS2017/TrafficLabelling/Tuesday-WorkingHours.pcap_ISCX.csv")

df.columns = [x.strip() for x in df.columns]

df2 = df[['Source IP', 'Destination IP', 'Source Port', 'Destination Port', 'Protocol', 'Label']]

df2 = df2.drop_duplicates()

# %%
df2['Label'].value_counts()
# Out:
# BENIGN         275481
# FTP-Patator      3991
# SSH-Patator      2979
# Name: Label, dtype: int64

# %%
p = packets[0]

# %%
p.display()
# Out:
# ###[ Ethernet ]###
#   dst       = b8:ac:6f:1d:1f:6c
#   src       = 18:66:da:9b:e3:7d
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 9356
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x40e7
#      src       = 192.168.10.3
#      dst       = 192.168.10.9
#      \options   \
# ###[ TCP ]###
#         sport     = epmap
#         dport     = 1627
#         seq       = 3886427326
#         ack       = 1784597541
#         dataofs   = 5
#         reserved  = 0
#         flags     = FA
#         window    = 2052
#         chksum    = 0xc0a7
#         urgptr    = 0
#         options   = []
# ###[ Padding ]###
#            load      = '\x00\x00\x00\x00\x00\x00'

# %%
p.sport
# Out:
# 135

# %%
import time
time.time()
# Out:
# 1570837093.0547328

# %%
import datetime
timestamp = 1570903313.609805
value = datetime.datetime.fromtimestamp(timestamp)
print(value.strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 2019-10-12 08:01:53

# %%
packets[0].payload.time
# Out:
# 1570903313.609805

# %%
sniff(offline=)
# Out:
# Signature: sniff(*args, **kwargs)
# Docstring:
# Sniff packets and return a list of packets.
#
# Args:
#     count: number of packets to capture. 0 means infinity.
#     store: whether to store sniffed packets or discard them
#     prn: function to apply to each packet. If something is returned, it
#          is displayed.
#          --Ex: prn = lambda x: x.summary()
#     session: a session = a flow decoder used to handle stream of packets.
#              e.g: IPSession (to defragment on-the-flow) or NetflowSession
#     filter: BPF filter to apply.
#     lfilter: Python function applied to each packet to determine if
#              further action may be done.
#              --Ex: lfilter = lambda x: x.haslayer(Padding)
#     offline: PCAP file (or list of PCAP files) to read packets from,
#              instead of sniffing them
#     timeout: stop sniffing after a given time (default: None).
#     L2socket: use the provided L2socket (default: use conf.L2listen).
# ...

# %%
for i in range(len(packets)):
    print(datetime.datetime.fromtimestamp(packets[i].time).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 2019-10-12 08:01:53
# 2019-10-12 08:01:53
# 2019-10-12 08:01:53
# 2019-10-12 08:01:53
# 2019-10-12 08:01:53
# 2019-10-12 08:01:53
# 2019-10-12 08:01:53
# 2019-10-12 08:01:53
# 2019-10-12 08:01:53
# 2019-10-12 08:01:53
# 2019-10-12 08:01:53
# 2019-10-12 08:01:53
# 2019-10-12 08:01:53
# 2019-10-12 08:01:53
# 2019-10-12 08:01:53
# 2019-10-12 08:01:53
# 2019-10-12 08:01:53
# 2019-10-12 08:01:53
# 2019-10-12 08:01:53
# 2019-10-12 08:01:53
# 2019-10-12 08:01:53

# %%
packets[4].time
# Out:
# 1570837011.0991912

# %%
packets[2].load
# Out:
# b'\x00\x00\x00\x00\x00\x00'

# %%
packets[15].display()
# Out:
# ###[ Ethernet ]###
#   dst       = b8:ac:6f:1d:1f:6c
#   src       = 00:c1:b1:14:eb:31
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 52
#      id        = 38588
#      flags     =
#      frag      = 0
#      ttl       = 244
#      proto     = tcp
#      chksum    = 0xca6a
#      src       = 192.138.218.96
#      dst       = 192.168.10.9
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 1495
#         seq       = 3867810820
#         ack       = 382183343
#         dataofs   = 8
#         reserved  = 0
#         flags     = A
#         window    = 5680
#         chksum    = 0xb86c
#         urgptr    = 0
#         options   = [('NOP', None), ('NOP', None), ('SAck', (382183342, 382183343))]

# %%
packets[10].display()
# Out:
# ###[ Ethernet ]###
#   dst       = b8:ac:6f:36:0b:a8
#   src       = 18:66:da:9b:e3:7d
#   type      = ARP
# ###[ ARP ]###
#      hwtype    = 0x1
#      ptype     = IPv4
#      hwlen     = 6
#      plen      = 4
#      op        = who-has
#      hwsrc     = 18:66:da:9b:e3:7d
#      psrc      = 192.168.10.3
#      hwdst     = b8:ac:6f:36:0b:a8
#      pdst      = 192.168.10.51
# ###[ Padding ]###
#         load      = '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'

# %%
for p in packets:
    ipl = p.getlayer(scp.IP)
    if ipl is not None:
        print("IP: " + ipl.src + "-" + ipl.dst, end="")
    arpl = p.getlayer(scp.ARP)
    if arpl is not None:
        print(" ARP: " + arpl.psrc + "-" + arpl.pdst, end="")
    print()
# Out:
# IP: 192.168.10.3-192.168.10.9
# IP: 192.168.10.3-192.168.10.9
# IP: 192.168.10.3-192.168.10.9
# IP: 192.168.10.3-192.168.10.9
# IP: 192.168.10.3-192.168.10.9
# IP: 192.168.10.9-192.168.10.3
# IP: 192.168.10.9-192.168.10.3
# IP: 192.168.10.9-192.168.10.3
# IP: 192.168.10.9-192.168.10.3
# IP: 192.168.10.9-192.138.218.96
#  ARP: 192.168.10.3-192.168.10.51
#  ARP: 192.168.10.3-192.168.10.51
#  ARP: 192.168.10.51-192.168.10.3
#  ARP: 192.168.10.51-192.168.10.3
# IP: 192.168.10.9-54.69.227.52
# IP: 192.138.218.96-192.168.10.9
# IP: 192.168.10.9-23.203.29.206
# IP: 54.69.227.52-192.168.10.9
# IP: 23.203.29.206-192.168.10.9
# IP: 192.168.10.9-52.22.170.157
# IP: 192.168.10.9-23.203.29.206

# %%
[print(p.getlayer(scp.IP).src, p.getlayer(scp.IP).dst) for p in packets]
# Out:
# 192.168.10.3 192.168.10.9
# 192.168.10.3 192.168.10.9
# 192.168.10.3 192.168.10.9
# 192.168.10.3 192.168.10.9
# 192.168.10.3 192.168.10.9
# 192.168.10.9 192.168.10.3
# 192.168.10.9 192.168.10.3
# 192.168.10.9 192.168.10.3
# 192.168.10.9 192.168.10.3
# 192.168.10.9 192.138.218.96
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-155805311bf2> in <module>
# ----> 1 [print(p.getlayer(scp.IP).src, p.getlayer(scp.IP).dst) for p in packets]
#
# <ipython-input-25-155805311bf2> in <listcomp>(.0)
# ----> 1 [print(p.getlayer(scp.IP).src, p.getlayer(scp.IP).dst) for p in packets]
#
# AttributeError: 'NoneType' object has no attribute 'src'

# %%
[print(p.load) for p in packets]
# Out:
# b'\x00\x00\x00\x00\x00\x00'
# b'\x00\x00\x00\x00\x00\x00'
# b'\x00\x00\x00\x00\x00\x00'
# b'\x00\x00\x00\x00\x00\x00'
# b'\x00\x00\x00\x00\x00\x00'
# b'\x00\x00\x00\x00\x00\x00'
# b'\x00\x00\x00\x00\x00\x00'
# b'\x00\x00\x00\x00\x00\x00'
# b'\x00\x00\x00\x00\x00\x00'
# b'\x00'
# b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# b'\x00'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scapy\packet.py in __getattr__(self, attr)
#     360         try:
# --> 361             fld, v = self.getfield_and_val(attr)
#     362         except TypeError:
#
# ...

# %%
p = packets[0]

# %%
p.summary()
# Out:
# 'Ether / IP / TCP 8.254.250.126:http > 192.168.10.5:49188 FA / Padding'

# %%
p.display()
# Out:
# ###[ Ethernet ]###
#   dst       = b8:ac:6f:36:0a:8b
#   src       = 00:c1:b1:14:eb:31
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 6964
#      flags     =
#      frag      = 0
#      ttl       = 55
#      proto     = tcp
#      chksum    = 0x9a72
#      src       = 8.254.250.126
#      dst       = 192.168.10.5
#      \options   \
# ###[ TCP ]###
#         sport     = http
#         dport     = 49188
#         seq       = 3755453835
#         ack       = 2495101083
#         dataofs   = 5
#         reserved  = 0
#         flags     = FA
#         window    = 329
#         chksum    = 0xc534
#         urgptr    = 0
#         options   = []
# ###[ Padding ]###
#            load      = '\x00\x00\x00\x00\x00\x00'

# %%
packets[0].getlayer(scp.IP).dst
# Out:
# '192.168.10.5'

# %%
rl = packets[9].getlayer(scp.Raw)

# %%
int.from_bytes(rl.load, 'big')
# Out:
# ...

# %%
rl.load
# Out:
# b'\x02\xb4\x81E\x00\x01\x00\x08SWCL\x00\x05\x01\tCisco IOS Software, Catalyst L3 Switch Software (CAT3K_CAA-UNIVERSALK9-M), Version 15.2(2)E6, RELEASE SOFTWARE (fc1)\nTechnical Support: http://www.cisco.com/techsupport\nCopyright (c) 1986-2016 by Cisco Systems, Inc.\nCompiled Sat 17-Dec-16 00:22 by prod_rel_team\x00\x06\x00\x16cisco WS-C3850-48U\x00\x02\x00\x11\x00\x00\x00\x01\x01\x01\xcc\x00\x04\xc0\xa8\n\x02\x00\x03\x00\x18GigabitEthernet1/0/6\x00\x04\x00\x08\x00\x00\x00(\x00\t\x00\x04\x00\n\x00\x06\x00\n\x00\x0b\x00\x05\x01\x00\x12\x00\x05\x00\x00\x13\x00\x05\x00\x00\x16\x00\x11\x00\x00\x00\x01\x01\x01\xcc\x00\x04\xc0\xa8\n\x02\x00\x1a\x00\x10\x00\x00\x00\x01\x00\x00\x00\x00\xff\xff\xff\xff\x00\x1f\x00\x05\x01\x10\x04\x00\x13706e.6d1d.bb00\x00\x10\x03\x00\x051'

# %%
int.from_bytes(b'\x02', 'big')
# Out:
# 2

# %%
int.from_bytes(b'\xb4', 'big')
# Out:
# 180

# %%
int.from_bytes(b'\x02\xb4', 'big')
# Out:
# 692

# %%
len(rl.load)
pkt =
# Out:
# 435

# %%
rl.load[1]
# Out:
# 180

# %% [markdown]
# # Check if label merging will work

# %%
import glob, re
from tqdm import tqdm
tqdm.pandas()

# %%
f_names = glob.glob(NOTEBOOK_PATH + "IDS2017/TrafficLabelling/*.csv")
dfs = []
for i in tqdm(range(len(f_names))):
    f = f_names[i]
    df_i = pd.read_csv(open(f, encoding='utf-8', errors='ignore'))
    df_i['File'] = i
    dfs.append(df_i)
df = pd.concat(dfs, ignore_index=True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:17<00:00,  2.23s/it]

# %%
df.columns = [x.strip() for x in df.columns]

df2 = df[['Source IP', 'Destination IP', 'Source Port', 'Destination Port', 'Protocol', 'Timestamp', 'Label']]

df2 = df2.dropna()
df2 = df2.drop_duplicates()

# %%
def reformatDates(date):
    l = list(map(lambda x: x.lstrip("0"), re.split("/| |:", date)))
    return f"{l[0]}/{l[1]}/{l[2]} {l[3]}:{l[4]}"

# %%
df2['Timestamp'] = df2['Timestamp'].progress_apply(reformatDates)

# %%
def groupAttacks(attack):
    attack = str(attack)
    group = attack
    if attack in ("DDoS", "DoS Hulk", "DoS GoldenEye", "DoS slowloris", "DoS Slowhttptest", "Heartbleed"):
        group = "DoS/DDos"
    elif attack.startswith("Web Attack"):
        group = "Web Attack"
    elif attack == "FTP-Patator":
        group = "Brute Force"
    elif attack == "SSH-Patator":
        group = "Brute Force"
    elif attack == "Bot":
        group = "Botnet"
    return group

# %%
df2['Label'] = df2['Label'].progress_apply(groupAttacks)

# %%
ipdict = {}

# %%
def add2ipdict(row):
    rowid = f"{row['Source IP']}-{row['Destination IP']}-{row['Source Port']}-{row['Destination Port']}-{str(row['Protocol'])}-{str(row['Timestamp'])}"
    if rowid in ipdict:
        if ipdict[rowid] != row['Label']:
            print(f"Mismatch with {rowid}: {ipdict[rowid]} and {row['Label']}")
    else:
        ipdict[rowid] = row['Label']

# %%
tqdm.pandas()

# %%
df2.progress_apply(add2ipdict, axis=1)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████| 2541697/2541697 [01:49<00:00, 23191.47it/s]
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
#            ...
# 3119340    None
# 3119341    None
# 3119342    None
# 3119343    None
# 3119344    None
# Length: 2541697, dtype: object

# %%
list(df2['Timestamp'].unique())
# Out:
# ['7/7/2017 3:30',
#  '7/7/2017 3:31',
#  '7/7/2017 3:32',
#  '7/7/2017 3:33',
#  '7/7/2017 3:34',
#  '7/7/2017 3:35',
#  '7/7/2017 3:36',
#  '7/7/2017 3:37',
#  '7/7/2017 3:38',
#  '7/7/2017 3:39',
#  '7/7/2017 3:40',
#  '7/7/2017 3:41',
#  '7/7/2017 3:42',
#  '7/7/2017 3:43',
#  '7/7/2017 3:44',
#  '7/7/2017 3:45',
#  '7/7/2017 3:46',
#  '7/7/2017 3:47',
#  '7/7/2017 3:48',
#  '7/7/2017 3:49',
#  '7/7/2017 3:50',
#  '7/7/2017 3:51',
#  '7/7/2017 3:52',
#  '7/7/2017 3:53',
#  '7/7/2017 3:54',
#  '7/7/2017 3:55',
#  '7/7/2017 3:56',
#  '7/7/2017 3:57',
#  '7/7/2017 3:58',
#  '7/7/2017 3:59',
#  '7/7/2017 4:00',
#  '7/7/2017 4:01',
#  '7/7/2017 4:02',
#  '7/7/2017 4:03',
#  '7/7/2017 4:04',
#  '7/7/2017 4:05',
#  '7/7/2017 4:06',
#  '7/7/2017 4:07',
#  '7/7/2017 4:08',
#  '7/7/2017 4:09',
#  '7/7/2017 4:10',
#  '7/7/2017 4:11',
#  '7/7/2017 4:12',
#  '7/7/2017 4:13',
#  '7/7/2017 4:14',
#  '7/7/2017 4:15',
#  '7/7/2017 4:16',
#  '7/7/2017 4:17',
#  '7/7/2017 4:18',
#  '7/7/2017 4:19',
# ...
