# %%
import numpy as np
np.random.seed(42)
np.set_printoptions(suppress=True)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
tqdm.pandas()

import glob, time, datetime, os, re
from scapy.all import sniff, IP, TCP, ARP

# %%
NOTEBOOK_PATH = "D:/Delta Stuff/Scifair20/"

# %% [markdown]
# # Create dict with packet IDs mapped to attack labels

# %%
f_names = glob.glob(NOTEBOOK_PATH + "IDS2017/TrafficLabelling/*.csv")
dfs = []
for i in tqdm(range(len(f_names))):
    f = f_names[i]
    df_i = pd.read_csv(open(f, encoding='utf-8', errors='ignore'))
    df_i['File'] = i
    dfs.append(df_i)
df = pd.concat(dfs, ignore_index=True)
# Out:
#   0%|                                                                                            | 0/8 [00:00<?, ?it/s]C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#  38%|███████████████████████████████▌                                                    | 3/8 [00:03<00:06,  1.25s/it]C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#  62%|████████████████████████████████████████████████████▌                               | 5/8 [00:08<00:05,  1.84s/it]C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (0,1,3,6,20,21,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:18<00:00,  2.26s/it]

# %%
df.columns = [x.strip() for x in df.columns]

df2 = df[['Source IP', 'Destination IP', 'Source Port', 'Destination Port', 'Protocol', 'Timestamp', 'Label']]

df2 = df2.dropna()
df2 = df2.drop_duplicates()

# %%
def reformatDates(date):
    l = list(map(lambda x: x.lstrip("0"), re.split("/| |:", date)))
    return f"{l[0]}/{l[1]}/{l[2]} {l[3]}:{l[4]}"

# %%
df2['Timestamp'] = df2['Timestamp'].progress_apply(reformatDates)
# Out:
# 100%|████████████████████████████████████████████████████████████████████| 2541697/2541697 [00:07<00:00, 329898.69it/s]

# %%
def groupAttacks(attack):
    attack = str(attack)
    group = attack
    if attack in ("DDoS", "DoS Hulk", "DoS GoldenEye", "DoS slowloris", "DoS Slowhttptest", "Heartbleed"):
        group = "DoS/DDos"
    elif attack.startswith("Web Attack"):
        group = "Web Attack"
    elif attack == "FTP-Patator":
        group = "Brute Force"
    elif attack == "SSH-Patator":
        group = "Brute Force"
    elif attack == "Bot":
        group = "Botnet"
    return group

# %%
df2['Label'] = df2['Label'].progress_apply(groupAttacks)
# Out:
# 100%|███████████████████████████████████████████████████████████████████| 2541697/2541697 [00:02<00:00, 1139229.98it/s]

# %%
ipdict = {}

def add2ipdict(row):
    rowid = f"{row['Source IP']}-{row['Destination IP']}-{str(int(row['Source Port']))}-{str(int(row['Destination Port']))}-{str(row['Timestamp'])}"
    if rowid in ipdict:
        if ipdict[rowid] != row['Label']:
            print(f"Mismatch with {rowid}: {ipdict[rowid]} and {row['Label']}")
    else:
        ipdict[rowid] = row['Label']

# %%
df2.progress_apply(add2ipdict, axis=1)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████| 2541697/2541697 [01:38<00:00, 25903.83it/s]
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
#            ...
# 3119340    None
# 3119341    None
# 3119342    None
# 3119343    None
# 3119344    None
# Length: 2541697, dtype: object

# %% [markdown]
# # Read in packets

# %%
pcap_files = glob.glob(NOTEBOOK_PATH + "IDS2017/PCAPs/*.pcap")
pcap_files
# Out:
# ['D:/Delta Stuff/Scifair20/IDS2017/PCAPs\\Monday-WorkingHours.pcap',
#  'D:/Delta Stuff/Scifair20/IDS2017/PCAPs\\Tuesday-WorkingHours.pcap']

# %%
pkt_df = pd.DataFrame(columns=["Bytes", "Label"])

# %%
def formatDate(date):
    fdate = datetime.datetime.fromtimestamp(date).strftime("%d/%m/%Y %H:%M")
    l = list(map(lambda x: x.lstrip("0"), re.split("/| |:", fdate)))
    return f"{l[0]}/{l[1]}/{l[2]} {str(int(l[3])+7)}:{l[4]}"

# %%
def processPacket(p):
    # Get source and destination IP addresses
    if IP in p:
        sip = p[IP].src
        dip = p[IP].dst
    elif ARP in p:
        sip = p[ARP].psrc
        dip = p[ARP].pdst
    else:
        return
        
    # Get source and destination ports
    if TCP in p:
        sp = p[TCP].sport
        dp = p[TCP].dport
    else:
        return
    
    # Get label
    try:
        pid = f"{sip}-{dip}-{sp}-{dp}-{formatDate(p.time)}"
        print(pid)
        label = ipdict[pid]
        pkt_df.loc[len(pkt_df)] = [str(p), label]
        print("Finished mapping packet to label " + label)
    except KeyError:
        print("Reversing...")
        pid = f"{dip}-{sip}-{dp}-{sp}-{formatDate(p.time)}"
        label = ipdict[pid]
        pkt_df.loc[len(pkt_df)] = [str(p), label]
        print("Finished mapping packet to label " + label)

# %%
for pcap in pcap_files[1:]:
    sniff(count=1000, offline=pcap, store=0, prn=processPacket)
# Out:
# 192.168.10.5-192.168.10.3-49159-445-4/7/2017 8:53
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49159-445-4/7/2017 8:53
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-445-49159-4/7/2017 8:53
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-445-49159-4/7/2017 8:53
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49182-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49182-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49182-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49182-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49182-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49182-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49182-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49182-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49182-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49182-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49182-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49182-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49182-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49182-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49182-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49182-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49183-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49183-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49183-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49183-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49183-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49183-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49183-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49183-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49183-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49183-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49183-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49183-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49183-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49183-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49183-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49183-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49183-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49183-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49184-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49184-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49184-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49184-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49184-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49184-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49184-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49184-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49184-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49184-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49184-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49184-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49184-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49184-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49184-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49184-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49185-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49185-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49185-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49185-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49185-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49185-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49185-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49185-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49185-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49185-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49185-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49185-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49185-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49185-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49185-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49185-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49186-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49186-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49186-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49186-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49186-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49186-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49186-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49186-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49186-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49186-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49186-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49186-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49186-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49186-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49186-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49186-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49186-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49186-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49187-135-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49187-135-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-135-49187-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-135-49187-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49187-135-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49187-135-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49187-135-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49187-135-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-135-49187-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-135-49187-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49187-135-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49187-135-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-135-49187-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-135-49187-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49189-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49189-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49189-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49189-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49189-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49189-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49189-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49189-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49189-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49189-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49189-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49189-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49189-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49189-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49189-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49189-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49189-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49189-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49189-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49189-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49187-135-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49187-135-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-135-49187-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-135-49187-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49190-49671-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49190-49671-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49671-49190-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49671-49190-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49190-49671-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49190-49671-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49190-49671-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49190-49671-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49671-49190-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49671-49190-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49190-49671-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49190-49671-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49671-49190-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49671-49190-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49187-135-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49190-49671-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49187-135-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49190-49671-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49191-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49191-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49191-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49191-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49191-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49191-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49192-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49192-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49192-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49192-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49192-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49192-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49192-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49192-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49192-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49192-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49192-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49192-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49192-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49192-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49192-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49192-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49192-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49192-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49192-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49192-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49191-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49191-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49191-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49191-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49191-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49191-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49191-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49191-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49191-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49191-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49193-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49193-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49193-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49193-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49193-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49193-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49193-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49193-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49193-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49193-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49193-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49193-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49193-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49193-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49193-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49193-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49193-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49193-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49193-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49193-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49191-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49191-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49191-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49191-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49193-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49193-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49191-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49191-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49193-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49193-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49193-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49193-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49193-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49193-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49193-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49193-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49191-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49191-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49191-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49191-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49187-135-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49187-135-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-135-49187-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-135-49187-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49194-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49194-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49194-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49194-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49194-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49194-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49194-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49194-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49194-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49194-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49194-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49194-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49194-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49194-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49194-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49194-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49194-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49194-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49194-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49194-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49195-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49195-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49195-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49195-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49195-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49195-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49195-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49195-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49195-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49195-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49195-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49195-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49195-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49187-135-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49187-135-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49196-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49196-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49196-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49196-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49196-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49196-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49196-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49196-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49196-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49196-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49196-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49196-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49196-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49196-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49196-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49196-88-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49196-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49196-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49196-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-88-49196-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49195-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49195-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49195-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49195-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49195-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49195-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49195-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49195-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49195-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49195-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49195-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49195-389-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49195-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-389-49195-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.217.41.219-49197-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 23.217.41.219-192.168.10.5-80-49197-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.217.41.219-49197-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.217.41.219-49197-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 23.217.41.219-192.168.10.5-80-49197-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 23.217.41.219-192.168.10.5-80-49197-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.217.41.219-49197-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.15.4.19-49198-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 23.15.4.19-192.168.10.5-80-49198-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.15.4.19-49198-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.15.4.19-49198-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 23.15.4.19-192.168.10.5-80-49198-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.15.4.19-49198-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 23.15.4.19-192.168.10.5-80-49198-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 23.15.4.19-192.168.10.5-80-49198-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.15.4.19-49198-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.217.41.219-49197-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 23.217.41.219-192.168.10.5-80-49197-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.217.41.219-49197-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.217.41.219-49197-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 23.217.41.219-192.168.10.5-80-49197-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.217.41.219-49197-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-104.88.60.48-49199-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 104.88.60.48-192.168.10.5-80-49199-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-104.88.60.48-49199-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-104.88.60.48-49199-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 104.88.60.48-192.168.10.5-80-49199-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 104.88.60.48-192.168.10.5-80-49199-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-104.88.60.48-49199-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.52.146.130-49200-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 23.52.146.130-192.168.10.5-80-49200-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.52.146.130-49200-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.52.146.130-49200-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 23.52.146.130-192.168.10.5-80-49200-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 23.52.146.130-192.168.10.5-80-49200-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.52.146.130-49200-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.202.233.152-49201-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 23.202.233.152-192.168.10.5-80-49201-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.202.233.152-49201-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.202.233.152-49201-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 23.202.233.152-192.168.10.5-80-49201-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 23.202.233.152-192.168.10.5-80-49201-4/7/2017 8:54
# Reversing...
# Finished mapping packet to label BENIGN
# 192.168.10.5-23.202.233.152-49201-80-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49187-135-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49187-135-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-135-49187-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-135-49187-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.3-192.168.10.5-49666-49188-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49187-135-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49187-135-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49188-49666-4/7/2017 8:54
# Finished mapping packet to label BENIGN
# 192.168.10.5-192.168.10.3-49159-445-4/7/2017 8:54
# Reversing...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-837ffd3c5375> in processPacket(p)
#      22         print(pid)
# ---> 23         label = ipdict[pid]
#      24         pkt_df.loc[len(pkt_df)] = [str(p), label]
#
# KeyError: '192.168.10.5-192.168.10.3-49159-445-4/7/2017 8:54'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-e7538d0fc047> in <module>
#       1 for pcap in pcap_files[1:]:
# ----> 2     sniff(count=1000, offline=pcap, store=0, prn=processPacket)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scapy\sendrecv.py in sniff(*args, **kwargs)
#     970 def sniff(*args, **kwargs):
#     971     sniffer = AsyncSniffer()
# --> 972     sniffer._run(*args, **kwargs)
#     973     return sniffer.results
#     974
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scapy\sendrecv.py in _run(self, count, store, offline, prn, lfilter, L2socket, timeout, opened_socket, stop_filter, iface, started_callback, session, session_args, session_kwargs, *arg, **karg)
#     923                     p.sniffed_on = sniff_sockets[s]
#     924                     # on_packet_received handles the prn/storage
# --> 925                     session.on_packet_received(p)
#     926                     # check
#     927                     if (stop_filter and stop_filter(p)) or \
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scapy\sessions.py in on_packet_received(self, pkt)
#      45             self.lst.append(pkt)
#      46         if self.prn:
# ---> 47             result = self.prn(pkt)
#      48             if result is not None:
#      49                 print(result)
#
# <ipython-input-48-837ffd3c5375> in processPacket(p)
#      27         print("Reversing...")
#      28         pid = f"{dip}-{sip}-{dp}-{sp}-{formatDate(p.time)}"
# ---> 29         label = ipdict[pid]
#      30         pkt_df.loc[len(pkt_df)] = [str(p), label]
#      31         print("Finished mapping packet to label " + label)
#
# KeyError: '192.168.10.3-192.168.10.5-445-49159-4/7/2017 8:54'

# %%
sorted(dict(df2[(df2['Source IP'] == '192.168.10.5') & (df2['Destination IP'] == '192.168.10.3')]['Source Port'].value_counts()))
# Out:
# [123.0,
#  49152.0,
#  49153.0,
#  49154.0,
#  49155.0,
#  49156.0,
#  49157.0,
#  49158.0,
#  49159.0,
#  49160.0,
#  49161.0,
#  49162.0,
#  49163.0,
#  49164.0,
#  49165.0,
#  49166.0,
#  49167.0,
#  49168.0,
#  49169.0,
#  49170.0,
#  49171.0,
#  49172.0,
#  49173.0,
#  49174.0,
#  49175.0,
#  49176.0,
#  49177.0,
#  49178.0,
#  49179.0,
#  49180.0,
#  49181.0,
#  49182.0,
#  49183.0,
#  49184.0,
#  49185.0,
#  49186.0,
#  49187.0,
#  49188.0,
#  49189.0,
#  49190.0,
#  49191.0,
#  49192.0,
#  49193.0,
#  49194.0,
#  49195.0,
#  49196.0,
#  49197.0,
#  49198.0,
#  49199.0,
#  49200.0,
#  49201.0,
#  49202.0,
#  49203.0,
#  49204.0,
#  49205.0,
#  49206.0,
#  49207.0,
#  49208.0,
#  49209.0,
#  49210.0,
#  49211.0,
#  49212.0,
#  49213.0,
#  49214.0,
#  49215.0,
#  49216.0,
#  49217.0,
#  49218.0,
#  49219.0,
#  49220.0,
#  49221.0,
#  49222.0,
#  49223.0,
#  49224.0,
#  49225.0,
#  49226.0,
#  49227.0,
#  49228.0,
#  49229.0,
#  49230.0,
#  49231.0,
#  49232.0,
#  49233.0,
#  49234.0,
#  49235.0,
#  49236.0,
#  49237.0,
#  49238.0,
#  49239.0,
#  49240.0,
#  49241.0,
#  49242.0,
#  49243.0,
#  49244.0,
#  49245.0,
#  49246.0,
#  49247.0,
#  49248.0,
#  49249.0,
#  49250.0,
#  49251.0,
#  49252.0,
#  49253.0,
#  49254.0,
#  49255.0,
#  49256.0,
#  49257.0,
#  49258.0,
#  49259.0,
#  49260.0,
#  49261.0,
#  49262.0,
#  49263.0,
#  49264.0,
#  49265.0,
#  49266.0,
#  49267.0,
#  49268.0,
#  49269.0,
#  49270.0,
#  49271.0,
#  49272.0,
#  49273.0,
#  49274.0,
#  49275.0,
#  49276.0,
#  49277.0,
#  49278.0,
#  49279.0,
#  49280.0,
#  49281.0,
#  49282.0,
#  49283.0,
#  49284.0,
#  49285.0,
#  49286.0,
#  49287.0,
#  49288.0,
#  49289.0,
#  49290.0,
#  49291.0,
#  49292.0,
#  49293.0,
#  49294.0,
#  49295.0,
#  49296.0,
#  49297.0,
#  49298.0,
#  49299.0,
#  49300.0,
#  49301.0,
#  49302.0,
#  49303.0,
#  49304.0,
#  49305.0,
#  49306.0,
#  49307.0,
#  49308.0,
#  49309.0,
#  49310.0,
#  49311.0,
#  49312.0,
#  49313.0,
#  49314.0,
#  49315.0,
#  49316.0,
#  49317.0,
#  49318.0,
#  49319.0,
#  49320.0,
#  49321.0,
#  49322.0,
#  49323.0,
#  49324.0,
#  49325.0,
#  49326.0,
#  49327.0,
#  49328.0,
#  49329.0,
#  49330.0,
#  49331.0,
#  49332.0,
#  49333.0,
#  49334.0,
#  49335.0,
#  49336.0,
#  49337.0,
#  49338.0,
#  49339.0,
#  49340.0,
#  49341.0,
#  49342.0,
#  49343.0,
#  49344.0,
#  49345.0,
#  49346.0,
#  49347.0,
#  49348.0,
#  49349.0,
#  49350.0,
#  49351.0,
#  49352.0,
#  49353.0,
#  49354.0,
#  49355.0,
#  49356.0,
#  49357.0,
#  49358.0,
#  49359.0,
#  49360.0,
#  49361.0,
#  49362.0,
#  49363.0,
#  49364.0,
#  49365.0,
#  49366.0,
#  49367.0,
#  49368.0,
#  49369.0,
#  49370.0,
#  49371.0,
#  49372.0,
#  49373.0,
#  49374.0,
#  49375.0,
#  49376.0,
#  49377.0,
#  49378.0,
#  49379.0,
#  49380.0,
#  49381.0,
#  49382.0,
#  49383.0,
#  49384.0,
#  49385.0,
#  49386.0,
#  49387.0,
#  49388.0,
#  49389.0,
#  49390.0,
#  49391.0,
#  49392.0,
#  49393.0,
#  49394.0,
#  49395.0,
#  49396.0,
#  49397.0,
#  49398.0,
#  49399.0,
#  49400.0,
#  49401.0,
#  49402.0,
#  49403.0,
#  49404.0,
#  49405.0,
#  49406.0,
#  49407.0,
#  49408.0,
#  49409.0,
#  49410.0,
#  49411.0,
#  49412.0,
#  49413.0,
#  49414.0,
#  49415.0,
#  49416.0,
#  49417.0,
#  49418.0,
#  49419.0,
#  49420.0,
#  49421.0,
#  49422.0,
#  49423.0,
#  49424.0,
#  49425.0,
#  49426.0,
#  49427.0,
#  49428.0,
#  49429.0,
#  49430.0,
#  49431.0,
#  49432.0,
#  49433.0,
#  49434.0,
#  49435.0,
#  49436.0,
#  49437.0,
#  49438.0,
#  49439.0,
#  49440.0,
#  49441.0,
#  49442.0,
#  49443.0,
#  49444.0,
#  49445.0,
#  49446.0,
#  49447.0,
#  49448.0,
#  49449.0,
#  49450.0,
#  49451.0,
#  49452.0,
#  49453.0,
#  49454.0,
#  49455.0,
#  49456.0,
#  49457.0,
#  49458.0,
#  49459.0,
#  49460.0,
#  49461.0,
#  49462.0,
#  49463.0,
#  49464.0,
#  49465.0,
#  49466.0,
#  49467.0,
#  49468.0,
#  49469.0,
#  49470.0,
#  49471.0,
#  49472.0,
#  49473.0,
#  49474.0,
#  49475.0,
#  49476.0,
#  49477.0,
#  49478.0,
#  49479.0,
#  49480.0,
#  49481.0,
#  49482.0,
#  49483.0,
#  49484.0,
#  49485.0,
#  49486.0,
#  49487.0,
#  49488.0,
#  49490.0,
#  49491.0,
#  49492.0,
#  49493.0,
#  49494.0,
#  49495.0,
#  49496.0,
#  49497.0,
#  49498.0,
#  49499.0,
#  49500.0,
#  49501.0,
#  49502.0,
#  49503.0,
#  49504.0,
#  49505.0,
#  49506.0,
#  49507.0,
#  49508.0,
#  49509.0,
#  49510.0,
#  49511.0,
#  49512.0,
#  49513.0,
#  49514.0,
#  49515.0,
#  49516.0,
#  49517.0,
#  49518.0,
#  49519.0,
#  49520.0,
#  49521.0,
#  49522.0,
#  49523.0,
#  49524.0,
#  49525.0,
#  49526.0,
#  49527.0,
#  49528.0,
#  49529.0,
#  49530.0,
#  49531.0,
#  49532.0,
#  49533.0,
#  49534.0,
#  49535.0,
#  49536.0,
#  49537.0,
#  49538.0,
#  49539.0,
#  49540.0,
#  49541.0,
#  49542.0,
#  49543.0,
#  49544.0,
#  49545.0,
#  49546.0,
#  49547.0,
#  49548.0,
#  49549.0,
#  49550.0,
#  49551.0,
#  49552.0,
#  49553.0,
#  49554.0,
#  49555.0,
#  49556.0,
#  49557.0,
#  49558.0,
#  49559.0,
#  49560.0,
#  49561.0,
#  49562.0,
#  49563.0,
#  49565.0,
#  49566.0,
#  49567.0,
#  49568.0,
#  49569.0,
#  49570.0,
#  49571.0,
#  49572.0,
#  49573.0,
#  49574.0,
#  49575.0,
#  49576.0,
#  49577.0,
#  49578.0,
#  49579.0,
#  49580.0,
#  49581.0,
#  49582.0,
#  49583.0,
#  49584.0,
#  49585.0,
#  49586.0,
#  49587.0,
#  49588.0,
#  49589.0,
#  49590.0,
#  49591.0,
#  49592.0,
#  49593.0,
#  49594.0,
#  49595.0,
#  49596.0,
#  49597.0,
#  49598.0,
#  49599.0,
#  49600.0,
#  49601.0,
#  49602.0,
#  49603.0,
#  49604.0,
#  49605.0,
#  49606.0,
#  49607.0,
#  49608.0,
#  49609.0,
#  49610.0,
#  49611.0,
#  49612.0,
#  49613.0,
#  49614.0,
#  49615.0,
#  49616.0,
#  49617.0,
#  49618.0,
#  49619.0,
#  49620.0,
#  49621.0,
#  49622.0,
#  49623.0,
#  49624.0,
#  49625.0,
#  49626.0,
#  49627.0,
#  49628.0,
#  49629.0,
#  49630.0,
#  49631.0,
#  49632.0,
#  49633.0,
#  49634.0,
#  49635.0,
#  49636.0,
#  49637.0,
#  49638.0,
#  49639.0,
#  49640.0,
#  49641.0,
#  49642.0,
#  49643.0,
#  49644.0,
#  49645.0,
#  49646.0,
#  49647.0,
#  49648.0,
#  49649.0,
#  49650.0,
#  49651.0,
#  49652.0,
#  49653.0,
#  49654.0,
#  49655.0,
#  49656.0,
#  49657.0,
#  49658.0,
#  49659.0,
#  49660.0,
#  49661.0,
#  49662.0,
#  49663.0,
#  49664.0,
#  49665.0,
#  49666.0,
#  49667.0,
#  49668.0,
#  49669.0,
#  49670.0,
#  49671.0,
#  49672.0,
#  49673.0,
#  49674.0,
#  49675.0,
#  49676.0,
#  49677.0,
#  49678.0,
#  49679.0,
#  49680.0,
#  49681.0,
#  49682.0,
#  49683.0,
#  49684.0,
#  49685.0,
#  49686.0,
#  49687.0,
#  49688.0,
#  49689.0,
#  49690.0,
#  49691.0,
#  49692.0,
#  49693.0,
#  49694.0,
#  49695.0,
#  49696.0,
#  49697.0,
#  49698.0,
#  49699.0,
#  49700.0,
#  49701.0,
#  49702.0,
#  49703.0,
#  49705.0,
#  49706.0,
#  49707.0,
#  49708.0,
#  49709.0,
#  49710.0,
#  49711.0,
#  49712.0,
#  49713.0,
#  49714.0,
#  49715.0,
#  49716.0,
#  49717.0,
#  49718.0,
#  49719.0,
#  49720.0,
#  49721.0,
#  49722.0,
#  49723.0,
#  49724.0,
#  49725.0,
#  49726.0,
#  49727.0,
#  49728.0,
#  49729.0,
#  49730.0,
#  49731.0,
#  49732.0,
#  49733.0,
#  49734.0,
#  49735.0,
#  49736.0,
#  49737.0,
#  49738.0,
#  49739.0,
#  49740.0,
#  49741.0,
#  49742.0,
#  49743.0,
#  49744.0,
#  49745.0,
#  49746.0,
#  49747.0,
#  49748.0,
#  49749.0,
#  49750.0,
#  49751.0,
#  49752.0,
#  49753.0,
#  49754.0,
#  49755.0,
#  49756.0,
#  49758.0,
#  49759.0,
#  49760.0,
#  49761.0,
#  49762.0,
#  49763.0,
#  49765.0,
#  49766.0,
#  49767.0,
#  49768.0,
#  49769.0,
#  49770.0,
#  49771.0,
#  49772.0,
#  49773.0,
#  49774.0,
#  49775.0,
#  49776.0,
#  49777.0,
#  49778.0,
#  49779.0,
#  49780.0,
#  49781.0,
#  49782.0,
#  49783.0,
#  49784.0,
#  49785.0,
#  49786.0,
#  49787.0,
#  49788.0,
#  49789.0,
#  49790.0,
#  49791.0,
#  49792.0,
#  49793.0,
#  49794.0,
#  49795.0,
#  49796.0,
#  49797.0,
#  49798.0,
#  49799.0,
#  49800.0,
#  49801.0,
#  49802.0,
#  49803.0,
#  49804.0,
#  49805.0,
#  49806.0,
#  49807.0,
#  49808.0,
#  49809.0,
#  49810.0,
#  49811.0,
#  49812.0,
#  49813.0,
#  49814.0,
#  49815.0,
#  49816.0,
#  49817.0,
#  49818.0,
#  49819.0,
#  49820.0,
#  49821.0,
#  49822.0,
#  49823.0,
#  49824.0,
#  49825.0,
#  49826.0,
#  49827.0,
#  49828.0,
#  49829.0,
#  49830.0,
#  49831.0,
#  49832.0,
#  49833.0,
#  49834.0,
#  49835.0,
#  49836.0,
#  49837.0,
#  49838.0,
#  49839.0,
#  49840.0,
#  49841.0,
#  49842.0,
#  49843.0,
#  49844.0,
#  49845.0,
#  49846.0,
#  49847.0,
#  49848.0,
#  49849.0,
#  49850.0,
#  49851.0,
#  49852.0,
#  49853.0,
#  49854.0,
#  49855.0,
#  49856.0,
#  49857.0,
#  49858.0,
#  49859.0,
#  49860.0,
#  49861.0,
#  49862.0,
#  49863.0,
#  49864.0,
#  49865.0,
#  49866.0,
#  49867.0,
#  49868.0,
#  49869.0,
#  49870.0,
#  49871.0,
#  49872.0,
#  49873.0,
#  49874.0,
#  49875.0,
#  49876.0,
#  49877.0,
#  49878.0,
#  49879.0,
#  49880.0,
#  49881.0,
#  49882.0,
#  49883.0,
#  49884.0,
#  49885.0,
#  49886.0,
#  49887.0,
#  49888.0,
#  49889.0,
#  49890.0,
#  49891.0,
#  49892.0,
#  49893.0,
#  49894.0,
#  49895.0,
#  49896.0,
#  49897.0,
#  49898.0,
#  49899.0,
#  49900.0,
#  49901.0,
#  49902.0,
#  49903.0,
#  49904.0,
#  49905.0,
#  49906.0,
#  49907.0,
#  49908.0,
#  49909.0,
#  49910.0,
#  49911.0,
#  49912.0,
#  49913.0,
#  49914.0,
#  49915.0,
#  49916.0,
#  49917.0,
#  49918.0,
#  49919.0,
#  49920.0,
#  49921.0,
#  49922.0,
#  49923.0,
#  49924.0,
#  49925.0,
#  49926.0,
#  49927.0,
#  49928.0,
#  49929.0,
#  49930.0,
#  49931.0,
#  49932.0,
#  49933.0,
#  49934.0,
#  49935.0,
#  49936.0,
#  49937.0,
#  49938.0,
#  49939.0,
#  49940.0,
#  49941.0,
#  49942.0,
#  49943.0,
#  49944.0,
#  49945.0,
#  49946.0,
#  49947.0,
#  49948.0,
#  49949.0,
#  49950.0,
#  49951.0,
#  49952.0,
#  49953.0,
#  49954.0,
#  49955.0,
#  49956.0,
#  49957.0,
#  49958.0,
#  49959.0,
#  49960.0,
#  49961.0,
#  49963.0,
#  49964.0,
#  49965.0,
#  49966.0,
#  49967.0,
#  49968.0,
#  49969.0,
#  49970.0,
#  49971.0,
#  49972.0,
#  49973.0,
#  49974.0,
#  49975.0,
#  49976.0,
#  49977.0,
#  49978.0,
#  49979.0,
#  49980.0,
#  49981.0,
#  49982.0,
#  49983.0,
#  49984.0,
#  49985.0,
#  49986.0,
#  49987.0,
#  49988.0,
#  49989.0,
#  49990.0,
#  49991.0,
#  49992.0,
#  49993.0,
#  49994.0,
#  49995.0,
#  49996.0,
#  49997.0,
#  49998.0,
#  49999.0,
#  50000.0,
#  50001.0,
#  50002.0,
#  50003.0,
#  50004.0,
#  50005.0,
#  50006.0,
#  50007.0,
#  50008.0,
#  50009.0,
#  50010.0,
#  50011.0,
#  50012.0,
#  50013.0,
#  50014.0,
#  50015.0,
#  50016.0,
#  50017.0,
#  50018.0,
#  50019.0,
#  50020.0,
#  50021.0,
#  50022.0,
#  50023.0,
#  50024.0,
#  50025.0,
#  50026.0,
#  50027.0,
#  50028.0,
#  50029.0,
#  50030.0,
#  50031.0,
#  50032.0,
#  50033.0,
#  50034.0,
#  50035.0,
#  50036.0,
#  50037.0,
#  50038.0,
#  50039.0,
#  50040.0,
#  50041.0,
#  50042.0,
#  50043.0,
#  50044.0,
#  50045.0,
#  50046.0,
#  50047.0,
#  50048.0,
#  50049.0,
#  50050.0,
#  50051.0,
#  50052.0,
#  50053.0,
#  50054.0,
#  50055.0,
#  50056.0,
#  50057.0,
#  50058.0,
#  50059.0,
#  50060.0,
#  50061.0,
#  50062.0,
#  50063.0,
#  50064.0,
#  50065.0,
#  50066.0,
#  50067.0,
#  50068.0,
#  50069.0,
#  50070.0,
#  50071.0,
#  50072.0,
#  50073.0,
#  50074.0,
#  50075.0,
#  50076.0,
#  50077.0,
#  50078.0,
#  50079.0,
#  50080.0,
#  50081.0,
#  50082.0,
#  50083.0,
#  50084.0,
#  50085.0,
#  50086.0,
#  50087.0,
#  50088.0,
#  50089.0,
#  50090.0,
#  50091.0,
#  50092.0,
#  50093.0,
#  50094.0,
#  50095.0,
#  50096.0,
#  50097.0,
#  50098.0,
#  50099.0,
#  50100.0,
#  50101.0,
#  50102.0,
#  50103.0,
#  50104.0,
#  50105.0,
#  50106.0,
#  50107.0,
#  50108.0,
#  50109.0,
#  50110.0,
#  50111.0,
#  50112.0,
#  50113.0,
#  50114.0,
#  50115.0,
#  50116.0,
#  50117.0,
#  50118.0,
#  50119.0,
#  50120.0,
#  50121.0,
#  50122.0,
#  50123.0,
#  50124.0,
#  50125.0,
#  50126.0,
#  50127.0,
#  50128.0,
#  50129.0,
#  50130.0,
#  50131.0,
#  50132.0,
#  50133.0,
#  50134.0,
#  50135.0,
#  50136.0,
#  50137.0,
#  50138.0,
#  50139.0,
#  50140.0,
#  50141.0,
#  50142.0,
#  50143.0,
#  50144.0,
#  50145.0,
#  50146.0,
#  50147.0,
#  50148.0,
#  50149.0,
#  50150.0,
#  50151.0,
#  50152.0,
#  50153.0,
#  50154.0,
#  50155.0,
#  50156.0,
#  ...]

# %%
len(ipdict)
# Out:
# 2516345

# %%
pkts = sniff(count=100, offline=pcap_files[1])

# %%
pkts[53][IP].dst
# Out:
# '192.168.10.5'

# %%
pkts[53].display()
# Out:
# ###[ Ethernet ]###
#   dst       = b8:ac:6f:36:0a:8b
#   src       = 18:66:da:9b:e3:7d
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 52
#      id        = 6977
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x4a2a
#      src       = 192.168.10.3
#      dst       = 192.168.10.5
#      \options   \
# ###[ TCP ]###
#         sport     = microsoft_ds
#         dport     = 49159
#         seq       = 2158492462
#         ack       = 728086466
#         dataofs   = 8
#         reserved  = 0
#         flags     = A
#         window    = 2049
#         chksum    = 0xf551
#         urgptr    = 0
#         options   = [('NOP', None), ('NOP', None), ('SAck', (728086465, 728086466))]

# %%
for i in range(len(pkts)):
    if (IP in pkts[i] or ARP in pkts[i]) and TCP in pkts[i]:
        print(i)
# Out:
# 51
# 52
# 53
# 54
# 82
# 83
# 84
# 85
# 86
# 87
# 88
# 89
# 90
# 91
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 99

# %%
pkts[0].summary()
# Out:
# 'Ether / IP / TCP 8.254.250.126:http > 192.168.10.5:49188 FA / Padding'

# %%
str(pkts[0])
# Out:
# "b'\\xb8\\xaco6\\n\\x8b\\x00\\xc1\\xb1\\x14\\xeb1\\x08\\x00E\\x00\\x00(\\x1b4\\x00\\x007\\x06\\x9ar\\x08\\xfe\\xfa~\\xc0\\xa8\\n\\x05\\x00P\\xc0$\\xdf\\xd7\\xad\\x8b\\x94\\xb88\\x9bP\\x11\\x01I\\xc54\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00'"

# %%
for p in pkts:
    print (IP in p, TCP in p)
# Out:
# True True
# True True
# True True
# True True
# True True
# True True
# True True
# True True
# False False
# False False

# %%
pkts[8].display()
# Out:
# ###[ 802.3 ]###
#   dst       = 01:00:0c:cc:cc:cc
#   src       = 70:6e:6d:1d:bb:04
#   len       = 443
# ###[ LLC ]###
#      dsap      = 0xaa
#      ssap      = 0xaa
#      ctrl      = 3
# ###[ SNAP ]###
#         OUI       = 0xc
#         code      = 0x2000
# ###[ Raw ]###
#            load      = '\x02\xb4\x81G\x00\x01\x00\x08SWCL\x00\x05\x01\tCisco IOS Software, Catalyst L3 Switch Software (CAT3K_CAA-UNIVERSALK9-M), Version 15.2(2)E6, RELEASE SOFTWARE (fc1)\nTechnical Support: http://www.cisco.com/techsupport\nCopyright (c) 1986-2016 by Cisco Systems, Inc.\nCompiled Sat 17-Dec-16 00:22 by prod_rel_team\x00\x06\x00\x16cisco WS-C3850-48U\x00\x02\x00\x11\x00\x00\x00\x01\x01\x01\xcc\x00\x04\xc0\xa8\n\x02\x00\x03\x00\x18GigabitEthernet1/0/4\x00\x04\x00\x08\x00\x00\x00(\x00\t\x00\x04\x00\n\x00\x06\x00\n\x00\x0b\x00\x05\x01\x00\x12\x00\x05\x00\x00\x13\x00\x05\x00\x00\x16\x00\x11\x00\x00\x00\x01\x01\x01\xcc\x00\x04\xc0\xa8\n\x02\x00\x1a\x00\x10\x00\x00\x00\x01\x00\x00\x00\x00\xff\xff\xff\xff\x00\x1f\x00\x05\x01\x10\x04\x00\x13706e.6d1d.bb00\x00\x10\x03\x00\x051'

# %%
import ipaddress, itertools

# %%
def convertIP(ipv6):
    myIP = ipaddress.ip_address(ipv6)
    hextets = myIP.exploded.split(":")
    
    # from itertools recipes
    def grouper(iterable, n, fillvalue=None):
        args = [iter(iterable)] * n
        return itertools.zip_longest(*args, fillvalue=fillvalue)

    new_groups = [int(a+b, base=16) for (a, b) in grouper(hextets, 2)]
    
    return '.'.join(map(str, new_groups))

# %%
convertIP(pkts[0].src)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-146-dfbfcbb7cd0f> in <module>
# ----> 1 convertIP(pkts[0].src)
#
# <ipython-input-144-95066ea6c44a> in convertIP(ipv6)
#       1 def convertIP(ipv6):
# ----> 2     myIP = ipaddress.ip_address(ipv6)
#       3     hextets = myIP.exploded.split(":")
#       4
#       5     # from itertools recipes
#
# ~\AppData\Local\Continuum\anaconda3\lib\ipaddress.py in ip_address(address)
#      52
#      53     raise ValueError('%r does not appear to be an IPv4 or IPv6 address' %
# ---> 54                      address)
#      55
#      56
#
# ValueError: '00:c1:b1:14:eb:31' does not appear to be an IPv4 or IPv6 address

# %%
pkts[0].display()
# Out:
# ###[ Ethernet ]###
#   dst       = b8:ac:6f:36:0a:8b
#   src       = 00:c1:b1:14:eb:31
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 6964
#      flags     =
#      frag      = 0
#      ttl       = 55
#      proto     = tcp
#      chksum    = 0x9a72
#      src       = 8.254.250.126
#      dst       = 192.168.10.5
#      \options   \
# ###[ TCP ]###
#         sport     = http
#         dport     = 49188
#         seq       = 3755453835
#         ack       = 2495101083
#         dataofs   = 5
#         reserved  = 0
#         flags     = FA
#         window    = 329
#         chksum    = 0xc534
#         urgptr    = 0
#         options   = []
# ###[ Padding ]###
#            load      = '\x00\x00\x00\x00\x00\x00'

# %%
p.display()
# Out:
# ###[ 802.3 ]###
#   dst       = 01:00:0c:cc:cc:cc
#   src       = 70:6e:6d:1d:bb:06
#   len       = 443
# ###[ LLC ]###
#      dsap      = 0xaa
#      ssap      = 0xaa
#      ctrl      = 3
# ###[ SNAP ]###
#         OUI       = 0xc
#         code      = 0x2000
# ###[ Raw ]###
#            load      = '\x02\xb4\x81E\x00\x01\x00\x08SWCL\x00\x05\x01\tCisco IOS Software, Catalyst L3 Switch Software (CAT3K_CAA-UNIVERSALK9-M), Version 15.2(2)E6, RELEASE SOFTWARE (fc1)\nTechnical Support: http://www.cisco.com/techsupport\nCopyright (c) 1986-2016 by Cisco Systems, Inc.\nCompiled Sat 17-Dec-16 00:22 by prod_rel_team\x00\x06\x00\x16cisco WS-C3850-48U\x00\x02\x00\x11\x00\x00\x00\x01\x01\x01\xcc\x00\x04\xc0\xa8\n\x02\x00\x03\x00\x18GigabitEthernet1/0/6\x00\x04\x00\x08\x00\x00\x00(\x00\t\x00\x04\x00\n\x00\x06\x00\n\x00\x0b\x00\x05\x01\x00\x12\x00\x05\x00\x00\x13\x00\x05\x00\x00\x16\x00\x11\x00\x00\x00\x01\x01\x01\xcc\x00\x04\xc0\xa8\n\x02\x00\x1a\x00\x10\x00\x00\x00\x01\x00\x00\x00\x00\xff\xff\xff\xff\x00\x1f\x00\x05\x01\x10\x04\x00\x13706e.6d1d.bb00\x00\x10\x03\x00\x051'

# %%
p = pkts[6]

p.dst

p.display()
# Out:
# ###[ Ethernet ]###
#   dst       = 33:33:00:01:00:02
#   src       = 00:1e:4f:d4:ca:28
#   type      = IPv6
# ###[ IPv6 ]###
#      version   = 6
#      tc        = 0
#      fl        = 0
#      plen      = 111
#      nh        = UDP
#      hlim      = 1
#      src       = fe80::f470:cd16:3cf6:bd7b
#      dst       = ff02::1:2
# ###[ UDP ]###
#         sport     = dhcpv6_client
#         dport     = dhcpv6_server
#         len       = 111
#         chksum    = 0x6cf2
# ###[ DHCPv6 Solicit Message ]###
#            msgtype   = SOLICIT
#            trid      = 0xf44ed9
# ###[ DHCP6 Elapsed Time Option ]###
#               optcode   = ELAPSED_TIME
#               optlen    = 2
#               elapsedtime= 0.00 sec
# ###[ DHCP6 Client Identifier Option ]###
#                  optcode   = CLIENTID
#                  optlen    = 14
#                  \duid      \
#                   |###[ DUID - Link-layer address plus time ]###
#                   |  type      = Link-layer address plus time
#                   |  hwtype    = Ethernet (10Mb)
#                   |  timeval   = Thu, 15 Jun 2017 19:01:51 -1000 (1497553311)
#                   |  lladdr    = 00:1e:4f:d4:ca:28
# ###[ DHCP6 Identity Association for Non-temporary Addresses Option ]###
#                     optcode   = IA_NA
#                     optlen    = 12
#                     iaid      = 0x3001e4f
#                     T1        = 0
#                     T2        = 0
#                     \ianaopts  \
# ###[ DHCP6 Option - Client FQDN ]###
#                        optcode   = OPTION_CLIENT_FQDN
#                        optlen    = 25
#                        res       = 0
#                        flags     =
#                        fqdn      = 'mitacs-pc4.Testbed1.ca.'
# ###[ DHCP6 Vendor Class Option ]###
#                           optcode   = VENDOR_CLASS
#                           optlen    = 14
#                           enterprisenum= Microsoft
#                           \vcdata    \
#                            |###[ vendor class data ]###
#                            |  len       = 8
#                            |  data      = 'MSFT 5.0'
# ###[ DHCP6 Option Request Option ]###
#                              optcode   = ORO
#                              optlen    = 8
#                              reqopts   = [Domain Search List option, DNS Recursive Name Server Option, VENDOR_OPTS, OPTION_CLIENT_FQDN]

# %%
d = datetime.datetime.strptime("03/07/2017 08:55:58", "%d/%m/%Y %H:%M:%S")

# %%
p[Ether].time
# Out:
# 1499082958.598308

# %%
p.time
# Out:
# 1499082958.598308

# %%
d.timestamp()
# Out:
# 1499108158.0

# %%
ipdict['8.254.250.126-192.168.10.5-80-49188-6-3/7/2017 8:55']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-4e71f74a7cc1> in <module>
# ----> 1 ipdict['192.168.10.5-8.254.250.126-80-49188-6-3/7/2017 8:55']
#
# KeyError: '192.168.10.5-8.254.250.126-80-49188-6-3/7/2017 8:55'
