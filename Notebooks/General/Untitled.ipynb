# %% [markdown]
# # PBS - Poster Board Stats
# This Jupyter Notebook was supported by Coders Like You.

# %%
import numpy as np
np.set_printoptions(suppress=True)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

import glob, pickle, time

# %%
NOTEBOOK_PATH = "C:/Users/Xetrov/Desktop/SciFair20/Code/"

# %%
x_scaled = pd.read_csv(NOTEBOOK_PATH + "IDS2017/x_scaled_powertransform.csv")

# %%
y_bin = pd.read_csv(NOTEBOOK_PATH + "IDS2017/y_all_binary.csv")

# %%
y_reg = pd.read_csv(NOTEBOOK_PATH + "IDS2017/y_1henc.csv")

# %%
y_group = pd.read_csv(NOTEBOOK_PATH + "IDS2017/y_grouped_1henc.csv")

# %%
y_flat = np.argmax(y_group.to_numpy(), axis=1)

# %%
grouplabels = sorted(y_group.columns)

# %%
y_flatl = pd.Series(y_flat).replace(dict(enumerate(grouplabels)))

# %%
y_flatl.value_counts()[1:]
# Out:
# DoS/DDoS        380699
# PortScan        158930
# Brute Force      13835
# Web Attack        2180
# Botnet            1966
# Infiltration        36
# dtype: int64

# %%
plt.figure(figsize=(5,5))
ax = sns.barplot(x=grouplabels, y=y_flatl.value_counts())
sns.set_style("darkgrid")
ax.set_yscale("log")

ax.set_ylabel("Number of Instances (Logarithmic Scale)")
ax.set_xticklabels(grouplabels, rotation=30)

plt.savefig(NOTEBOOK_PATH + 'Pictures/imbalance.png', format='png', dpi=600)
