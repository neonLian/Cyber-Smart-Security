# %% [markdown]
# # CSE-CIC-IDS 2017

# %%
model_id = "cnn7-autoencodershape"

# %%
import numpy as np
np.random.seed(42)
np.set_printoptions(suppress=True)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

import glob, time, os

import keras
# Out:
# Using TensorFlow backend.
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
NOTEBOOK_PATH = "C:/Users/Xetrov/Desktop/SciFair20/Code/"

# %%
x_scaled = pd.read_csv(NOTEBOOK_PATH + "IDS2017/x_scaled_powertransform.csv")

# %%
y_df_enc = pd.read_csv(NOTEBOOK_PATH + "IDS2017/y_all_binary.csv")

# %% [markdown]
# # Reshape into images

# %%
x_img = x_scaled.to_numpy().reshape((len(x_scaled), 4, 17))

# %%
x_img = np.expand_dims(x_img, -1)

# %% [markdown]
# # Split data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split

x_train, x_valtest, y_train, y_valtest = train_test_split(x_img, y_df_enc, test_size = 0.4, random_state = 42)

x_val, x_test, y_val, y_test = train_test_split(x_valtest, y_valtest, test_size = 0.5, random_state = 42)

del x_train
del y_train
del x_valtest 
del y_valtest

# %% [markdown]
# # Read ADASYN data

# %%
x_train_res = pd.read_csv(NOTEBOOK_PATH + "IDS2017/x_adasyn_binary.csv")

# %%
y_train_res = pd.read_csv(NOTEBOOK_PATH + "IDS2017/y_adasyn_binary.csv")['IsAttack']

# %%
x_train_resimg = np.expand_dims(x_train_res.to_numpy().reshape((len(x_train_res), 4, 17)), -1)

# %% [markdown]
# # Train model

# %%
from keras.models import Model, Sequential
from keras.layers import Dense, BatchNormalization, Dropout, InputLayer, Conv2D, Flatten
from keras.optimizers import SGD, Adam

# %%
def addDenseBlock(model, units, **params):
    model.add(Dense(units=units, activation=params['hidden_activation'], input_dim=x_train_res.shape[1]))
    if params['batch_normalization']: model.add(BatchNormalization())
    if params['dropout_rate'] > 0: model.add(Dropout(params['dropout_rate']))

def addConvBlock(model, units, **params):
    model.add(Conv2D(filters=units, kernel_size=params['kernel_size'], activation=params['hidden_activation'], padding=params['padding'],input_shape=(4,17,1)))
    if params['batch_normalization']: model.add(BatchNormalization())
    if params['dropout_rate'] > 0: model.add(Dropout(params['dropout_rate']))
        
def createModel(**in_params):
    """
    Supported parameters:
    batch_normalization - True or False
    dropout_rate - 0 to 1
    num_units - integer
    learning_rate - float
    activation_function - string
    """
    
    model = Sequential()

    # Set default values
    params = {
        'batch_normalization': True,
        'dropout_rate': 0,
        'num_layers': 6,
        'num_units': 128,
        'learning_rate': 0.001,
        'hidden_activation': 'relu',
        'final_activation': 'sigmoid',
        'kernel_size': (2,2),
        'padding':'same'
    }
    
    # Replace defaults with specified parameters
    for param in in_params:
        params[param] = in_params[param]    
    
    # InputLayer causes serialization issues
#     model.add( InputLayer(input_shape = (x_train.shape[1],) ) )
    
#     for i in range(params['num_layers']):
#         addDenseBlock(model, params['num_units'], **params)

    addConvBlock(model, 256, **params)
    addConvBlock(model, 128, **params)
    addConvBlock(model, 64, **params)
    addConvBlock(model, 32, **params)
    addConvBlock(model, 64, **params)
    addConvBlock(model, 128, **params)
    addConvBlock(model, 256, **params)
    
    model.add(Flatten())

    model.add(Dense(units=1, activation=params['final_activation']))

    # optim = SGD(lr=0.001, nesterov=True)
    optim = Adam(lr=params['learning_rate'])

    model.compile(loss='binary_crossentropy', optimizer=optim, metrics=['accuracy'])
    
#     print(params)
    
    return model

# %% [markdown]
# Ensure a GPU is available

# %%
import keras.backend as K

K.tensorflow_backend._get_available_gpus()
# Out:
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %% [markdown]
# ### Callbacks

# %%
from keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint

def timestamp():
    return time.strftime("%m-%d-%Y, %I%M%p")

csv_callback = CSVLogger(NOTEBOOK_PATH + 'Loss Logs/%s (%s)' % (model_id, timestamp()), append=True)
early_stop = EarlyStopping(monitor = 'val_loss', min_delta=0.0001, patience=5)

savedir = NOTEBOOK_PATH + "Models/%s/" % model_id
if not os.path.exists(savedir):
    os.makedirs(savedir)
    print("Created " + savedir)
else:
    print("Using " + savedir)
# Out:
# Created C:/Users/Xetrov/Desktop/SciFair20/Code/Models/cnn7-autoencodershape/

# %% [markdown]
# ### Training

# %%
import itertools

trainEpochs = 400

parameters = {'batch_size': 1000, 'batch_normalization':True, 'dropout_rate':0, 'final_activation': 'sigmoid'}

# %%
# %%time
# print(model_id)
model = createModel(**parameters)
# model = keras.models.load_model(NOTEBOOK_PATH + "Models/cnn4-adasyn-run1/cnn(4).h5")
model.summary()
model_checkpoint = ModelCheckpoint(NOTEBOOK_PATH + "Models/%s/cnn({epoch}).h5" % (model_id), monitor='val_loss')
model.fit(x_train_resimg, y_train_res, validation_data=(x_val, y_val), batch_size=parameters['batch_size'], epochs=trainEpochs, verbose=2, callbacks=[csv_callback, model_checkpoint])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 4, 17, 256)        1280
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 4, 17, 256)        1024
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 17, 128)        131200
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 4, 17, 128)        512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 17, 64)         32832
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 17, 64)         256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 17, 32)         8224
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 17, 32)         128
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 17, 64)         8256
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 4, 17, 64)         256
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 17, 128)        32896
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 4, 17, 128)        512
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 17, 256)        131328
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 4, 17, 256)        1024
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 17408)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17409
# =================================================================
# Total params: 367,137
# Trainable params: 365,281
# Non-trainable params: 1,856
# _________________________________________________________________
# Train on 2727615 samples, validate on 566149 samples
# Epoch 1/400
#  - 183s - loss: 0.0450 - acc: 0.9858 - val_loss: 0.0248 - val_acc: 0.9931
# Epoch 2/400
#  - 181s - loss: 0.0212 - acc: 0.9946 - val_loss: 0.0227 - val_acc: 0.9945
# Epoch 3/400
#  - 182s - loss: 0.0164 - acc: 0.9960 - val_loss: 0.0175 - val_acc: 0.9958
# Epoch 4/400
#  - 181s - loss: 0.0155 - acc: 0.9963 - val_loss: 0.0167 - val_acc: 0.9950
# Epoch 5/400
#  - 182s - loss: 0.0151 - acc: 0.9964 - val_loss: 0.0167 - val_acc: 0.9951
# Epoch 6/400
#  - 182s - loss: 0.0139 - acc: 0.9967 - val_loss: 0.0175 - val_acc: 0.9960
# Epoch 7/400
#  - 182s - loss: 0.0134 - acc: 0.9969 - val_loss: 0.0183 - val_acc: 0.9951
# Epoch 8/400
#  - 183s - loss: 0.0131 - acc: 0.9970 - val_loss: 0.0170 - val_acc: 0.9958
# Epoch 9/400
#  - 183s - loss: 0.0123 - acc: 0.9971 - val_loss: 0.0142 - val_acc: 0.9964
# Epoch 10/400
#  - 183s - loss: 0.0122 - acc: 0.9972 - val_loss: 0.0143 - val_acc: 0.9963
# Epoch 11/400
#  - 182s - loss: 0.0114 - acc: 0.9974 - val_loss: 0.0184 - val_acc: 0.9968
# Epoch 12/400
#  - 182s - loss: 0.0116 - acc: 0.9973 - val_loss: 0.0125 - val_acc: 0.9967
# Epoch 13/400
#  - 181s - loss: 0.0112 - acc: 0.9975 - val_loss: 0.0136 - val_acc: 0.9962
# Epoch 14/400
#  - 182s - loss: 0.0116 - acc: 0.9973 - val_loss: 0.0133 - val_acc: 0.9966
# Epoch 15/400
#  - 182s - loss: 0.0109 - acc: 0.9975 - val_loss: 0.0145 - val_acc: 0.9966
# Epoch 16/400
#  - 182s - loss: 0.0109 - acc: 0.9975 - val_loss: 0.0110 - val_acc: 0.9969
# Epoch 17/400
#  - 183s - loss: 0.0108 - acc: 0.9976 - val_loss: 0.0143 - val_acc: 0.9966
# Epoch 18/400
#  - 183s - loss: 0.0109 - acc: 0.9976 - val_loss: 0.0122 - val_acc: 0.9967
# Epoch 19/400
#  - 182s - loss: 0.0105 - acc: 0.9976 - val_loss: 0.0106 - val_acc: 0.9972
# Epoch 20/400
#  - 182s - loss: 0.0106 - acc: 0.9977 - val_loss: 0.0120 - val_acc: 0.9969
# Epoch 21/400
#  - 182s - loss: 0.0107 - acc: 0.9976 - val_loss: 0.0116 - val_acc: 0.9971
# Epoch 22/400
#  - 183s - loss: 0.0103 - acc: 0.9977 - val_loss: 0.0128 - val_acc: 0.9969
# Epoch 23/400
#  - 182s - loss: 0.0102 - acc: 0.9977 - val_loss: 0.0120 - val_acc: 0.9969
# Epoch 24/400
#  - 182s - loss: 0.0104 - acc: 0.9977 - val_loss: 0.0105 - val_acc: 0.9979
# Epoch 25/400
#  - 183s - loss: 0.0100 - acc: 0.9978 - val_loss: 0.0153 - val_acc: 0.9963
# Epoch 26/400
#  - 182s - loss: 0.0100 - acc: 0.9978 - val_loss: 0.0115 - val_acc: 0.9971
# Epoch 27/400
#  - 182s - loss: 0.0098 - acc: 0.9979 - val_loss: 0.0203 - val_acc: 0.9966
# Epoch 28/400
#  - 181s - loss: 0.0097 - acc: 0.9979 - val_loss: 0.0168 - val_acc: 0.9962
# Epoch 29/400
#  - 182s - loss: 0.0095 - acc: 0.9980 - val_loss: 0.0110 - val_acc: 0.9977
# Epoch 30/400
#  - 183s - loss: 0.0093 - acc: 0.9981 - val_loss: 0.0110 - val_acc: 0.9977
# Epoch 31/400
#  - 182s - loss: 0.0097 - acc: 0.9979 - val_loss: 0.0155 - val_acc: 0.9953
# Epoch 32/400
#  - 182s - loss: 0.0097 - acc: 0.9979 - val_loss: 0.0108 - val_acc: 0.9971
# Epoch 33/400
#  - 182s - loss: 0.0095 - acc: 0.9980 - val_loss: 0.0105 - val_acc: 0.9974
# Epoch 34/400
#  - 182s - loss: 0.0092 - acc: 0.9981 - val_loss: 0.0137 - val_acc: 0.9950
# Epoch 35/400
#  - 183s - loss: 0.0097 - acc: 0.9979 - val_loss: 0.0096 - val_acc: 0.9978
# Epoch 36/400
#  - 182s - loss: 0.0093 - acc: 0.9980 - val_loss: 0.0089 - val_acc: 0.9980
# Epoch 37/400
#  - 182s - loss: 0.0090 - acc: 0.9981 - val_loss: 0.0101 - val_acc: 0.9979
# Epoch 38/400
#  - 182s - loss: 0.0092 - acc: 0.9981 - val_loss: 0.0100 - val_acc: 0.9977
# Epoch 39/400
#  - 180s - loss: 0.0090 - acc: 0.9981 - val_loss: 0.0096 - val_acc: 0.9979
# Epoch 40/400
#  - 182s - loss: 0.0089 - acc: 0.9982 - val_loss: 0.0148 - val_acc: 0.9947
# Epoch 41/400
#  - 182s - loss: 0.0093 - acc: 0.9980 - val_loss: 0.0120 - val_acc: 0.9971
# Epoch 42/400
#  - 182s - loss: 0.0090 - acc: 0.9981 - val_loss: 0.0112 - val_acc: 0.9970
# Epoch 43/400
#  - 182s - loss: 0.0091 - acc: 0.9981 - val_loss: 0.0122 - val_acc: 0.9973
# Epoch 44/400
#  - 182s - loss: 0.0093 - acc: 0.9981 - val_loss: 0.0122 - val_acc: 0.9972
# Epoch 45/400
#  - 183s - loss: 0.0086 - acc: 0.9982 - val_loss: 0.0105 - val_acc: 0.9971
# Epoch 46/400
#  - 183s - loss: 0.0089 - acc: 0.9981 - val_loss: 0.0104 - val_acc: 0.9979
# Epoch 47/400
#  - 183s - loss: 0.0090 - acc: 0.9981 - val_loss: 0.0110 - val_acc: 0.9976
# Epoch 48/400
#  - 183s - loss: 0.0086 - acc: 0.9982 - val_loss: 0.0132 - val_acc: 0.9973
# Epoch 49/400
#  - 182s - loss: 0.0088 - acc: 0.9982 - val_loss: 0.0124 - val_acc: 0.9971
# Epoch 50/400
#  - 182s - loss: 0.0090 - acc: 0.9981 - val_loss: 0.0114 - val_acc: 0.9974
# Epoch 51/400
#  - 181s - loss: 0.0083 - acc: 0.9983 - val_loss: 0.0099 - val_acc: 0.9980
# Epoch 52/400
#  - 181s - loss: 0.0092 - acc: 0.9981 - val_loss: 0.0218 - val_acc: 0.9968
# Epoch 53/400
#  - 182s - loss: 0.0087 - acc: 0.9982 - val_loss: 0.0111 - val_acc: 0.9974
# Epoch 54/400
#  - 182s - loss: 0.0087 - acc: 0.9982 - val_loss: 0.0110 - val_acc: 0.9977
# Epoch 55/400
#  - 180s - loss: 0.0090 - acc: 0.9982 - val_loss: 0.0105 - val_acc: 0.9975
# Epoch 56/400
#  - 182s - loss: 0.0086 - acc: 0.9982 - val_loss: 0.0118 - val_acc: 0.9955
# Epoch 57/400
#  - 182s - loss: 0.0082 - acc: 0.9983 - val_loss: 0.0094 - val_acc: 0.9980
# Epoch 58/400
#  - 181s - loss: 0.0085 - acc: 0.9983 - val_loss: 0.0116 - val_acc: 0.9972
# Epoch 59/400
#  - 182s - loss: 0.0082 - acc: 0.9984 - val_loss: 0.0108 - val_acc: 0.9973
# Epoch 60/400
#  - 181s - loss: 0.0085 - acc: 0.9983 - val_loss: 0.0090 - val_acc: 0.9981
# Epoch 61/400
#  - 182s - loss: 0.0088 - acc: 0.9982 - val_loss: 0.0148 - val_acc: 0.9971
# Epoch 62/400
#  - 183s - loss: 0.0090 - acc: 0.9982 - val_loss: 0.0109 - val_acc: 0.9972
# Epoch 63/400
#  - 183s - loss: 0.0088 - acc: 0.9982 - val_loss: 0.0110 - val_acc: 0.9970
# Epoch 64/400
#  - 182s - loss: 0.0086 - acc: 0.9982 - val_loss: 0.0101 - val_acc: 0.9975
# Epoch 65/400
#  - 183s - loss: 0.0085 - acc: 0.9983 - val_loss: 0.0096 - val_acc: 0.9981
# Epoch 66/400
#  - 182s - loss: 0.0080 - acc: 0.9984 - val_loss: 0.0090 - val_acc: 0.9982
# Epoch 67/400
#  - 183s - loss: 0.0081 - acc: 0.9984 - val_loss: 0.0107 - val_acc: 0.9977
# Epoch 68/400
#  - 183s - loss: 0.0081 - acc: 0.9984 - val_loss: 0.0100 - val_acc: 0.9978
# Epoch 69/400
#  - 183s - loss: 0.0081 - acc: 0.9984 - val_loss: 0.0199 - val_acc: 0.9968
# Epoch 70/400
#  - 182s - loss: 0.0080 - acc: 0.9984 - val_loss: 0.0090 - val_acc: 0.9982
# Epoch 71/400
#  - 183s - loss: 0.0081 - acc: 0.9984 - val_loss: 0.0153 - val_acc: 0.9972
# Epoch 72/400
#  - 183s - loss: 0.0078 - acc: 0.9985 - val_loss: 0.0091 - val_acc: 0.9980
# Epoch 73/400
#  - 183s - loss: 0.0078 - acc: 0.9984 - val_loss: 0.0091 - val_acc: 0.9981
# Epoch 74/400
#  - 184s - loss: 0.0078 - acc: 0.9985 - val_loss: 0.0097 - val_acc: 0.9980
# Epoch 75/400
#  - 183s - loss: 0.0081 - acc: 0.9984 - val_loss: 0.0103 - val_acc: 0.9978
# Epoch 76/400
#  - 182s - loss: 0.0079 - acc: 0.9985 - val_loss: 0.0104 - val_acc: 0.9979
# Epoch 77/400
#  - 183s - loss: 0.0089 - acc: 0.9982 - val_loss: 0.0119 - val_acc: 0.9955
# Epoch 78/400
#  - 183s - loss: 0.0081 - acc: 0.9984 - val_loss: 0.0183 - val_acc: 0.9960
# Epoch 79/400
#  - 182s - loss: 0.0084 - acc: 0.9983 - val_loss: 0.0084 - val_acc: 0.9981
# Epoch 80/400
#  - 181s - loss: 0.0075 - acc: 0.9986 - val_loss: 0.0199 - val_acc: 0.9971
# Epoch 81/400
#  - 182s - loss: 0.0082 - acc: 0.9984 - val_loss: 0.0117 - val_acc: 0.9976
# Epoch 82/400
#  - 182s - loss: 0.0077 - acc: 0.9985 - val_loss: 0.0222 - val_acc: 0.9965
# Epoch 83/400
#  - 182s - loss: 0.0079 - acc: 0.9984 - val_loss: 0.0090 - val_acc: 0.9980
# Epoch 84/400
#  - 182s - loss: 0.0078 - acc: 0.9985 - val_loss: 0.0174 - val_acc: 0.9971
# Epoch 85/400
#  - 183s - loss: 0.0082 - acc: 0.9984 - val_loss: 0.0105 - val_acc: 0.9978
# Epoch 86/400
#  - 183s - loss: 0.0078 - acc: 0.9985 - val_loss: 0.0124 - val_acc: 0.9955
# Epoch 87/400
- loss: 0.0068 - acc: 0.9987 - val_loss: 0.0085 - val_acc: 0.9982
# Epoch 174/400
#  - 181s - loss: 0.0067 - acc: 0.9988 - val_loss: 0.0079 - val_acc: 0.9983
# Epoch 175/400
#  - 181s - loss: 0.0067 - acc: 0.9987 - val_loss: 0.0083 - val_acc: 0.9982
# Epoch 176/400
#  - 182s - loss: 0.0069 - acc: 0.9987 - val_loss: 0.0085 - val_acc: 0.9982
# Epoch 177/400
#  - 182s - loss: 0.0069 - acc: 0.9987 - val_loss: 0.0088 - val_acc: 0.9978
# Epoch 178/400
#  - 182s - loss: 0.0069 - acc: 0.9987 - val_loss: 0.0089 - val_acc: 0.9981
# Epoch 179/400
#  - 182s - loss: 0.0066 - acc: 0.9988 - val_loss: 0.0083 - val_acc: 0.9982
# Epoch 180/400
#  - 181s - loss: 0.0067 - acc: 0.9987 - val_loss: 0.0093 - val_acc: 0.9982
# Epoch 181/400
#  - 181s - loss: 0.0063 - acc: 0.9988 - val_loss: 0.0102 - val_acc: 0.9978
# Epoch 182/400
#  - 180s - loss: 0.0062 - acc: 0.9988 - val_loss: 0.0086 - val_acc: 0.9982
# Epoch 183/400
#  - 180s - loss: 0.0068 - acc: 0.9987 - val_loss: 0.0113 - val_acc: 0.9975
# Epoch 184/400
#  - 182s - loss: 0.0067 - acc: 0.9988 - val_loss: 0.0092 - val_acc: 0.9982
# Epoch 185/400
#  - 182s - loss: 0.0066 - acc: 0.9988 - val_loss: 0.0103 - val_acc: 0.9979
# Epoch 186/400
#  - 181s - loss: 0.0066 - acc: 0.9988 - val_loss: 0.0090 - val_acc: 0.9983
# Epoch 187/400
#  - 182s - loss: 0.0068 - acc: 0.9987 - val_loss: 0.0089 - val_acc: 0.9982
# Epoch 188/400
#  - 181s - loss: 0.0063 - acc: 0.9988 - val_loss: 0.0089 - val_acc: 0.9982
# Epoch 189/400
#  - 182s - loss: 0.0065 - acc: 0.9988 - val_loss: 0.0090 - val_acc: 0.9983
# Epoch 190/400
#  - 182s - loss: 0.0065 - acc: 0.9988 - val_loss: 0.0105 - val_acc: 0.9980
# Epoch 191/400
#  - 181s - loss: 0.0070 - acc: 0.9987 - val_loss: 0.0095 - val_acc: 0.9983
# Epoch 192/400
#  - 181s - loss: 0.0063 - acc: 0.9988 - val_loss: 0.0091 - val_acc: 0.9980
# Epoch 193/400
#  - 182s - loss: 0.0063 - acc: 0.9988 - val_loss: 0.0093 - val_acc: 0.9983
# Epoch 194/400
#  - 182s - loss: 0.0065 - acc: 0.9988 - val_loss: 0.0092 - val_acc: 0.9982
# Epoch 195/400
#  - 182s - loss: 0.0061 - acc: 0.9989 - val_loss: 0.0097 - val_acc: 0.9978
# Epoch 196/400
#  - 181s - loss: 0.0059 - acc: 0.9989 - val_loss: 0.0655 - val_acc: 0.9856
# Epoch 197/400
#  - 181s - loss: 0.0059 - acc: 0.9989 - val_loss: 0.0081 - val_acc: 0.9983
# Epoch 198/400
#  - 182s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0077 - val_acc: 0.9983
# Epoch 199/400
#  - 182s - loss: 0.0059 - acc: 0.9989 - val_loss: 0.0084 - val_acc: 0.9983
# Epoch 200/400
#  - 182s - loss: 0.0065 - acc: 0.9987 - val_loss: 0.0093 - val_acc: 0.9983
# Epoch 201/400
#  - 182s - loss: 0.0060 - acc: 0.9989 - val_loss: 0.0088 - val_acc: 0.9983
# Epoch 202/400
#  - 182s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0094 - val_acc: 0.9983
# Epoch 203/400
#  - 183s - loss: 0.0066 - acc: 0.9988 - val_loss: 0.0104 - val_acc: 0.9980
# Epoch 204/400
#  - 183s - loss: 0.0064 - acc: 0.9988 - val_loss: 0.0081 - val_acc: 0.9983
# Epoch 205/400
#  - 182s - loss: 0.0066 - acc: 0.9987 - val_loss: 0.0083 - val_acc: 0.9981
# Epoch 206/400
#  - 181s - loss: 0.0061 - acc: 0.9988 - val_loss: 0.0083 - val_acc: 0.9984
# Epoch 207/400
#  - 182s - loss: 0.0067 - acc: 0.9987 - val_loss: 0.0097 - val_acc: 0.9982
# Epoch 208/400
#  - 182s - loss: 0.0062 - acc: 0.9988 - val_loss: 0.0081 - val_acc: 0.9983
# Epoch 209/400
#  - 183s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0080 - val_acc: 0.9982
# Epoch 210/400
#  - 183s - loss: 0.0059 - acc: 0.9989 - val_loss: 0.0086 - val_acc: 0.9983
# Epoch 211/400
#  - 182s - loss: 0.0064 - acc: 0.9988 - val_loss: 0.0100 - val_acc: 0.9981
# Epoch 212/400
#  - 183s - loss: 0.0065 - acc: 0.9988 - val_loss: 0.0085 - val_acc: 0.9983
# Epoch 213/400
#  - 184s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0085 - val_acc: 0.9982
# Epoch 214/400
#  - 183s - loss: 0.0059 - acc: 0.9989 - val_loss: 0.0077 - val_acc: 0.9983
# Epoch 215/400
#  - 184s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0097 - val_acc: 0.9982
# Epoch 216/400
#  - 183s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0092 - val_acc: 0.9979
# Epoch 217/400
#  - 183s - loss: 0.0061 - acc: 0.9988 - val_loss: 0.0085 - val_acc: 0.9982
# Epoch 218/400
#  - 183s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0080 - val_acc: 0.9983
# Epoch 219/400
#  - 183s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0093 - val_acc: 0.9982
# Epoch 220/400
#  - 183s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0083 - val_acc: 0.9983
# Epoch 221/400
#  - 184s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0079 - val_acc: 0.9983
# Epoch 222/400
#  - 184s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0081 - val_acc: 0.9984
# Epoch 223/400
#  - 183s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0086 - val_acc: 0.9982
# Epoch 224/400
#  - 183s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0089 - val_acc: 0.9981
# Epoch 225/400
#  - 184s - loss: 0.0062 - acc: 0.9988 - val_loss: 0.0117 - val_acc: 0.9973
# Epoch 226/400
#  - 183s - loss: 0.0068 - acc: 0.9987 - val_loss: 0.0256 - val_acc: 0.9971
# Epoch 227/400
#  - 182s - loss: 0.0069 - acc: 0.9987 - val_loss: 0.0093 - val_acc: 0.9983
# Epoch 228/400
#  - 183s - loss: 0.0063 - acc: 0.9989 - val_loss: 0.0080 - val_acc: 0.9983
# Epoch 229/400
#  - 183s - loss: 0.0059 - acc: 0.9989 - val_loss: 0.0086 - val_acc: 0.9982
# Epoch 230/400
#  - 183s - loss: 0.0059 - acc: 0.9989 - val_loss: 0.0079 - val_acc: 0.9983
# Epoch 231/400
#  - 184s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0082 - val_acc: 0.9982
# Epoch 232/400
#  - 184s - loss: 0.0061 - acc: 0.9988 - val_loss: 0.0087 - val_acc: 0.9981
# Epoch 233/400
#  - 184s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0121 - val_acc: 0.9975
# Epoch 234/400
#  - 184s - loss: 0.0062 - acc: 0.9988 - val_loss: 0.0083 - val_acc: 0.9982
# Epoch 235/400
#  - 184s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0103 - val_acc: 0.9974
# Epoch 236/400
#  - 182s - loss: 0.0067 - acc: 0.9987 - val_loss: 0.0093 - val_acc: 0.9983
# Epoch 237/400
#  - 183s - loss: 0.0068 - acc: 0.9987 - val_loss: 0.0093 - val_acc: 0.9981
# Epoch 238/400
#  - 183s - loss: 0.0073 - acc: 0.9986 - val_loss: 0.0104 - val_acc: 0.9981
# Epoch 239/400
#  - 183s - loss: 0.0064 - acc: 0.9988 - val_loss: 0.0081 - val_acc: 0.9983
# Epoch 240/400
#  - 184s - loss: 0.0065 - acc: 0.9988 - val_loss: 0.0123 - val_acc: 0.9975
# Epoch 241/400
#  - 183s - loss: 0.0063 - acc: 0.9988 - val_loss: 0.0254 - val_acc: 0.9970
# Epoch 242/400
#  - 184s - loss: 0.0063 - acc: 0.9988 - val_loss: 0.0088 - val_acc: 0.9979
# Epoch 243/400
#  - 184s - loss: 0.0059 - acc: 0.9989 - val_loss: 0.0081 - val_acc: 0.9983
# Epoch 244/400
#  - 183s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0085 - val_acc: 0.9984
# Epoch 245/400
#  - 184s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0100 - val_acc: 0.9977
# Epoch 246/400
#  - 183s - loss: 0.0066 - acc: 0.9988 - val_loss: 0.0095 - val_acc: 0.9978
# Epoch 247/400
#  - 184s - loss: 0.0063 - acc: 0.9988 - val_loss: 0.0082 - val_acc: 0.9982
# Epoch 248/400
#  - 184s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0089 - val_acc: 0.9979
# Epoch 249/400
#  - 183s - loss: 0.0064 - acc: 0.9988 - val_loss: 0.0100 - val_acc: 0.9978
# Epoch 250/400
#  - 182s - loss: 0.0061 - acc: 0.9989 - val_loss: 0.0114 - val_acc: 0.9977
# Epoch 251/400
#  - 183s - loss: 0.0065 - acc: 0.9988 - val_loss: 0.0079 - val_acc: 0.9983
# Epoch 252/400
#  - 184s - loss: 0.0065 - acc: 0.9988 - val_loss: 0.0082 - val_acc: 0.9982
# Epoch 253/400
#  - 184s - loss: 0.0060 - acc: 0.9989 - val_loss: 0.0111 - val_acc: 0.9977
# Epoch 254/400
#  - 185s - loss: 0.0059 - acc: 0.9989 - val_loss: 0.0086 - val_acc: 0.9981
# Epoch 255/400
#  - 184s - loss: 0.0062 - acc: 0.9988 - val_loss: 0.0084 - val_acc: 0.9982
# Epoch 256/400
#  - 185s - loss: 0.0071 - acc: 0.9986 - val_loss: 0.0088 - val_acc: 0.9977
# Epoch 257/400
#  - 184s - loss: 0.0071 - acc: 0.9986 - val_loss: 0.0088 - val_acc: 0.9982
# Epoch 258/400
#  - 184s - loss: 0.0066 - acc: 0.9988 - val_loss: 0.0081 - val_acc: 0.9983
# Epoch 259/400
#  - 183s - loss: 0.0062 - acc: 0.9989 - val_loss: 0.0082 - val_acc: 0.9983
# Epoch 260/400
#  - 184s - loss: 0.0064 - acc: 0.9988 - val_loss: 0.0094 - val_acc: 0.9978
# Epoch 261/400
#  - 185s - loss: 0.0061 - acc: 0.9988 - val_loss: 0.0085 - val_acc: 0.9983
# Epoch 262/400
#  - 185s - loss: 0.0068 - acc: 0.9987 - val_loss: 0.0088 - val_acc: 0.9983
# Epoch 263/400
#  - 184s - loss: 0.0067 - acc: 0.9988 - val_loss: 0.0093 - val_acc: 0.9983
# Epoch 264/400
#  - 184s - loss: 0.0065 - acc: 0.9988 - val_loss: 0.0094 - val_acc: 0.9983
# Epoch 265/400
#  - 183s - loss: 0.0069 - acc: 0.9987 - val_loss: 0.0118 - val_acc: 0.9958
# Epoch 266/400
#  - 184s - loss: 0.0071 - acc: 0.9986 - val_loss: 0.0088 - val_acc: 0.9981
# Epoch 267/400
#  - 185s - loss: 0.0073 - acc: 0.9986 - val_loss: 0.0180 - val_acc: 0.9976
# Epoch 268/400
#  - 185s - loss: 0.0071 - acc: 0.9986 - val_loss: 0.0101 - val_acc: 0.9976
# Epoch 269/400
#  - 185s - loss: 0.0075 - acc: 0.9985 - val_loss: 0.0088 - val_acc: 0.9981
# Epoch 270/400
#  - 183s - loss: 0.0073 - acc: 0.9986 - val_loss: 0.0115 - val_acc: 0.9957
# Epoch 271/400
#  - 184s - loss: 0.0072 - acc: 0.9986 - val_loss: 0.0217 - val_acc: 0.9975
# Epoch 272/400
#  - 184s - loss: 0.0065 - acc: 0.9988 - val_loss: 0.0099 - val_acc: 0.9977
# Epoch 273/400
#  - 184s - loss: 0.0067 - acc: 0.9988 - val_loss: 0.0148 - val_acc: 0.9975
# Epoch 274/400
#  - 185s - loss: 0.0065 - acc: 0.9988 - val_loss: 0.0227 - val_acc: 0.9970
# Epoch 275/400
#  - 183s - loss: 0.0066 - acc: 0.9987 - val_loss: 0.0165 - val_acc: 0.9952
# Epoch 276/400
#  - 184s - loss: 0.0071 - acc: 0.9986 - val_loss: 0.0109 - val_acc: 0.9974
# Epoch 277/400
#  - 185s - loss: 0.0069 - acc: 0.9987 - val_loss: 0.0120 - val_acc: 0.9959
# Epoch 278/400
#  - 184s - loss: 0.0068 - acc: 0.9987 - val_loss: 0.0102 - val_acc: 0.9983
# Epoch 279/400
#  - 184s - loss: 0.0070 - acc: 0.9987 - val_loss: 0.0091 - val_acc: 0.9983
# Epoch 280/400
#  - 185s - loss: 0.0066 - acc: 0.9988 - val_loss: 0.0100 - val_acc: 0.9982
# Epoch 281/400
#  - 184s - loss: 0.0065 - acc: 0.9988 - val_loss: 0.0132 - val_acc: 0.9959
# Epoch 282/400
#  - 184s - loss: 0.0068 - acc: 0.9987 - val_loss: 0.0081 - val_acc: 0.9982
# Epoch 283/400
#  - 183s - loss: 0.0068 - acc: 0.9987 - val_loss: 0.0102 - val_acc: 0.9983
# Epoch 284/400
#  - 183s - loss: 0.0067 - acc: 0.9988 - val_loss: 0.0107 - val_acc: 0.9983
# Epoch 285/400
#  - 184s - loss: 0.0063 - acc: 0.9988 - val_loss: 0.0091 - val_acc: 0.9983
# Epoch 286/400
#  - 185s - loss: 0.0066 - acc: 0.9988 - val_loss: 0.0095 - val_acc: 0.9978
# Epoch 287/400
#  - 184s - loss: 0.0062 - acc: 0.9988 - val_loss: 0.0088 - val_acc: 0.9983
# Epoch 288/400
#  - 185s - loss: 0.0061 - acc: 0.9988 - val_loss: 0.0092 - val_acc: 0.9982
# Epoch 289/400
#  - 184s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0086 - val_acc: 0.9983
# Epoch 290/400
#  - 184s - loss: 0.0062 - acc: 0.9988 - val_loss: 0.0105 - val_acc: 0.9981
# Epoch 291/400
#  - 185s - loss: 0.0065 - acc: 0.9988 - val_loss: 0.0144 - val_acc: 0.9956
# Epoch 292/400
#  - 186s - loss: 0.0065 - acc: 0.9988 - val_loss: 0.0088 - val_acc: 0.9983
# Epoch 293/400
#  - 185s - loss: 0.0066 - acc: 0.9988 - val_loss: 0.0097 - val_acc: 0.9983
# Epoch 294/400
#  - 185s - loss: 0.0070 - acc: 0.9987 - val_loss: 0.0091 - val_acc: 0.9978
# Epoch 295/400
#  - 185s - loss: 0.0066 - acc: 0.9988 - val_loss: 0.0094 - val_acc: 0.9982
# Epoch 296/400
#  - 184s - loss: 0.0068 - acc: 0.9987 - val_loss: 0.0082 - val_acc: 0.9983
# Epoch 297/400
#  - 185s - loss: 0.0063 - acc: 0.9988 - val_loss: 0.0087 - val_acc: 0.9984
# Epoch 298/400
#  - 185s - loss: 0.0068 - acc: 0.9987 - val_loss: 0.0096 - val_acc: 0.9983
# Epoch 299/400
#  - 185s - loss: 0.0063 - acc: 0.9989 - val_loss: 0.0093 - val_acc: 0.9982
# Epoch 300/400
#  - 185s - loss: 0.0061 - acc: 0.9989 - val_loss: 0.0093 - val_acc: 0.9983
# Epoch 301/400
#  - 185s - loss: 0.0059 - acc: 0.9989 - val_loss: 0.0091 - val_acc: 0.9983
# Epoch 302/400
#  - 185s - loss: 0.0063 - acc: 0.9989 - val_loss: 0.0101 - val_acc: 0.9984
# Epoch 303/400
#  - 185s - loss: 0.0059 - acc: 0.9989 - val_loss: 0.0079 - val_acc: 0.9983
# Epoch 304/400
#  - 185s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0090 - val_acc: 0.9984
# Epoch 305/400
#  - 185s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0082 - val_acc: 0.9983
# Epoch 306/400
#  - 185s - loss: 0.0064 - acc: 0.9988 - val_loss: 0.0086 - val_acc: 0.9984
# Epoch 307/400
#  - 183s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0076 - val_acc: 0.9984
# Epoch 308/400
#  - 183s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0109 - val_acc: 0.9982
# Epoch 309/400
#  - 184s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0086 - val_acc: 0.9984
# Epoch 310/400
#  - 185s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0112 - val_acc: 0.9977
# Epoch 311/400
#  - 184s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0085 - val_acc: 0.9982
# Epoch 312/400
#  - 184s - loss: 0.0062 - acc: 0.9988 - val_loss: 0.0091 - val_acc: 0.9982
# Epoch 313/400
#  - 184s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0086 - val_acc: 0.9983
# Epoch 314/400
#  - 183s - loss: 0.0064 - acc: 0.9988 - val_loss: 0.0085 - val_acc: 0.9983
# Epoch 315/400
#  - 182s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0075 - val_acc: 0.9984
# Epoch 316/400
#  - 183s - loss: 0.0067 - acc: 0.9988 - val_loss: 0.0074 - val_acc: 0.9983
# Epoch 317/400
#  - 185s - loss: 0.0061 - acc: 0.9989 - val_loss: 0.0083 - val_acc: 0.9983
# Epoch 318/400
#  - 184s - loss: 0.0059 - acc: 0.9989 - val_loss: 0.0074 - val_acc: 0.9984
# Epoch 319/400
#  - 184s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0075 - val_acc: 0.9984
# Epoch 320/400
#  - 183s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0101 - val_acc: 0.9978
# Epoch 321/400
#  - 186s - loss: 0.0067 - acc: 0.9988 - val_loss: 0.0146 - val_acc: 0.9957
# Epoch 322/400
#  - 185s - loss: 0.0068 - acc: 0.9987 - val_loss: 0.0105 - val_acc: 0.9978
# Epoch 323/400
#  - 184s - loss: 0.0062 - acc: 0.9989 - val_loss: 0.0139 - val_acc: 0.9974
# Epoch 324/400
#  - 188s - loss: 0.0063 - acc: 0.9989 - val_loss: 0.0085 - val_acc: 0.9983
# Epoch 325/400
#  - 189s - loss: 0.0059 - acc: 0.9989 - val_loss: 0.0084 - val_acc: 0.9983
# Epoch 326/400
#  - 186s - loss: 0.0062 - acc: 0.9988 - val_loss: 0.0220 - val_acc: 0.9944
# Epoch 327/400
#  - 183s - loss: 0.0059 - acc: 0.9989 - val_loss: 0.0087 - val_acc: 0.9982
# Epoch 328/400
#  - 183s - loss: 0.0061 - acc: 0.9988 - val_loss: 0.0087 - val_acc: 0.9982
# Epoch 329/400
#  - 184s - loss: 0.0061 - acc: 0.9989 - val_loss: 0.0082 - val_acc: 0.9983
# Epoch 330/400
#  - 184s - loss: 0.0063 - acc: 0.9988 - val_loss: 0.0098 - val_acc: 0.9963
# Epoch 331/400
#  - 186s - loss: 0.0061 - acc: 0.9989 - val_loss: 0.0085 - val_acc: 0.9983
# Epoch 332/400
#  - 184s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0080 - val_acc: 0.9983
# Epoch 333/400
#  - 183s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0081 - val_acc: 0.9984
# Epoch 334/400
#  - 184s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0083 - val_acc: 0.9982
# Epoch 335/400
#  - 184s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0081 - val_acc: 0.9983
# Epoch 336/400
#  - 185s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0083 - val_acc: 0.9983
# Epoch 337/400
#  - 186s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0085 - val_acc: 0.9982
# Epoch 338/400
#  - 184s - loss: 0.0055 - acc: 0.9990 - val_loss: 0.0359 - val_acc: 0.9955
# Epoch 339/400
#  - 184s - loss: 0.0055 - acc: 0.9990 - val_loss: 0.0079 - val_acc: 0.9983
# Epoch 340/400
#  - 185s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0080 - val_acc: 0.9983
# Epoch 341/400
#  - 185s - loss: 0.0055 - acc: 0.9990 - val_loss: 0.0082 - val_acc: 0.9984
# Epoch 342/400
#  - 183s - loss: 0.0055 - acc: 0.9990 - val_loss: 0.0092 - val_acc: 0.9982
# Epoch 343/400
#  - 183s - loss: 0.0055 - acc: 0.9990 - val_loss: 0.0081 - val_acc: 0.9983
# Epoch 344/400
#  - 183s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0080 - val_acc: 0.9983
# Epoch 345/400
#  - 186s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0082 - val_acc: 0.9983
# Epoch 346/400
#  - 187s - loss: 0.0055 - acc: 0.9990 - val_loss: 0.0080 - val_acc: 0.9984
# Epoch 347/400
#  - 187s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0117 - val_acc: 0.9959
# Epoch 348/400
#  - 188s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0085 - val_acc: 0.9983
# Epoch 349/400
#  - 187s - loss: 0.0068 - acc: 0.9987 - val_loss: 0.0089 - val_acc: 0.9983
# Epoch 350/400
#  - 190s - loss: 0.0065 - acc: 0.9988 - val_loss: 0.0090 - val_acc: 0.9983
# Epoch 351/400
#  - 185s - loss: 0.0065 - acc: 0.9988 - val_loss: 0.0086 - val_acc: 0.9983
# Epoch 352/400
#  - 187s - loss: 0.0061 - acc: 0.9989 - val_loss: 0.0135 - val_acc: 0.9959
# Epoch 353/400
#  - 188s - loss: 0.0059 - acc: 0.9989 - val_loss: 0.0078 - val_acc: 0.9984
# Epoch 354/400
#  - 189s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0130 - val_acc: 0.9960
# Epoch 355/400
#  - 183s - loss: 0.0060 - acc: 0.9989 - val_loss: 0.0104 - val_acc: 0.9959
# Epoch 356/400
#  - 188s - loss: 0.0060 - acc: 0.9989 - val_loss: 0.0115 - val_acc: 0.9960
# Epoch 357/400
#  - 185s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0134 - val_acc: 0.9957
# Epoch 358/400
#  - 182s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0082 - val_acc: 0.9983
# Epoch 359/400
#  - 184s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0178 - val_acc: 0.9958
# Epoch 360/400
#  - 183s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0095 - val_acc: 0.9977
# Epoch 361/400
#  - 183s - loss: 0.0060 - acc: 0.9989 - val_loss: 0.0120 - val_acc: 0.9959
# Epoch 362/400
#  - 189s - loss: 0.0059 - acc: 0.9989 - val_loss: 0.0087 - val_acc: 0.9983
# Epoch 363/400
#  - 187s - loss: 0.0059 - acc: 0.9989 - val_loss: 0.0090 - val_acc: 0.9983
# Epoch 364/400
#  - 185s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0096 - val_acc: 0.9977
# Epoch 365/400
#  - 187s - loss: 0.0063 - acc: 0.9989 - val_loss: 0.0093 - val_acc: 0.9982
# Epoch 366/400
#  - 184s - loss: 0.0066 - acc: 0.9988 - val_loss: 0.0090 - val_acc: 0.9983
# Epoch 367/400
#  - 184s - loss: 0.0063 - acc: 0.9989 - val_loss: 0.0077 - val_acc: 0.9985
# Epoch 368/400
#  - 185s - loss: 0.0059 - acc: 0.9989 - val_loss: 0.0093 - val_acc: 0.9983
# Epoch 369/400
#  - 183s - loss: 0.0068 - acc: 0.9987 - val_loss: 0.0124 - val_acc: 0.9976
# Epoch 370/400
#  - 184s - loss: 0.0065 - acc: 0.9988 - val_loss: 0.0093 - val_acc: 0.9983
# Epoch 371/400
#  - 185s - loss: 0.0069 - acc: 0.9988 - val_loss: 0.0106 - val_acc: 0.9974
# Epoch 372/400
#  - 185s - loss: 0.0060 - acc: 0.9989 - val_loss: 0.0089 - val_acc: 0.9983
# Epoch 373/400
#  - 184s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0112 - val_acc: 0.9976
# Epoch 374/400
#  - 184s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0079 - val_acc: 0.9984
# Epoch 375/400
#  - 184s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0208 - val_acc: 0.9960
# Epoch 376/400
#  - 185s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0096 - val_acc: 0.9982
# Epoch 377/400
#  - 185s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0116 - val_acc: 0.9959
# Epoch 378/400
#  - 185s - loss: 0.0055 - acc: 0.9990 - val_loss: 0.0091 - val_acc: 0.9982
# Epoch 379/400
#  - 184s - loss: 0.0055 - acc: 0.9990 - val_loss: 0.0089 - val_acc: 0.9984
# Epoch 380/400
#  - 183s - loss: 0.0055 - acc: 0.9990 - val_loss: 0.0082 - val_acc: 0.9983
# Epoch 381/400
#  - 184s - loss: 0.0056 - acc: 0.9990 - val_loss: 0.0084 - val_acc: 0.9983
# Epoch 382/400
#  - 183s - loss: 0.0055 - acc: 0.9990 - val_loss: 0.0080 - val_acc: 0.9983
# Epoch 383/400
#  - 183s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0133 - val_acc: 0.9959
# Epoch 384/400
#  - 184s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0087 - val_acc: 0.9983
# Epoch 385/400
#  - 184s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0082 - val_acc: 0.9984
# Epoch 386/400
#  - 184s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0081 - val_acc: 0.9983
# Epoch 387/400
#  - 184s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0079 - val_acc: 0.9984
# Epoch 388/400
#  - 183s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0081 - val_acc: 0.9984
# Epoch 389/400
#  - 183s - loss: 0.0055 - acc: 0.9990 - val_loss: 0.0079 - val_acc: 0.9985
# Epoch 390/400
#  - 183s - loss: 0.0059 - acc: 0.9989 - val_loss: 0.0114 - val_acc: 0.9958
# Epoch 391/400
#  - 185s - loss: 0.0068 - acc: 0.9987 - val_loss: 0.0086 - val_acc: 0.9983
# Epoch 392/400
#  - 185s - loss: 0.0070 - acc: 0.9987 - val_loss: 0.0291 - val_acc: 0.9916
# Epoch 393/400
#  - 184s - loss: 0.0064 - acc: 0.9988 - val_loss: 0.0088 - val_acc: 0.9979
# Epoch 394/400
#  - 183s - loss: 0.0060 - acc: 0.9989 - val_loss: 0.0088 - val_acc: 0.9984
# Epoch 395/400
#  - 182s - loss: 0.0065 - acc: 0.9988 - val_loss: 0.0090 - val_acc: 0.9984
# Epoch 396/400
#  - 183s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0084 - val_acc: 0.9984
# Epoch 397/400
#  - 183s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0079 - val_acc: 0.9983
# Epoch 398/400
#  - 184s - loss: 0.0056 - acc: 0.9990 - val_loss: 0.0081 - val_acc: 0.9983
# Epoch 399/400
#  - 184s - loss: 0.0055 - acc: 0.9990 - val_loss: 0.0071 - val_acc: 0.9984
# Epoch 400/400
#  - 183s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0084 - val_acc: 0.9984
# Wall time: 20h 21min 19s

# %%
y_train.shape
# Out:
# (2547668, 10)

# %% [markdown]
# # Graph the losses

# %%
def most_recent_file(pattern):
    return max(glob.iglob(pattern, recursive=True), key=os.path.getctime)

logpath = most_recent_file(NOTEBOOK_PATH + "Loss Logs/%s**" % model_id)
log_df = pd.read_csv(logpath)
log_df['epoch'] += 1

print(logpath)
# Out:
# C:/Users/Xetrov/Desktop/SciFair20/Code/Loss Logs\cnn7-autoencodershape (11-07-2019, 1023PM)

# %%
plot_df = log_df[:]

metric = 'loss'

plt.figure(figsize=(12,6))
sns.lineplot(x='epoch', y=metric, data=plot_df, label=metric)
sns.lineplot(x='epoch', y='val_'+metric, data=plot_df, label='val_'+metric)
plt.legend()

minEpoch = plot_df.loc[plot_df.idxmin()[metric]]
plt.plot((minEpoch['epoch']), (minEpoch[metric]), 'go', markersize=8)
minEpoch = plot_df.loc[plot_df.idxmin()['val_'+metric]]
plt.plot((minEpoch['epoch']), (minEpoch['val_'+metric]), 'ro', markersize=8)
print(minEpoch)

plt.xticks(list(range(0, plot_df['epoch'].max()+1, 5)))
# plt.yticks(list(np.arange(0.0,0.4,0.05)))

plt.grid(True)
# Out:
# epoch       399.000000
# acc           0.998973
# loss          0.005533
# val_acc       0.998373
# val_loss      0.007081
# Name: 398, dtype: float64

# %% [markdown]
# # Validation data

# %%
print("Loading...")
model = keras.models.load_model(NOTEBOOK_PATH + "Models/%s/cnn(399).h5" % model_id)
print("Done!")
# Out:
# Loading...

# %%
print("Predicting...")
pred = model.predict(x_val)

print("Plotting...")
pred_index = list(pred.argmax(1))
y_index = list(np.argmax(y_val.to_numpy(), axis=1))

atktypes = sorted(y_val.columns)
pred_series = pd.Series(pred_index, name="Pred").replace(dict(enumerate(atktypes)))
y_series = pd.Series(y_index, name="Actual").replace(dict(enumerate(atktypes)))

matrix = pd.crosstab(pred_series, y_series, margins=True)
print("Done!")
matrix
# Out:
# Predicting...
# Plotting...
# Done!
# Actual    IsAttack     All
# Pred
# IsAttack    566149  566149
# All         566149  566149

# %% [markdown]
# # Test data

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

# %%
# model = keras.models.load_model(NOTEBOOK_PATH + "Models/%s/cnn(50).h5" % model_id)
pred = model.predict(x_test, batch_size=1000)

# %%
pred = pred.round().astype('int').ravel()
y_test_npy = y_test.to_numpy().ravel()

precision = precision_score(y_test_npy, pred)
print("Precision:", precision)

recall = recall_score(y_test_npy, pred)
print("Recall:", recall)

f1 = f1_score(y_test_npy, pred)
print("F1:", f1)
# Out:
# Precision: 0.991988379139486
# Recall: 0.9995869215779596
# F1: 0.9957731548367186

# %%
pred_series = pd.Series(pred, name="Pred").replace({0: 'Benign', 1: 'Attack'})
y_series = pd.Series(y_test.to_numpy().ravel(), name="Actual").replace({0: 'Benign', 1: 'Attack'})

matrix = pd.crosstab(pred_series, y_series, margins=True)
matrix
# Out:
# Actual  Attack  Benign     All
# Pred
# Attack  111313     899  112212
# Benign      46  453891  453937
# All     111359  454790  566149

# %% [markdown]
# # Log results

# %%
model_log = open(NOTEBOOK_PATH + "model_log.txt", "a")

model_log.write("\n" + model_id)
model_log.write("\n\tF1 Micro: " + str(f1_micro))
model_log.write("\n\tF1 Macro: " + str(f1_macro))

model_log.close()
