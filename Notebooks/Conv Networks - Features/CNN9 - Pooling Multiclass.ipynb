# %% [markdown]
# # CSE-CIC-IDS 2017

# %%
model_id = "cnn9-pooling-multiclass"

# %%
import numpy as np
np.random.seed(42)
np.set_printoptions(suppress=True)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

import glob, time, os

import keras
# Out:
# Using TensorFlow backend.
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
NOTEBOOK_PATH = "C:/Users/Xetrov/Desktop/SciFair20/Code/"

# %%
x_scaled = pd.read_csv(NOTEBOOK_PATH + "IDS2017/x_scaled_powertransform.csv")

# %%
y_df_enc = pd.read_csv(NOTEBOOK_PATH + "IDS2017/y_grouped_1henc.csv")

# %% [markdown]
# # Reshape into images

# %%
x_img = x_scaled.to_numpy().reshape((len(x_scaled), 4, 17))

# %%
x_img = np.expand_dims(x_img, -1)

# %% [markdown]
# # Split data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split

x_train, x_valtest, y_train, y_valtest = train_test_split(x_img, y_df_enc, test_size = 0.4, random_state = 42)

x_val, x_test, y_val, y_test = train_test_split(x_valtest, y_valtest, test_size = 0.5, random_state = 42)

del x_valtest 
del y_valtest

# %% [markdown]
# # Read ADASYN data

# %%
x_train_res = pd.read_csv(NOTEBOOK_PATH + "IDS2017/x_adasyn.csv").to_numpy()

# %%
y_train_res = pd.read_csv(NOTEBOOK_PATH + "IDS2017/y_adasyn.csv")

y_train_res2 = pd.get_dummies(y_train_res[y_train_res.columns[0]])

# %%
x_train_resimg = np.expand_dims(x_train_res.reshape((len(x_train_res), 4, 17)), -1)

# %% [markdown]
# # Train model

# %%
from keras.models import Model, Sequential
from keras.layers import Dense, BatchNormalization, Dropout, InputLayer, Conv2D, Flatten, MaxPooling2D
from keras.optimizers import SGD, Adam

# %%
def addDenseBlock(model, units, **params):
    model.add(Dense(units=units, activation=params['hidden_activation'], input_dim=x_train.shape[1]))
    if params['batch_normalization']: model.add(BatchNormalization())
    if params['dropout_rate'] > 0: model.add(Dropout(params['dropout_rate']))

def addConvBlock(model, units, **params):
    model.add(Conv2D(filters=units, kernel_size=params['kernel_size'], activation=params['hidden_activation'], padding=params['padding'],input_shape=(4,17,1)))
    if params['batch_normalization']: model.add(BatchNormalization())
    if params['dropout_rate'] > 0: model.add(Dropout(params['dropout_rate']))
        
def createModel(**in_params):
    """
    Supported parameters:
    batch_normalization - True or False
    dropout_rate - 0 to 1
    num_units - integer
    learning_rate - float
    activation_function - string
    """
    
    model = Sequential()

    # Set default values
    params = {
        'batch_normalization': False,
        'dropout_rate': 0,
        'learning_rate': 0.001,
        'hidden_activation': 'relu',
        'final_activation': 'softmax',
        'kernel_size': (2,2),
        'padding':'same'
    }
    
    # Replace defaults with specified parameters
    for param in in_params:
        params[param] = in_params[param]    
    
    # InputLayer causes serialization issues
#     model.add( InputLayer(input_shape = (x_train.shape[1],) ) )
    
#     for i in range(params['num_layers']):
#         addDenseBlock(model, params['num_units'], **params)

    addConvBlock(model, 256, **params)
    addConvBlock(model, 128, **params)
    model.add(MaxPooling2D())
    addConvBlock(model, 64, **params)
    addConvBlock(model, 32, **params)
    addConvBlock(model, 64, **params)
    model.add(MaxPooling2D())
    addConvBlock(model, 128, **params)
    addConvBlock(model, 256, **params)
    
    model.add(Flatten())

    model.add(Dense(units=y_train.shape[1], activation=params['final_activation']))

    # optim = SGD(lr=0.001, nesterov=True)
    optim = Adam(lr=params['learning_rate'])

    model.compile(loss='categorical_crossentropy', optimizer=optim, metrics=['accuracy'])
    
#     print(params)
    
    return model

# %% [markdown]
# Ensure a GPU is available

# %%
import keras.backend as K

K.tensorflow_backend._get_available_gpus()
# Out:
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %% [markdown]
# ### Callbacks

# %%
from keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint

def timestamp():
    return time.strftime("%m-%d-%Y, %I%M%p")

csv_callback = CSVLogger(NOTEBOOK_PATH + 'Loss Logs/%s (%s)' % (model_id, timestamp()), append=True)
early_stop = EarlyStopping(monitor = 'val_loss', min_delta=0.0001, patience=5)

# %% [markdown]
# ### Model Saving

# %%
savedir = NOTEBOOK_PATH + "Models/%s/" % model_id
if not os.path.exists(savedir):
    os.makedirs(savedir)
    print("Created " + savedir)
else:
    print("Using " + savedir)
# Out:
# Created C:/Users/Xetrov/Desktop/SciFair20/Code/Models/cnn9-pooling-multiclass/

# %% [markdown]
# ### Training

# %%
import itertools

trainEpochs = 200

parameters = {'batch_size': 1000, 'batch_normalization':True, 'dropout_rate':0}

# %%
# %%time
# print(model_id)
model = createModel(**parameters)
# model = keras.models.load_model(NOTEBOOK_PATH + "Models/cnn4-adasyn-run1/cnn(4).h5")
model.summary()
model_checkpoint = ModelCheckpoint(NOTEBOOK_PATH + "Models/%s/cnn({epoch}).h5" % (model_id), monitor='val_loss')
model.fit(x_train_resimg, y_train_res2, validation_data=(x_val, y_val), batch_size=parameters['batch_size'], epochs=trainEpochs, verbose=2, callbacks=[csv_callback, model_checkpoint])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 4, 17, 256)        1280
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 4, 17, 256)        1024
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 17, 128)        131200
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 4, 17, 128)        512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 8, 128)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 2, 8, 64)          32832
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 2, 8, 64)          256
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 2, 8, 32)          8224
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 2, 8, 32)          128
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 2, 8, 64)          8256
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 2, 8, 64)          256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 4, 64)          0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 1, 4, 128)         32896
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 1, 4, 128)         512
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 1, 4, 256)         131328
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 1, 4, 256)         1024
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 7175
# =================================================================
# Total params: 356,903
# Trainable params: 355,047
# Non-trainable params: 1,856
# _________________________________________________________________
# Train on 9549194 samples, validate on 566149 samples
# Epoch 1/200
#  - 381s - loss: 0.0386 - acc: 0.9881 - val_loss: 0.0863 - val_acc: 0.9784
# Epoch 2/200
#  - 382s - loss: 0.0229 - acc: 0.9930 - val_loss: 0.0334 - val_acc: 0.9925
# Epoch 3/200
#  - 382s - loss: 0.0185 - acc: 0.9942 - val_loss: 0.1001 - val_acc: 0.9873
# Epoch 4/200
#  - 382s - loss: 0.0170 - acc: 0.9947 - val_loss: 0.1984 - val_acc: 0.9815
# Epoch 5/200
#  - 381s - loss: 0.0146 - acc: 0.9954 - val_loss: 0.0219 - val_acc: 0.9955
# Epoch 6/200
#  - 382s - loss: 0.0130 - acc: 0.9958 - val_loss: 0.0300 - val_acc: 0.9936
# Epoch 7/200
#  - 382s - loss: 0.0123 - acc: 0.9961 - val_loss: 0.0191 - val_acc: 0.9959
# Epoch 8/200
#  - 382s - loss: 0.0122 - acc: 0.9963 - val_loss: 0.0353 - val_acc: 0.9942
# Epoch 9/200
loss: 0.0062 - acc: 0.9981 - val_loss: 0.0170 - val_acc: 0.9969
# Epoch 67/200
#  - 381s - loss: 0.0058 - acc: 0.9983 - val_loss: 0.0138 - val_acc: 0.9975
# Epoch 68/200
#  - 381s - loss: 0.0055 - acc: 0.9984 - val_loss: 0.0153 - val_acc: 0.9977
# Epoch 69/200
#  - 381s - loss: 0.0052 - acc: 0.9985 - val_loss: 0.0163 - val_acc: 0.9970
# Epoch 70/200
#  - 381s - loss: 0.0049 - acc: 0.9986 - val_loss: 0.0110 - val_acc: 0.9978
# Epoch 71/200
#  - 382s - loss: 0.0050 - acc: 0.9986 - val_loss: 0.0158 - val_acc: 0.9972
# Epoch 72/200
#  - 381s - loss: 0.0049 - acc: 0.9986 - val_loss: 0.0123 - val_acc: 0.9978
# Epoch 73/200
#  - 382s - loss: 0.0048 - acc: 0.9986 - val_loss: 0.0147 - val_acc: 0.9970
# Epoch 74/200
#  - 381s - loss: 0.0047 - acc: 0.9986 - val_loss: 0.0126 - val_acc: 0.9977
# Epoch 75/200
#  - 381s - loss: 0.0047 - acc: 0.9987 - val_loss: 0.0131 - val_acc: 0.9977
# Epoch 76/200
#  - 381s - loss: 0.0046 - acc: 0.9987 - val_loss: 0.0133 - val_acc: 0.9977
# Epoch 77/200
#  - 382s - loss: 0.0046 - acc: 0.9987 - val_loss: 0.0131 - val_acc: 0.9977
# Epoch 78/200
#  - 382s - loss: 0.0045 - acc: 0.9987 - val_loss: 0.0130 - val_acc: 0.9974
# Epoch 79/200
#  - 381s - loss: 0.0045 - acc: 0.9987 - val_loss: 0.0582 - val_acc: 0.9925
# Epoch 80/200
#  - 381s - loss: 0.0044 - acc: 0.9987 - val_loss: 0.1346 - val_acc: 0.9871
# Epoch 81/200
#  - 382s - loss: 0.0045 - acc: 0.9987 - val_loss: 0.0253 - val_acc: 0.9964
# Epoch 82/200
#  - 381s - loss: 0.0047 - acc: 0.9987 - val_loss: 0.0152 - val_acc: 0.9976
# Epoch 83/200
#  - 382s - loss: 0.0044 - acc: 0.9987 - val_loss: 0.0125 - val_acc: 0.9979
# Epoch 84/200
#  - 382s - loss: 0.0044 - acc: 0.9988 - val_loss: 0.0130 - val_acc: 0.9976
# Epoch 85/200
#  - 381s - loss: 0.0043 - acc: 0.9988 - val_loss: 0.0121 - val_acc: 0.9979
# Epoch 86/200
#  - 382s - loss: 0.0043 - acc: 0.9988 - val_loss: 0.0162 - val_acc: 0.9972
# Epoch 87/200
#  - 381s - loss: 0.0046 - acc: 0.9987 - val_loss: 0.0116 - val_acc: 0.9979
# Epoch 88/200
#  - 381s - loss: 0.0043 - acc: 0.9988 - val_loss: 0.0103 - val_acc: 0.9981
# Epoch 89/200
#  - 381s - loss: 0.0042 - acc: 0.9988 - val_loss: 0.0149 - val_acc: 0.9975
# Epoch 90/200
#  - 381s - loss: 0.0042 - acc: 0.9988 - val_loss: 0.0115 - val_acc: 0.9978
# Epoch 91/200
#  - 382s - loss: 0.0042 - acc: 0.9988 - val_loss: 0.0119 - val_acc: 0.9978
# Epoch 92/200
#  - 381s - loss: 0.0043 - acc: 0.9988 - val_loss: 0.0114 - val_acc: 0.9979
# Epoch 93/200
#  - 382s - loss: 0.0042 - acc: 0.9988 - val_loss: 0.0137 - val_acc: 0.9977
# Epoch 94/200
#  - 382s - loss: 0.0042 - acc: 0.9988 - val_loss: 0.0152 - val_acc: 0.9977
# Epoch 95/200
#  - 382s - loss: 0.0042 - acc: 0.9988 - val_loss: 0.0133 - val_acc: 0.9976
# Epoch 96/200
#  - 382s - loss: 0.0041 - acc: 0.9988 - val_loss: 0.0179 - val_acc: 0.9955
# Epoch 97/200
#  - 381s - loss: 0.0040 - acc: 0.9989 - val_loss: 0.0137 - val_acc: 0.9978
# Epoch 98/200
#  - 380s - loss: 0.0041 - acc: 0.9988 - val_loss: 0.0117 - val_acc: 0.9978
# Epoch 99/200
#  - 382s - loss: 0.0040 - acc: 0.9989 - val_loss: 0.0117 - val_acc: 0.9981
# Epoch 100/200
#  - 381s - loss: 0.0041 - acc: 0.9989 - val_loss: 0.0642 - val_acc: 0.9876
# Epoch 101/200
#  - 381s - loss: 0.0040 - acc: 0.9989 - val_loss: 0.0132 - val_acc: 0.9979
# Epoch 102/200
#  - 381s - loss: 0.0048 - acc: 0.9986 - val_loss: 0.0162 - val_acc: 0.9974
# Epoch 103/200
#  - 381s - loss: 0.0043 - acc: 0.9988 - val_loss: 0.0462 - val_acc: 0.9947
# Epoch 104/200
#  - 381s - loss: 0.0043 - acc: 0.9988 - val_loss: 0.0151 - val_acc: 0.9977
# Epoch 105/200
#  - 382s - loss: 0.0042 - acc: 0.9988 - val_loss: 0.0352 - val_acc: 0.9945
# Epoch 106/200
#  - 381s - loss: 0.0044 - acc: 0.9988 - val_loss: 0.0178 - val_acc: 0.9974
# Epoch 107/200
#  - 381s - loss: 0.0041 - acc: 0.9988 - val_loss: 0.0160 - val_acc: 0.9975
# Epoch 108/200
#  - 381s - loss: 0.0041 - acc: 0.9989 - val_loss: 0.0123 - val_acc: 0.9979
# Epoch 109/200
#  - 381s - loss: 0.0041 - acc: 0.9989 - val_loss: 0.0136 - val_acc: 0.9978
# Epoch 110/200
#  - 381s - loss: 0.0041 - acc: 0.9989 - val_loss: 0.0115 - val_acc: 0.9980
# Epoch 111/200
#  - 381s - loss: 0.0040 - acc: 0.9989 - val_loss: 0.1660 - val_acc: 0.9872
# Epoch 112/200
#  - 381s - loss: 0.0039 - acc: 0.9989 - val_loss: 0.0114 - val_acc: 0.9979
# Epoch 113/200
#  - 382s - loss: 0.0039 - acc: 0.9989 - val_loss: 0.0141 - val_acc: 0.9973
# Epoch 114/200
#  - 381s - loss: 0.0040 - acc: 0.9989 - val_loss: 0.0191 - val_acc: 0.9969
# Epoch 115/200
#  - 381s - loss: 0.0040 - acc: 0.9989 - val_loss: 0.0152 - val_acc: 0.9973
# Epoch 116/200
#  - 381s - loss: 0.0044 - acc: 0.9988 - val_loss: 0.0118 - val_acc: 0.9979
# Epoch 117/200
#  - 381s - loss: 0.0040 - acc: 0.9989 - val_loss: 0.0141 - val_acc: 0.9977
# Epoch 118/200
#  - 382s - loss: 0.0040 - acc: 0.9989 - val_loss: 0.0124 - val_acc: 0.9978
# Epoch 119/200
#  - 382s - loss: 0.0039 - acc: 0.9989 - val_loss: 0.0151 - val_acc: 0.9976
# Epoch 120/200
#  - 381s - loss: 0.0040 - acc: 0.9989 - val_loss: 0.0138 - val_acc: 0.9976
# Epoch 121/200
#  - 382s - loss: 0.0039 - acc: 0.9990 - val_loss: 0.0195 - val_acc: 0.9953
# Epoch 122/200
#  - 381s - loss: 0.0038 - acc: 0.9990 - val_loss: 0.0159 - val_acc: 0.9973
# Epoch 123/200
#  - 382s - loss: 0.0039 - acc: 0.9989 - val_loss: 0.0159 - val_acc: 0.9977
# Epoch 124/200
#  - 382s - loss: 0.0037 - acc: 0.9990 - val_loss: 0.1575 - val_acc: 0.9849
# Epoch 125/200
#  - 381s - loss: 0.0037 - acc: 0.9990 - val_loss: 0.0126 - val_acc: 0.9979
# Epoch 126/200
#  - 381s - loss: 0.0037 - acc: 0.9990 - val_loss: 0.0247 - val_acc: 0.9951
# Epoch 127/200
#  - 381s - loss: 0.0037 - acc: 0.9990 - val_loss: 0.0122 - val_acc: 0.9976
# Epoch 128/200
#  - 381s - loss: 0.0036 - acc: 0.9990 - val_loss: 0.0108 - val_acc: 0.9981
# Epoch 129/200
#  - 381s - loss: 0.0038 - acc: 0.9990 - val_loss: 0.0138 - val_acc: 0.9978
# Epoch 130/200
#  - 381s - loss: 0.0040 - acc: 0.9989 - val_loss: 0.0141 - val_acc: 0.9976
# Epoch 131/200
#  - 381s - loss: 0.0037 - acc: 0.9990 - val_loss: 0.0116 - val_acc: 0.9979
# Epoch 132/200
#  - 382s - loss: 0.0036 - acc: 0.9990 - val_loss: 0.0303 - val_acc: 0.9951
# Epoch 133/200
#  - 382s - loss: 0.0037 - acc: 0.9990 - val_loss: 0.0145 - val_acc: 0.9977
# Epoch 134/200
#  - 382s - loss: 0.0037 - acc: 0.9990 - val_loss: 0.0130 - val_acc: 0.9977
# Epoch 135/200
#  - 381s - loss: 0.0038 - acc: 0.9990 - val_loss: 0.0636 - val_acc: 0.9943
# Epoch 136/200
#  - 381s - loss: 0.0037 - acc: 0.9990 - val_loss: 0.0150 - val_acc: 0.9972
# Epoch 137/200
#  - 382s - loss: 0.0036 - acc: 0.9990 - val_loss: 0.0136 - val_acc: 0.9978
# Epoch 138/200
#  - 382s - loss: 0.0036 - acc: 0.9990 - val_loss: 0.0176 - val_acc: 0.9971
# Epoch 139/200
#  - 381s - loss: 0.0036 - acc: 0.9990 - val_loss: 0.0120 - val_acc: 0.9979
# Epoch 140/200
#  - 381s - loss: 0.0036 - acc: 0.9990 - val_loss: 0.0165 - val_acc: 0.9956
# Epoch 141/200
#  - 381s - loss: 0.0035 - acc: 0.9991 - val_loss: 0.0125 - val_acc: 0.9980
# Epoch 142/200
#  - 381s - loss: 0.0035 - acc: 0.9991 - val_loss: 0.0129 - val_acc: 0.9981
# Epoch 143/200
#  - 381s - loss: 0.0036 - acc: 0.9990 - val_loss: 0.0121 - val_acc: 0.9980
# Epoch 144/200
#  - 381s - loss: 0.0035 - acc: 0.9991 - val_loss: 0.0140 - val_acc: 0.9979
# Epoch 145/200
#  - 381s - loss: 0.0036 - acc: 0.9991 - val_loss: 0.0116 - val_acc: 0.9981
# Epoch 146/200
#  - 381s - loss: 0.0035 - acc: 0.9991 - val_loss: 0.0129 - val_acc: 0.9980
# Epoch 147/200
#  - 381s - loss: 0.0036 - acc: 0.9991 - val_loss: 0.0439 - val_acc: 0.9899
# Epoch 148/200
#  - 381s - loss: 0.0035 - acc: 0.9991 - val_loss: 0.0130 - val_acc: 0.9979
# Epoch 149/200
#  - 381s - loss: 0.0035 - acc: 0.9991 - val_loss: 0.0164 - val_acc: 0.9978
# Epoch 150/200
#  - 381s - loss: 0.0035 - acc: 0.9991 - val_loss: 0.0137 - val_acc: 0.9979
# Epoch 151/200
#  - 381s - loss: 0.0035 - acc: 0.9991 - val_loss: 0.0127 - val_acc: 0.9980
# Epoch 152/200
#  - 381s - loss: 0.0035 - acc: 0.9991 - val_loss: 0.0115 - val_acc: 0.9980
# Epoch 153/200
#  - 382s - loss: 0.0034 - acc: 0.9991 - val_loss: 0.0163 - val_acc: 0.9975
# Epoch 154/200
#  - 381s - loss: 0.0034 - acc: 0.9991 - val_loss: 0.0118 - val_acc: 0.9979
# Epoch 155/200
#  - 382s - loss: 0.0035 - acc: 0.9991 - val_loss: 0.0146 - val_acc: 0.9977
# Epoch 156/200
#  - 382s - loss: 0.0035 - acc: 0.9991 - val_loss: 0.0175 - val_acc: 0.9977
# Epoch 157/200
#  - 381s - loss: 0.0035 - acc: 0.9991 - val_loss: 0.0156 - val_acc: 0.9978
# Epoch 158/200
#  - 382s - loss: 0.0035 - acc: 0.9991 - val_loss: 0.0143 - val_acc: 0.9978
# Epoch 159/200
#  - 382s - loss: 0.0037 - acc: 0.9990 - val_loss: 0.2039 - val_acc: 0.9844
# Epoch 160/200
#  - 382s - loss: 0.0035 - acc: 0.9991 - val_loss: 0.0159 - val_acc: 0.9972
# Epoch 161/200
#  - 382s - loss: 0.0034 - acc: 0.9991 - val_loss: 0.0156 - val_acc: 0.9975
# Epoch 162/200
#  - 381s - loss: 0.0034 - acc: 0.9991 - val_loss: 0.0136 - val_acc: 0.9979
# Epoch 163/200
#  - 381s - loss: 0.0034 - acc: 0.9991 - val_loss: 0.0112 - val_acc: 0.9981
# Epoch 164/200
#  - 382s - loss: 0.0034 - acc: 0.9991 - val_loss: 0.0128 - val_acc: 0.9980
# Epoch 165/200
#  - 381s - loss: 0.0034 - acc: 0.9991 - val_loss: 0.0137 - val_acc: 0.9980
# Epoch 166/200
#  - 381s - loss: 0.0034 - acc: 0.9991 - val_loss: 0.0205 - val_acc: 0.9973
# Epoch 167/200
#  - 382s - loss: 0.0034 - acc: 0.9991 - val_loss: 0.0144 - val_acc: 0.9976
# Epoch 168/200
#  - 382s - loss: 0.0033 - acc: 0.9991 - val_loss: 0.0137 - val_acc: 0.9979
# Epoch 169/200
#  - 381s - loss: 0.0033 - acc: 0.9992 - val_loss: 0.0120 - val_acc: 0.9982
# Epoch 170/200
#  - 382s - loss: 0.0038 - acc: 0.9990 - val_loss: 0.1923 - val_acc: 0.9852
# Epoch 171/200
#  - 382s - loss: 0.0033 - acc: 0.9991 - val_loss: 0.0109 - val_acc: 0.9981
# Epoch 172/200
#  - 382s - loss: 0.0034 - acc: 0.9991 - val_loss: 0.0174 - val_acc: 0.9961
# Epoch 173/200
#  - 382s - loss: 0.0033 - acc: 0.9991 - val_loss: 0.0123 - val_acc: 0.9979
# Epoch 174/200
#  - 382s - loss: 0.0033 - acc: 0.9992 - val_loss: 0.0155 - val_acc: 0.9977
# Epoch 175/200
#  - 381s - loss: 0.0033 - acc: 0.9992 - val_loss: 0.0131 - val_acc: 0.9981
# Epoch 176/200
#  - 381s - loss: 0.0033 - acc: 0.9992 - val_loss: 0.0184 - val_acc: 0.9977
# Epoch 177/200
#  - 381s - loss: 0.0033 - acc: 0.9991 - val_loss: 0.0126 - val_acc: 0.9980
# Epoch 178/200
#  - 381s - loss: 0.0035 - acc: 0.9991 - val_loss: 0.0140 - val_acc: 0.9979
# Epoch 179/200
#  - 382s - loss: 0.0033 - acc: 0.9992 - val_loss: 0.0143 - val_acc: 0.9979
# Epoch 180/200
#  - 381s - loss: 0.0032 - acc: 0.9992 - val_loss: 0.0268 - val_acc: 0.9970
# Epoch 181/200
#  - 381s - loss: 0.0036 - acc: 0.9991 - val_loss: 0.0252 - val_acc: 0.9973
# Epoch 182/200
#  - 382s - loss: 0.0032 - acc: 0.9992 - val_loss: 0.0165 - val_acc: 0.9978
# Epoch 183/200
#  - 382s - loss: 0.0032 - acc: 0.9992 - val_loss: 0.0224 - val_acc: 0.9972
# Epoch 184/200
#  - 381s - loss: 0.0032 - acc: 0.9992 - val_loss: 0.0150 - val_acc: 0.9979
# Epoch 185/200
#  - 382s - loss: 0.0032 - acc: 0.9992 - val_loss: 0.0176 - val_acc: 0.9977
# Epoch 186/200
#  - 382s - loss: 0.0032 - acc: 0.9992 - val_loss: 0.0143 - val_acc: 0.9979
# Epoch 187/200
#  - 382s - loss: 0.0032 - acc: 0.9992 - val_loss: 0.0228 - val_acc: 0.9972
# Epoch 188/200
#  - 382s - loss: 0.0032 - acc: 0.9992 - val_loss: 0.0162 - val_acc: 0.9975
# Epoch 189/200
#  - 383s - loss: 0.0031 - acc: 0.9992 - val_loss: 0.1659 - val_acc: 0.9884
# Epoch 190/200
#  - 383s - loss: 0.0032 - acc: 0.9992 - val_loss: 0.0695 - val_acc: 0.9921
# Epoch 191/200
#  - 383s - loss: 0.0032 - acc: 0.9992 - val_loss: 0.0164 - val_acc: 0.9979
# Epoch 192/200
#  - 382s - loss: 0.0032 - acc: 0.9992 - val_loss: 0.0177 - val_acc: 0.9977
# Epoch 193/200
#  - 381s - loss: 0.0031 - acc: 0.9992 - val_loss: 0.0150 - val_acc: 0.9979
# Epoch 194/200
#  - 382s - loss: 0.0032 - acc: 0.9992 - val_loss: 0.0191 - val_acc: 0.9976
# Epoch 195/200
#  - 382s - loss: 0.0032 - acc: 0.9992 - val_loss: 0.0139 - val_acc: 0.9979
# Epoch 196/200
#  - 382s - loss: 0.0031 - acc: 0.9992 - val_loss: 0.0118 - val_acc: 0.9980
# Epoch 197/200
#  - 382s - loss: 0.0033 - acc: 0.9992 - val_loss: 0.0662 - val_acc: 0.9886
# Epoch 198/200
#  - 381s - loss: 0.0032 - acc: 0.9992 - val_loss: 0.0127 - val_acc: 0.9979
# Epoch 199/200
#  - 382s - loss: 0.0033 - acc: 0.9992 - val_loss: 0.0140 - val_acc: 0.9978
# Epoch 200/200
#  - 382s - loss: 0.0032 - acc: 0.9992 - val_loss: 0.0192 - val_acc: 0.9976
# Wall time: 21h 12min 5s

# %%
y_train.shape
# Out:
# (2547668, 10)

# %% [markdown]
# # Graph the losses

# %%
def most_recent_file(pattern):
    return max(glob.iglob(pattern, recursive=True), key=os.path.getctime)

logpath = most_recent_file(NOTEBOOK_PATH + "Loss Logs/%s**" % model_id)
log_df = pd.read_csv(logpath)
log_df['epoch'] += 1

print(logpath)
# Out:
# C:/Users/Xetrov/Desktop/SciFair20/Code/Loss Logs\cnn9-pooling-multiclass (11-20-2019, 0957PM)

# %%
plot_df = log_df[:]

metric = 'loss'

plt.figure(figsize=(12,6))
sns.lineplot(x='epoch', y=metric, data=plot_df, label=metric)
sns.lineplot(x='epoch', y='val_'+metric, data=plot_df, label='val_'+metric)
plt.legend()

minEpoch = plot_df.loc[plot_df.idxmin()[metric]]
plt.plot((minEpoch['epoch']), (minEpoch[metric]), 'go', markersize=8)
minEpoch = plot_df.loc[plot_df.idxmin()['val_'+metric]]
plt.plot((minEpoch['epoch']), (minEpoch['val_'+metric]), 'ro', markersize=8)
print(minEpoch)

plt.xticks(list(range(0, plot_df['epoch'].max()+1, 5)))
# plt.yticks(list(np.arange(0.0,0.4,0.05)))

plt.grid(True)
# Out:
# epoch       88.000000
# acc          0.998772
# loss         0.004308
# val_acc      0.998107
# val_loss     0.010292
# Name: 88, dtype: float64

# %% [markdown]
# # Validation data

# %%
print("Loading...")
model = keras.models.load_model(NOTEBOOK_PATH + "Models/%s/cnn(88).h5" % model_id)
print("Predicting...")
pred = model.predict(x_val)

print("Plotting...")
pred_index = list(pred.argmax(1))
y_index = list(np.argmax(y_val.to_numpy(), axis=1))

atktypes = sorted(y_val.columns)
pred_series = pd.Series(pred_index, name="Pred").replace(dict(enumerate(atktypes)))
y_series = pd.Series(y_index, name="Actual").replace(dict(enumerate(atktypes)))

matrix = pd.crosstab(pred_series, y_series, margins=True)
print("Done!")
matrix
# Out:
# Loading...
# Predicting...
# Plotting...
# Done!
# Actual        BENIGN  Botnet  Brute Force  DoS/DDoS  Infiltration  PortScan  \
# Pred
# BENIGN        453220      13            0        21             0         1
# Botnet           477     384            0         0             0         0
# Brute Force        3       0         2810         0             0         0
# DoS/DDoS         297       0            0     76477             0         9
# Infiltration      13       0            0         0             7         0
# PortScan         192       0            0         6             0     31774
# Web Attack         5       0            0         6             0         3
# All           454207     397         2810     76510             7     31787
#
# Actual        Web Attack     All
# Pred
# BENIGN                 3  453258
# Botnet                 0     861
# Brute Force            0    2813
# DoS/DDoS               4   76787
# Infiltration           0      20
# PortScan              19   31991
# Web Attack           405     419
# All                  431  566149

# %% [markdown]
# # Test data

# %%
from sklearn.metrics import f1_score

# %%
# model = keras.models.load_model(NOTEBOOK_PATH + "Models/%s/cnn(50).h5" % model_id)
pred = model.predict(x_test, batch_size=256).argmax(axis=1)
pred_f1 = np.zeros((len(x_test), y_test.shape[1]))
for j in range(len(pred)):
    pred_f1[j,pred[j]] = 1
f1_micro = f1_score(y_test, pred_f1.astype('uint8'), average='micro')
f1_macro = f1_score(y_test, pred_f1.astype('uint8'), average='macro')
print("Micro:", f1_micro)
print("Macro:", f1_macro)
# Out:
# Micro: 0.9980782444197552
# Macro: 0.8310551304047975

# %%
pred_index = pred
y_index = list(np.argmax(y_test.to_numpy(), axis=1))

atktypes = sorted(y_test.columns)
pred_series = pd.Series(pred_index, name="Pred").replace(dict(enumerate(atktypes)))
y_series = pd.Series(y_index, name="Actual").replace(dict(enumerate(atktypes)))

matrix = pd.crosstab(pred_series, y_series, margins=True)
print("Done!")
matrix.to_csv(NOTEBOOK_PATH + "Confusion Matrices/%s.csv" % model_id)
matrix
# Out:
# Done!
# Actual        BENIGN  Botnet  Brute Force  DoS/DDoS  Infiltration  PortScan  \
# Pred
# BENIGN        453794      15            2        22             2         3
# Botnet           460     369            0         0             0         0
# Brute Force        2       0         2750         1             0         0
# DoS/DDoS         313       0            0     75861             0         7
# Infiltration      15       0            0         0             3         0
# PortScan         197       0            0        11             0     31865
# Web Attack         9       0            0         2             0         1
# All           454790     384         2752     75897             5     31876
#
# Actual        Web Attack     All
# Pred
# BENIGN                 1  453839
# Botnet                 0     829
# Brute Force            2    2755
# DoS/DDoS               3   76184
# Infiltration           0      18
# PortScan              20   32093
# Web Attack           419     431
# All                  445  566149

# %% [markdown]
# # Log results

# %%
model_log = open(NOTEBOOK_PATH + "model_log.txt", "a")

model_log.write("\n" + model_id)
model_log.write("\n\tF1 Micro: " + str(f1_micro))
model_log.write("\n\tF1 Macro: " + str(f1_macro))

model_log.close()
