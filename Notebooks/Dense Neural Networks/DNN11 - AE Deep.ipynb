# %% [markdown]
# # CSE-CIC-IDS 2017

# %%
model_id = "dnn11-autoencoder-16mid"

# %%
import numpy as np
np.random.seed(42)
np.set_printoptions(suppress=True)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

import glob, time, os

import keras
# Out:
# Using TensorFlow backend.
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
NOTEBOOK_PATH = "C:/Users/Xetrov/Desktop/SciFair20/Code/"

# %%
x_scaled = pd.read_csv(NOTEBOOK_PATH + "IDS2017/x_scaled_powertransform.csv")

# %%
y_df_enc = pd.read_csv(NOTEBOOK_PATH + "IDS2017/y_all_binary.csv")

# %% [markdown]
# # Split data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_valtest, y_train, y_valtest = train_test_split(x_scaled, y_df_enc, test_size = 0.4, random_state = 42)

# %%
x_val, x_test, y_val, y_test = train_test_split(x_valtest, y_valtest, test_size = 0.5, random_state = 42)

# %%
del x_train
del y_train
del x_valtest 
del y_valtest

# %% [markdown]
# # Oversampling

# %%
x_train_res = pd.read_csv(NOTEBOOK_PATH + "IDS2017/x_adasyn_binary.csv")

# %%
y_train_res = pd.read_csv(NOTEBOOK_PATH + "IDS2017/y_adasyn_binary.csv")['IsAttack']

# %% [markdown]
# # Train model

# %%
from keras.models import Model, Sequential
from keras.layers import Dense, BatchNormalization, Dropout, InputLayer
from keras.optimizers import SGD, Adam

# %%
def addDenseBlock(model, units, **params):
    model.add(Dense(units=units, activation=params['hidden_activation'], input_dim=x_train_res.shape[1]))
    if params['batch_normalization']: model.add(BatchNormalization())
    if params['dropout_rate'] > 0: model.add(Dropout(params['dropout_rate']))

def createModel(**in_params):
    """
    Supported parameters:
    batch_normalization - True or False
    dropout_rate - 0 to 1
    num_units - integer
    learning_rate - float
    activation_function - string
    """
    
    model = Sequential()

    # Set default values
    params = {
        'batch_normalization': True,
        'dropout_rate': 0,
        'num_layers': 6,
        'num_units': 128,
        'learning_rate': 0.001,
        'hidden_activation': 'relu',
        'final_activation': 'sigmoid'
    }
    
    # Replace defaults with specified parameters
    for param in in_params:
        params[param] = in_params[param]    
    
    # InputLayer causes serialization issues
#     model.add( InputLayer(input_shape = (x_train.shape[1],) ) )
    
#     for i in range(params['num_layers']):
#         addDenseBlock(model, params['num_units'], **params)

    addDenseBlock(model, 256, **params)
    addDenseBlock(model, 128, **params)
    addDenseBlock(model, 64, **params)
    addDenseBlock(model, 32, **params)
    addDenseBlock(model, 16, **params)
    addDenseBlock(model, 32, **params)
    addDenseBlock(model, 64, **params)
    addDenseBlock(model, 128, **params)
    addDenseBlock(model, 256, **params)

    model.add(Dense(units=1, activation=params['final_activation']))

    # optim = SGD(lr=0.001, nesterov=True)
    optim = Adam(lr=params['learning_rate'])

    model.compile(loss='binary_crossentropy', optimizer=optim, metrics=['accuracy'])
    
#     print(params)
    
    return model

# %% [markdown]
# ### Callbacks

# %%
from keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint

def timestamp():
    return time.strftime("%m-%d-%Y, %I%M%p")

csv_callback = CSVLogger(NOTEBOOK_PATH + 'Loss Logs/%s (%s)' % (model_id, timestamp()), append=True)
early_stop = EarlyStopping(monitor = 'val_loss', min_delta=0.0001, patience=5)

# %% [markdown]
# ### Model Saving

# %%
savedir = NOTEBOOK_PATH + "Models/%s/" % model_id
if not os.path.exists(savedir):
    os.makedirs(savedir)
    print("Created " + savedir)
else:
    print("Using " + savedir)
# Out:
# Created C:/Users/Xetrov/Desktop/SciFair20/Code/Models/dnn11-autoencoder-16mid/

# %% [markdown]
# Ensure a GPU is available

# %%
import keras.backend as K

K.tensorflow_backend._get_available_gpus()
# Out:
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %% [markdown]
# ### Training

# %%
import itertools

trainEpochs = 500

parameters = {'batch_size': 1000, 'batch_normalization':True,'dropout_rate':0, 'final_activation':'sigmoid'}

# %%
# %%time
print(model_id)
model = createModel(**parameters)
model.summary()
model_checkpoint = ModelCheckpoint(NOTEBOOK_PATH + "Models/%s/dnn({epoch}).h5" % (model_id), monitor='val_loss')
model.fit(x_train_res, y_train_res, validation_data=(x_val, y_val), 
          batch_size=parameters['batch_size'], 
          epochs=trainEpochs, 
          verbose=2, 
          callbacks=[csv_callback, model_checkpoint]
         )
# Out:
# dnn11-autoencoder-16mid
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 256)               17664
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32)                128
# _________________________________________________________________
# dense_5 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16)                64
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                544
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32)                128
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                2112
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 64)                256
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               8320
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 128)               512
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               33024
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 109,585
# Trainable params: 107,633
# Non-trainable params: 1,952
# _________________________________________________________________
# Train on 2727615 samples, validate on 566149 samples
# Epoch 1/500
#  - 48s - loss: 0.0369 - acc: 0.9879 - val_loss: 0.0396 - val_acc: 0.9879
# Epoch 2/500
#  - 45s - loss: 0.0236 - acc: 0.9932 - val_loss: 0.0191 - val_acc: 0.9946
# Epoch 3/500
#  - 45s - loss: 0.0203 - acc: 0.9945 - val_loss: 0.0232 - val_acc: 0.9935
# Epoch 4/500
#  - 46s - loss: 0.0191 - acc: 0.9949 - val_loss: 0.0399 - val_acc: 0.9897
# Epoch 5/500
#  - 45s - loss: 0.0196 - acc: 0.9946 - val_loss: 0.0202 - val_acc: 0.9931
# Epoch 6/500
#  - 45s - loss: 0.0182 - acc: 0.9951 - val_loss: 0.0415 - val_acc: 0.9865
# Epoch 7/500
#  - 45s - loss: 0.0171 - acc: 0.9955 - val_loss: 0.0197 - val_acc: 0.9943
# Epoch 8/500
#  - 45s - loss: 0.0165 - acc: 0.9957 - val_loss: 0.0260 - val_acc: 0.9917
# Epoch 9/500
#  - 45s - loss: 0.0158 - acc: 0.9959 - val_loss: 0.0280 - val_acc: 0.9927
# Epoch 10/500
- loss: 0.0069 - acc: 0.9985 - val_loss: 0.0083 - val_acc: 0.9981
# Epoch 119/500
#  - 45s - loss: 0.0069 - acc: 0.9985 - val_loss: 0.0114 - val_acc: 0.9966
# Epoch 120/500
#  - 45s - loss: 0.0068 - acc: 0.9985 - val_loss: 0.0291 - val_acc: 0.9959
# Epoch 121/500
#  - 45s - loss: 0.0068 - acc: 0.9985 - val_loss: 0.0550 - val_acc: 0.9951
# Epoch 122/500
#  - 45s - loss: 0.0068 - acc: 0.9985 - val_loss: 0.0182 - val_acc: 0.9959
# Epoch 123/500
#  - 45s - loss: 0.0068 - acc: 0.9985 - val_loss: 0.0238 - val_acc: 0.9948
# Epoch 124/500
#  - 45s - loss: 0.0068 - acc: 0.9985 - val_loss: 0.0587 - val_acc: 0.9937
# Epoch 125/500
#  - 45s - loss: 0.0067 - acc: 0.9985 - val_loss: 0.0093 - val_acc: 0.9979
# Epoch 126/500
#  - 45s - loss: 0.0067 - acc: 0.9985 - val_loss: 0.0143 - val_acc: 0.9974
# Epoch 127/500
#  - 45s - loss: 0.0070 - acc: 0.9985 - val_loss: 0.0147 - val_acc: 0.9970
# Epoch 128/500
#  - 45s - loss: 0.0067 - acc: 0.9985 - val_loss: 0.0134 - val_acc: 0.9974
# Epoch 129/500
#  - 45s - loss: 0.0067 - acc: 0.9985 - val_loss: 0.0167 - val_acc: 0.9969
# Epoch 130/500
#  - 45s - loss: 0.0066 - acc: 0.9986 - val_loss: 0.2834 - val_acc: 0.9769
# Epoch 131/500
#  - 45s - loss: 0.0067 - acc: 0.9985 - val_loss: 0.0484 - val_acc: 0.9954
# Epoch 132/500
#  - 45s - loss: 0.0067 - acc: 0.9985 - val_loss: 0.0136 - val_acc: 0.9963
# Epoch 133/500
#  - 45s - loss: 0.0066 - acc: 0.9986 - val_loss: 0.0338 - val_acc: 0.9958
# Epoch 134/500
#  - 45s - loss: 0.0067 - acc: 0.9985 - val_loss: 0.0531 - val_acc: 0.9949
# Epoch 135/500
#  - 45s - loss: 0.0066 - acc: 0.9986 - val_loss: 0.0084 - val_acc: 0.9980
# Epoch 136/500
#  - 45s - loss: 0.0066 - acc: 0.9986 - val_loss: 0.0092 - val_acc: 0.9980
# Epoch 137/500
#  - 45s - loss: 0.0066 - acc: 0.9986 - val_loss: 0.0192 - val_acc: 0.9955
# Epoch 138/500
#  - 45s - loss: 0.0066 - acc: 0.9986 - val_loss: 0.0561 - val_acc: 0.9948
# Epoch 139/500
#  - 45s - loss: 0.0067 - acc: 0.9986 - val_loss: 0.0477 - val_acc: 0.9954
# Epoch 140/500
#  - 45s - loss: 0.0066 - acc: 0.9986 - val_loss: 0.0136 - val_acc: 0.9976
# Epoch 141/500
#  - 45s - loss: 0.0066 - acc: 0.9986 - val_loss: 0.2164 - val_acc: 0.9826
# Epoch 142/500
#  - 45s - loss: 0.0065 - acc: 0.9986 - val_loss: 0.0446 - val_acc: 0.9951
# Epoch 143/500
#  - 45s - loss: 0.0066 - acc: 0.9986 - val_loss: 0.0293 - val_acc: 0.9939
# Epoch 144/500
#  - 45s - loss: 0.0066 - acc: 0.9986 - val_loss: 0.0110 - val_acc: 0.9974
# Epoch 145/500
#  - 45s - loss: 0.0065 - acc: 0.9986 - val_loss: 0.0145 - val_acc: 0.9975
# Epoch 146/500
#  - 45s - loss: 0.0065 - acc: 0.9986 - val_loss: 0.0132 - val_acc: 0.9975
# Epoch 147/500
#  - 45s - loss: 0.0065 - acc: 0.9986 - val_loss: 0.0154 - val_acc: 0.9963
# Epoch 148/500
#  - 45s - loss: 0.0065 - acc: 0.9986 - val_loss: 0.0091 - val_acc: 0.9980
# Epoch 149/500
#  - 45s - loss: 0.0065 - acc: 0.9986 - val_loss: 0.0094 - val_acc: 0.9979
# Epoch 150/500
#  - 45s - loss: 0.0065 - acc: 0.9986 - val_loss: 0.0070 - val_acc: 0.9984
# Epoch 151/500
#  - 45s - loss: 0.0066 - acc: 0.9986 - val_loss: 0.0525 - val_acc: 0.9953
# Epoch 152/500
#  - 45s - loss: 0.0065 - acc: 0.9986 - val_loss: 0.0088 - val_acc: 0.9979
# Epoch 153/500
#  - 45s - loss: 0.0066 - acc: 0.9986 - val_loss: 0.0199 - val_acc: 0.9958
# Epoch 154/500
#  - 45s - loss: 0.0064 - acc: 0.9986 - val_loss: 0.0084 - val_acc: 0.9981
# Epoch 155/500
#  - 45s - loss: 0.0065 - acc: 0.9986 - val_loss: 0.0555 - val_acc: 0.9951
# Epoch 156/500
#  - 45s - loss: 0.0064 - acc: 0.9986 - val_loss: 0.0398 - val_acc: 0.9954
# Epoch 157/500
#  - 45s - loss: 0.0064 - acc: 0.9986 - val_loss: 0.0166 - val_acc: 0.9962
# Epoch 158/500
#  - 45s - loss: 0.0065 - acc: 0.9986 - val_loss: 0.0194 - val_acc: 0.9966
# Epoch 159/500
#  - 45s - loss: 0.0067 - acc: 0.9985 - val_loss: 0.0102 - val_acc: 0.9978
# Epoch 160/500
#  - 45s - loss: 0.0064 - acc: 0.9986 - val_loss: 0.1156 - val_acc: 0.9809
# Epoch 161/500
#  - 45s - loss: 0.0065 - acc: 0.9986 - val_loss: 0.0476 - val_acc: 0.9947
# Epoch 162/500
#  - 45s - loss: 0.0064 - acc: 0.9986 - val_loss: 0.0086 - val_acc: 0.9980
# Epoch 163/500
#  - 45s - loss: 0.0064 - acc: 0.9986 - val_loss: 0.1596 - val_acc: 0.9843
# Epoch 164/500
#  - 45s - loss: 0.0063 - acc: 0.9986 - val_loss: 0.0171 - val_acc: 0.9954
# Epoch 165/500
#  - 45s - loss: 0.0064 - acc: 0.9986 - val_loss: 0.0186 - val_acc: 0.9963
# Epoch 166/500
#  - 45s - loss: 0.0064 - acc: 0.9986 - val_loss: 0.1642 - val_acc: 0.9847
# Epoch 167/500
#  - 45s - loss: 0.0063 - acc: 0.9987 - val_loss: 0.0132 - val_acc: 0.9965
# Epoch 168/500
#  - 45s - loss: 0.0064 - acc: 0.9986 - val_loss: 0.0085 - val_acc: 0.9982
# Epoch 169/500
#  - 45s - loss: 0.0064 - acc: 0.9986 - val_loss: 0.0420 - val_acc: 0.9934
# Epoch 170/500
#  - 45s - loss: 0.0064 - acc: 0.9986 - val_loss: 0.0523 - val_acc: 0.9953
# Epoch 171/500
#  - 45s - loss: 0.0063 - acc: 0.9986 - val_loss: 0.0084 - val_acc: 0.9981
# Epoch 172/500
#  - 45s - loss: 0.0064 - acc: 0.9986 - val_loss: 0.0167 - val_acc: 0.9961
# Epoch 173/500
#  - 45s - loss: 0.0063 - acc: 0.9987 - val_loss: 0.0980 - val_acc: 0.9868
# Epoch 174/500
#  - 45s - loss: 0.0063 - acc: 0.9987 - val_loss: 0.0301 - val_acc: 0.9959
# Epoch 175/500
#  - 45s - loss: 0.0063 - acc: 0.9986 - val_loss: 0.1881 - val_acc: 0.9832
# Epoch 176/500
#  - 45s - loss: 0.0063 - acc: 0.9987 - val_loss: 0.0985 - val_acc: 0.9882
# Epoch 177/500
#  - 45s - loss: 0.0063 - acc: 0.9987 - val_loss: 0.0091 - val_acc: 0.9981
# Epoch 178/500
#  - 45s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0313 - val_acc: 0.9956
# Epoch 179/500
#  - 45s - loss: 0.0063 - acc: 0.9987 - val_loss: 0.0106 - val_acc: 0.9976
# Epoch 180/500
#  - 45s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0176 - val_acc: 0.9968
# Epoch 181/500
#  - 45s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0116 - val_acc: 0.9966
# Epoch 182/500
#  - 45s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0285 - val_acc: 0.9960
# Epoch 183/500
#  - 45s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0163 - val_acc: 0.9966
# Epoch 184/500
#  - 45s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0332 - val_acc: 0.9952
# Epoch 185/500
#  - 45s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0412 - val_acc: 0.9955
# Epoch 186/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0240 - val_acc: 0.9954
# Epoch 187/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0149 - val_acc: 0.9971
# Epoch 188/500
#  - 45s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0228 - val_acc: 0.9955
# Epoch 189/500
#  - 45s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0145 - val_acc: 0.9975
# Epoch 190/500
#  - 45s - loss: 0.0064 - acc: 0.9987 - val_loss: 0.0161 - val_acc: 0.9967
# Epoch 191/500
#  - 45s - loss: 0.0064 - acc: 0.9986 - val_loss: 0.0561 - val_acc: 0.9944
# Epoch 192/500
#  - 45s - loss: 0.0065 - acc: 0.9986 - val_loss: 0.0323 - val_acc: 0.9959
# Epoch 193/500
#  - 45s - loss: 0.0064 - acc: 0.9986 - val_loss: 0.0179 - val_acc: 0.9961
# Epoch 194/500
#  - 45s - loss: 0.0064 - acc: 0.9986 - val_loss: 0.0244 - val_acc: 0.9959
# Epoch 195/500
#  - 45s - loss: 0.0063 - acc: 0.9987 - val_loss: 0.0153 - val_acc: 0.9962
# Epoch 196/500
#  - 45s - loss: 0.0063 - acc: 0.9987 - val_loss: 0.0205 - val_acc: 0.9961
# Epoch 197/500
#  - 45s - loss: 0.0063 - acc: 0.9987 - val_loss: 0.0172 - val_acc: 0.9958
# Epoch 198/500
#  - 45s - loss: 0.0064 - acc: 0.9987 - val_loss: 0.0537 - val_acc: 0.9936
# Epoch 199/500
#  - 45s - loss: 0.0063 - acc: 0.9987 - val_loss: 0.1410 - val_acc: 0.9844
# Epoch 200/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0136 - val_acc: 0.9973
# Epoch 201/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0177 - val_acc: 0.9950
# Epoch 202/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0564 - val_acc: 0.9950
# Epoch 203/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0387 - val_acc: 0.9952
# Epoch 204/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0140 - val_acc: 0.9974
# Epoch 205/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0357 - val_acc: 0.9954
# Epoch 206/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0120 - val_acc: 0.9964
# Epoch 207/500
#  - 45s - loss: 0.0060 - acc: 0.9987 - val_loss: 0.0109 - val_acc: 0.9980
# Epoch 208/500
#  - 45s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.1072 - val_acc: 0.9838
# Epoch 209/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0108 - val_acc: 0.9977
# Epoch 210/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0167 - val_acc: 0.9961
# Epoch 211/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0124 - val_acc: 0.9975
# Epoch 212/500
#  - 45s - loss: 0.0060 - acc: 0.9987 - val_loss: 0.0200 - val_acc: 0.9955
# Epoch 213/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0225 - val_acc: 0.9964
# Epoch 214/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0290 - val_acc: 0.9959
# Epoch 215/500
#  - 45s - loss: 0.0060 - acc: 0.9987 - val_loss: 0.0452 - val_acc: 0.9950
# Epoch 216/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0114 - val_acc: 0.9973
# Epoch 217/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0279 - val_acc: 0.9961
# Epoch 218/500
#  - 45s - loss: 0.0060 - acc: 0.9987 - val_loss: 0.0104 - val_acc: 0.9980
# Epoch 219/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0104 - val_acc: 0.9981
# Epoch 220/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0787 - val_acc: 0.9893
# Epoch 221/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0240 - val_acc: 0.9956
# Epoch 222/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0101 - val_acc: 0.9981
# Epoch 223/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0098 - val_acc: 0.9983
# Epoch 224/500
#  - 45s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0230 - val_acc: 0.9958
# Epoch 225/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0103 - val_acc: 0.9978
# Epoch 226/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0140 - val_acc: 0.9969
# Epoch 227/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0283 - val_acc: 0.9958
# Epoch 228/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.1070 - val_acc: 0.9852
# Epoch 229/500
#  - 45s - loss: 0.0065 - acc: 0.9986 - val_loss: 0.0086 - val_acc: 0.9981
# Epoch 230/500
#  - 45s - loss: 0.0063 - acc: 0.9987 - val_loss: 0.0533 - val_acc: 0.9954
# Epoch 231/500
#  - 45s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0548 - val_acc: 0.9941
# Epoch 232/500
#  - 45s - loss: 0.0061 - acc: 0.9988 - val_loss: 0.0197 - val_acc: 0.9954
# Epoch 233/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0103 - val_acc: 0.9981
# Epoch 234/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0207 - val_acc: 0.9959
# Epoch 235/500
#  - 45s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0518 - val_acc: 0.9952
# Epoch 236/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0383 - val_acc: 0.9957
# Epoch 237/500
#  - 45s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0118 - val_acc: 0.9981
# Epoch 238/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0168 - val_acc: 0.9965
# Epoch 239/500
#  - 45s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0118 - val_acc: 0.9978
# Epoch 240/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0559 - val_acc: 0.9951
# Epoch 241/500
#  - 45s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.1092 - val_acc: 0.9840
# Epoch 242/500
#  - 45s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0281 - val_acc: 0.9960
# Epoch 243/500
#  - 45s - loss: 0.0066 - acc: 0.9986 - val_loss: 0.0094 - val_acc: 0.9980
# Epoch 244/500
#  - 45s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0095 - val_acc: 0.9979
# Epoch 245/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0105 - val_acc: 0.9978
# Epoch 246/500
#  - 45s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0172 - val_acc: 0.9956
# Epoch 247/500
#  - 45s - loss: 0.0061 - acc: 0.9988 - val_loss: 0.0169 - val_acc: 0.9965
# Epoch 248/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0551 - val_acc: 0.9950
# Epoch 249/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0172 - val_acc: 0.9965
# Epoch 250/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0507 - val_acc: 0.9952
# Epoch 251/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0211 - val_acc: 0.9964
# Epoch 252/500
#  - 45s - loss: 0.0061 - acc: 0.9988 - val_loss: 0.0447 - val_acc: 0.9948
# Epoch 253/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0104 - val_acc: 0.9978
# Epoch 254/500
#  - 45s - loss: 0.0063 - acc: 0.9987 - val_loss: 0.0236 - val_acc: 0.9959
# Epoch 255/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.1151 - val_acc: 0.9861
# Epoch 256/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0540 - val_acc: 0.9954
# Epoch 257/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0314 - val_acc: 0.9957
# Epoch 258/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0229 - val_acc: 0.9950
# Epoch 259/500
#  - 45s - loss: 0.0061 - acc: 0.9988 - val_loss: 0.0207 - val_acc: 0.9954
# Epoch 260/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0134 - val_acc: 0.9975
# Epoch 261/500
#  - 45s - loss: 0.0061 - acc: 0.9988 - val_loss: 0.0170 - val_acc: 0.9963
# Epoch 262/500
#  - 45s - loss: 0.0060 - acc: 0.9987 - val_loss: 0.0511 - val_acc: 0.9953
# Epoch 263/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0253 - val_acc: 0.9959
# Epoch 264/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0193 - val_acc: 0.9961
# Epoch 265/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0462 - val_acc: 0.9951
# Epoch 266/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.1371 - val_acc: 0.9859
# Epoch 267/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0107 - val_acc: 0.9979
# Epoch 268/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0092 - val_acc: 0.9981
# Epoch 269/500
#  - 45s - loss: 0.0060 - acc: 0.9987 - val_loss: 0.0086 - val_acc: 0.9981
# Epoch 270/500
#  - 45s - loss: 0.0060 - acc: 0.9987 - val_loss: 0.0135 - val_acc: 0.9965
# Epoch 271/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0133 - val_acc: 0.9969
# Epoch 272/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0242 - val_acc: 0.9961
# Epoch 273/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0108 - val_acc: 0.9979
# Epoch 274/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0134 - val_acc: 0.9975
# Epoch 275/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0243 - val_acc: 0.9956
# Epoch 276/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0105 - val_acc: 0.9977
# Epoch 277/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0099 - val_acc: 0.9983
# Epoch 278/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0302 - val_acc: 0.9964
# Epoch 279/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0144 - val_acc: 0.9977
# Epoch 280/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0391 - val_acc: 0.9951
# Epoch 281/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.1564 - val_acc: 0.9859
# Epoch 282/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0082 - val_acc: 0.9983
# Epoch 283/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0480 - val_acc: 0.9953
# Epoch 284/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.1388 - val_acc: 0.9858
# Epoch 285/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0101 - val_acc: 0.9982
# Epoch 286/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0090 - val_acc: 0.9980
# Epoch 287/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0292 - val_acc: 0.9956
# Epoch 288/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0258 - val_acc: 0.9957
# Epoch 289/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0489 - val_acc: 0.9899
# Epoch 290/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0513 - val_acc: 0.9956
# Epoch 291/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0322 - val_acc: 0.9961
# Epoch 292/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0091 - val_acc: 0.9983
# Epoch 293/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0283 - val_acc: 0.9947
# Epoch 294/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0094 - val_acc: 0.9982
# Epoch 295/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0439 - val_acc: 0.9952
# Epoch 296/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0151 - val_acc: 0.9969
# Epoch 297/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0529 - val_acc: 0.9955
# Epoch 298/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0205 - val_acc: 0.9960
# Epoch 299/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0092 - val_acc: 0.9981
# Epoch 300/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.1270 - val_acc: 0.9861
# Epoch 301/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0345 - val_acc: 0.9956
# Epoch 302/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0267 - val_acc: 0.9956
# Epoch 303/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0090 - val_acc: 0.9981
# Epoch 304/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0446 - val_acc: 0.9954
# Epoch 305/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0153 - val_acc: 0.9951
# Epoch 306/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0103 - val_acc: 0.9982
# Epoch 307/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0089 - val_acc: 0.9980
# Epoch 308/500
#  - 45s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.1972 - val_acc: 0.9851
# Epoch 309/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0289 - val_acc: 0.9960
# Epoch 310/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0085 - val_acc: 0.9981
# Epoch 311/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0113 - val_acc: 0.9966
# Epoch 312/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0106 - val_acc: 0.9978
# Epoch 313/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0106 - val_acc: 0.9982
# Epoch 314/500
#  - 45s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0087 - val_acc: 0.9982
# Epoch 315/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0093 - val_acc: 0.9982
# Epoch 316/500
#  - 44s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0100 - val_acc: 0.9983
# Epoch 317/500
#  - 45s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0546 - val_acc: 0.9954
# Epoch 318/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0100 - val_acc: 0.9980
# Epoch 319/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0976 - val_acc: 0.9859
# Epoch 320/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0112 - val_acc: 0.9975
# Epoch 321/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0166 - val_acc: 0.9962
# Epoch 322/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0129 - val_acc: 0.9978
# Epoch 323/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0079 - val_acc: 0.9984
# Epoch 324/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0080 - val_acc: 0.9982
# Epoch 325/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0516 - val_acc: 0.9953
# Epoch 326/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0258 - val_acc: 0.9956
# Epoch 327/500
#  - 45s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0103 - val_acc: 0.9980
# Epoch 328/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0635 - val_acc: 0.9922
# Epoch 329/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.2082 - val_acc: 0.9859
# Epoch 330/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0525 - val_acc: 0.9953
# Epoch 331/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0298 - val_acc: 0.9960
# Epoch 332/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0224 - val_acc: 0.9955
# Epoch 333/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0531 - val_acc: 0.9955
# Epoch 334/500
#  - 45s - loss: 0.0061 - acc: 0.9988 - val_loss: 0.0158 - val_acc: 0.9962
# Epoch 335/500
#  - 45s - loss: 0.0064 - acc: 0.9988 - val_loss: 0.0126 - val_acc: 0.9964
# Epoch 336/500
#  - 45s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0124 - val_acc: 0.9977
# Epoch 337/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0156 - val_acc: 0.9975
# Epoch 338/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0516 - val_acc: 0.9953
# Epoch 339/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0095 - val_acc: 0.9982
# Epoch 340/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0109 - val_acc: 0.9980
# Epoch 341/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.2059 - val_acc: 0.9863
# Epoch 342/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0521 - val_acc: 0.9954
# Epoch 343/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0095 - val_acc: 0.9984
# Epoch 344/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.2220 - val_acc: 0.9832
# Epoch 345/500
#  - 45s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0141 - val_acc: 0.9977
# Epoch 346/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0173 - val_acc: 0.9957
# Epoch 347/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0154 - val_acc: 0.9974
# Epoch 348/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0384 - val_acc: 0.9954
# Epoch 349/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0534 - val_acc: 0.9954
# Epoch 350/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0190 - val_acc: 0.9965
# Epoch 351/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0078 - val_acc: 0.9984
# Epoch 352/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0272 - val_acc: 0.9955
# Epoch 353/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0078 - val_acc: 0.9983
# Epoch 354/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0997 - val_acc: 0.9882
# Epoch 355/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0562 - val_acc: 0.9922
# Epoch 356/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0091 - val_acc: 0.9980
# Epoch 357/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0083 - val_acc: 0.9982
# Epoch 358/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0112 - val_acc: 0.9977
# Epoch 359/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0381 - val_acc: 0.9957
# Epoch 360/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0182 - val_acc: 0.9955
# Epoch 361/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0135 - val_acc: 0.9972
# Epoch 362/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0476 - val_acc: 0.9951
# Epoch 363/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0077 - val_acc: 0.9983
# Epoch 364/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0083 - val_acc: 0.9981
# Epoch 365/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0081 - val_acc: 0.9983
# Epoch 366/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.2147 - val_acc: 0.9848
# Epoch 367/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0525 - val_acc: 0.9940
# Epoch 368/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0555 - val_acc: 0.9950
# Epoch 369/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0144 - val_acc: 0.9974
# Epoch 370/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0128 - val_acc: 0.9976
# Epoch 371/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0090 - val_acc: 0.9982
# Epoch 372/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.1622 - val_acc: 0.9853
# Epoch 373/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0082 - val_acc: 0.9982
# Epoch 374/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0097 - val_acc: 0.9978
# Epoch 375/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0092 - val_acc: 0.9981
# Epoch 376/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0144 - val_acc: 0.9974
# Epoch 377/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0094 - val_acc: 0.9980
# Epoch 378/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0088 - val_acc: 0.9982
# Epoch 379/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0139 - val_acc: 0.9976
# Epoch 380/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.1494 - val_acc: 0.9872
# Epoch 381/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0386 - val_acc: 0.9953
# Epoch 382/500
#  - 45s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0088 - val_acc: 0.9982
# Epoch 383/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0091 - val_acc: 0.9980
# Epoch 384/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0081 - val_acc: 0.9983
# Epoch 385/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0827 - val_acc: 0.9859
# Epoch 386/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0161 - val_acc: 0.9969
# Epoch 387/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0105 - val_acc: 0.9980
# Epoch 388/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0093 - val_acc: 0.9981
# Epoch 389/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0222 - val_acc: 0.9957
# Epoch 390/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0082 - val_acc: 0.9983
# Epoch 391/500
#  - 45s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0134 - val_acc: 0.9970
# Epoch 392/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0290 - val_acc: 0.9957
# Epoch 393/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0422 - val_acc: 0.9952
# Epoch 394/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0086 - val_acc: 0.9983
# Epoch 395/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0085 - val_acc: 0.9983
# Epoch 396/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0083 - val_acc: 0.9982
# Epoch 397/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0451 - val_acc: 0.9953
# Epoch 398/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0150 - val_acc: 0.9964
# Epoch 399/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.1161 - val_acc: 0.9853
# Epoch 400/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0337 - val_acc: 0.9954
# Epoch 401/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0391 - val_acc: 0.9952
# Epoch 402/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0154 - val_acc: 0.9959
# Epoch 403/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0234 - val_acc: 0.9959
# Epoch 404/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0117 - val_acc: 0.9971
# Epoch 405/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0232 - val_acc: 0.9950
# Epoch 406/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0194 - val_acc: 0.9954
# Epoch 407/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0233 - val_acc: 0.9912
# Epoch 408/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0109 - val_acc: 0.9977
# Epoch 409/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0194 - val_acc: 0.9957
# Epoch 410/500
#  - 45s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0104 - val_acc: 0.9983
# Epoch 411/500
#  - 45s - loss: 0.0056 - acc: 0.9988 - val_loss: 0.0088 - val_acc: 0.9982
# Epoch 412/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0231 - val_acc: 0.9957
# Epoch 413/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0102 - val_acc: 0.9981
# Epoch 414/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0086 - val_acc: 0.9983
# Epoch 415/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0247 - val_acc: 0.9961
# Epoch 416/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0094 - val_acc: 0.9978
# Epoch 417/500
#  - 45s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0340 - val_acc: 0.9959
# Epoch 418/500
#  - 45s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0086 - val_acc: 0.9982
# Epoch 419/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0293 - val_acc: 0.9951
# Epoch 420/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0096 - val_acc: 0.9978
# Epoch 421/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0088 - val_acc: 0.9983
# Epoch 422/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0518 - val_acc: 0.9953
# Epoch 423/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0153 - val_acc: 0.9965
# Epoch 424/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0168 - val_acc: 0.9956
# Epoch 425/500
#  - 45s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0085 - val_acc: 0.9983
# Epoch 426/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.1176 - val_acc: 0.9857
# Epoch 427/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0203 - val_acc: 0.9961
# Epoch 428/500
#  - 46s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0244 - val_acc: 0.9960
# Epoch 429/500
#  - 45s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0240 - val_acc: 0.9959
# Epoch 430/500
#  - 45s - loss: 0.0061 - acc: 0.9988 - val_loss: 0.0085 - val_acc: 0.9983
# Epoch 431/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0261 - val_acc: 0.9955
# Epoch 432/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0304 - val_acc: 0.9953
# Epoch 433/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0130 - val_acc: 0.9974
# Epoch 434/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0142 - val_acc: 0.9965
# Epoch 435/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0143 - val_acc: 0.9975
# Epoch 436/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0100 - val_acc: 0.9978
# Epoch 437/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0083 - val_acc: 0.9982
# Epoch 438/500
#  - 45s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0185 - val_acc: 0.9955
# Epoch 439/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0761 - val_acc: 0.9892
# Epoch 440/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0480 - val_acc: 0.9952
# Epoch 441/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0202 - val_acc: 0.9963
# Epoch 442/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0144 - val_acc: 0.9973
# Epoch 443/500
#  - 45s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0078 - val_acc: 0.9984
# Epoch 444/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0166 - val_acc: 0.9965
# Epoch 445/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0111 - val_acc: 0.9982
# Epoch 446/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0102 - val_acc: 0.9983
# Epoch 447/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0237 - val_acc: 0.9963
# Epoch 448/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0163 - val_acc: 0.9964
# Epoch 449/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0553 - val_acc: 0.9950
# Epoch 450/500
#  - 45s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0514 - val_acc: 0.9953
# Epoch 451/500
#  - 45s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0097 - val_acc: 0.9983
# Epoch 452/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0545 - val_acc: 0.9946
# Epoch 453/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0096 - val_acc: 0.9980
# Epoch 454/500
#  - 44s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0091 - val_acc: 0.9981
# Epoch 455/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0322 - val_acc: 0.9953
# Epoch 456/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0531 - val_acc: 0.9919
# Epoch 457/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.1448 - val_acc: 0.9856
# Epoch 458/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0091 - val_acc: 0.9980
# Epoch 459/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0189 - val_acc: 0.9961
# Epoch 460/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0137 - val_acc: 0.9976
# Epoch 461/500
#  - 45s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0096 - val_acc: 0.9981
# Epoch 462/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0211 - val_acc: 0.9955
# Epoch 463/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0092 - val_acc: 0.9982
# Epoch 464/500
#  - 44s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0157 - val_acc: 0.9973
# Epoch 465/500
#  - 44s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0355 - val_acc: 0.9960
# Epoch 466/500
#  - 44s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0132 - val_acc: 0.9977
# Epoch 467/500
#  - 45s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0093 - val_acc: 0.9982
# Epoch 468/500
#  - 44s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0548 - val_acc: 0.9954
# Epoch 469/500
#  - 44s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0203 - val_acc: 0.9957
# Epoch 470/500
#  - 44s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0096 - val_acc: 0.9982
# Epoch 471/500
#  - 44s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0113 - val_acc: 0.9980
# Epoch 472/500
#  - 44s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0200 - val_acc: 0.9967
# Epoch 473/500
#  - 44s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0217 - val_acc: 0.9956
# Epoch 474/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0191 - val_acc: 0.9964
# Epoch 475/500
#  - 44s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0096 - val_acc: 0.9980
# Epoch 476/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.1377 - val_acc: 0.9792
# Epoch 477/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0118 - val_acc: 0.9981
# Epoch 478/500
#  - 45s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.1723 - val_acc: 0.9862
# Epoch 479/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0081 - val_acc: 0.9983
# Epoch 480/500
#  - 44s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0118 - val_acc: 0.9979
# Epoch 481/500
#  - 44s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0354 - val_acc: 0.9956
# Epoch 482/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0077 - val_acc: 0.9984
# Epoch 483/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0088 - val_acc: 0.9983
# Epoch 484/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0115 - val_acc: 0.9964
# Epoch 485/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0112 - val_acc: 0.9972
# Epoch 486/500
#  - 45s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0305 - val_acc: 0.9954
# Epoch 487/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0228 - val_acc: 0.9957
# Epoch 488/500
#  - 44s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0139 - val_acc: 0.9966
# Epoch 489/500
#  - 44s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0297 - val_acc: 0.9962
# Epoch 490/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0491 - val_acc: 0.9953
# Epoch 491/500
#  - 45s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0134 - val_acc: 0.9977
# Epoch 492/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0324 - val_acc: 0.9959
# Epoch 493/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0095 - val_acc: 0.9980
# Epoch 494/500
#  - 44s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0133 - val_acc: 0.9976
# Epoch 495/500
#  - 45s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0098 - val_acc: 0.9983
# Epoch 496/500
#  - 44s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0300 - val_acc: 0.9954
# Epoch 497/500
#  - 45s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0088 - val_acc: 0.9982
# Epoch 498/500
#  - 45s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0085 - val_acc: 0.9984
# Epoch 499/500
#  - 45s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0150 - val_acc: 0.9958
# Epoch 500/500
#  - 45s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0124 - val_acc: 0.9979
# Wall time: 6h 13min 32s

# %% [markdown]
# # Graph the losses

# %%
def most_recent_file(pattern):
    return max(glob.iglob(pattern, recursive=True), key=os.path.getctime)

logpath = most_recent_file(NOTEBOOK_PATH + "Loss Logs/%s**" % model_id)
log_df = pd.read_csv(logpath)
log_df['epoch'] += 1

print(logpath)
# Out:
# C:/Users/Xetrov/Desktop/SciFair20/Code/Loss Logs\dnn11-autoencoder-16mid (11-09-2019, 1111PM)

# %%
plot_df = log_df[:]

metric = 'loss'

plt.figure(figsize=(12,6))
sns.lineplot(x='epoch', y=metric, data=plot_df, label=metric)
sns.lineplot(x='epoch', y='val_'+metric, data=plot_df, label='val_'+metric)
plt.legend()

minEpoch = plot_df.loc[plot_df.idxmin()[metric]]
plt.plot((minEpoch['epoch']), (minEpoch[metric]), 'go', markersize=8)
minEpoch = plot_df.loc[plot_df.idxmin()['val_'+metric]]
plt.plot((minEpoch['epoch']), (minEpoch['val_'+metric]), 'ro', markersize=8)
print(minEpoch)

plt.xticks(list(range(0, plot_df['epoch'].max()+1, 5)))
# plt.yticks(list(np.arange(0.0,0.4,0.05)))

plt.grid(True)
# Out:
# epoch       150.000000
# acc           0.998612
# loss          0.006472
# val_acc       0.998373
# val_loss      0.006998
# Name: 149, dtype: float64

# %% [markdown]
# # View confusion matrix

# %%
print("Loading...")
model = keras.models.load_model(NOTEBOOK_PATH + "Models/%s/dnn(498).h5" % model_id)
print("Done!")
# Out:
# Loading...
# Done!

# %%
print("Predicting...")
pred = model.predict(x_val)

print("Plotting...")
pred_series = pd.Series(pred.round().astype('int').ravel(), name="Pred").replace({0: 'Benign', 1: 'Attack'})
y_series = pd.Series(y_val.to_numpy().ravel(), name="Actual").replace({0: 'Benign', 1: 'Attack'})

matrix = pd.crosstab(pred_series, y_series, margins=True)
print("Done!")
matrix
# Out:
# Predicting...
# Plotting...
# Done!
# Actual  Attack  Benign     All
# Pred
# Attack  111925     904  112829
# Benign      17  453303  453320
# All     111942  454207  566149

# %% [markdown]
# # F1 Score

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

# %%
pred = model.predict(x_test).round().astype('int').ravel()
y_test_npy = y_test.to_numpy().ravel()

precision = precision_score(y_test_npy, pred)
print("Precision:", precision)

recall = recall_score(y_test_npy, pred)
print("Recall:", recall)

f1 = f1_score(y_test_npy, pred)
print("F1:", f1)
# Out:
# Precision: 0.9927202005513378
# Recall: 0.9992456828814914
# F1: 0.9959722533005148

# %%
pred_series = pd.Series(pred, name="Pred").replace({0: 'Benign', 1: 'Attack'})
y_series = pd.Series(y_test.to_numpy().ravel(), name="Actual").replace({0: 'Benign', 1: 'Attack'})

matrix = pd.crosstab(pred_series, y_series, margins=True)
matrix
# Out:
# Actual  Attack  Benign     All
# Pred
# Attack  111275     816  112091
# Benign      84  453974  454058
# All     111359  454790  566149

# %% [markdown]
# # Log results

# %%
model_log = open(NOTEBOOK_PATH + "model_log.txt", "a")

model_log.write("\n" + model_id)
model_log.write("\n\tF1 Micro: " + str(f1_micro))
model_log.write("\n\tF1 Macro: " + str(f1_macro))

model_log.close()
