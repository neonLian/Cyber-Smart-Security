# %% [markdown]
# # CSE-CIC-IDS 2017

# %%
model_id = "dnn9-featureselection2drop-regular"

# %%
import numpy as np
np.random.seed(42)
np.set_printoptions(suppress=True)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

import glob, time, os

import keras
# Out:
# Using TensorFlow backend.
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
NOTEBOOK_PATH = "C:/Users/Xetrov/Desktop/SciFair20/Code/"

# %%
selected_features = [
    'Destination Port',
    'Init_Win_bytes_forward',
    'Avg Fwd Segment Size',
    'Subflow Fwd Bytes',
    'Packet Length Std',
    'Packet Length Variance',
    'Fwd Packet Length Mean',
    'Init_Win_bytes_backward',
    'Fwd Packet Length Max',
    'Packet Length Mean',
    'Total Length of Fwd Packets',
    'Average Packet Size',
    'Max Packet Length',
    'Avg Bwd Segment Size',
    'Bwd Packet Length Max',
    'Fwd Header Length.1',
    'Bwd Packet Length Mean',
    'Bwd Packet Length Std',
    'Total Length of Bwd Packets',
    'Fwd Header Length',
    'Min Packet Length',
    'Bwd Packet Length Min',
    'Subflow Bwd Bytes',
    'act_data_pkt_fwd',
    'Bwd Packets/s',
    'Flow IAT Max',
    'Flow IAT Min'
]

# %%
x_scaled = pd.read_csv(NOTEBOOK_PATH + "IDS2017/x_scaled_powertransform.csv")[selected_features]

# %%
y_df_enc = pd.read_csv(NOTEBOOK_PATH + "IDS2017/y_all_binary.csv")

# %% [markdown]
# # Split data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_valtest, y_train, y_valtest = train_test_split(x_scaled, y_df_enc, test_size = 0.4, random_state = 42)

# %%
x_val, x_test, y_val, y_test = train_test_split(x_valtest, y_valtest, test_size = 0.5, random_state = 42)

# %%
del x_train
del y_train
del x_valtest 
del y_valtest

# %% [markdown]
# # Oversampling

# %%
x_train_res = pd.read_csv(NOTEBOOK_PATH + "IDS2017/x_adasyn_binary.csv")[selected_features]

# %%
y_train_res = pd.read_csv(NOTEBOOK_PATH + "IDS2017/y_adasyn_binary.csv")['IsAttack']

# %% [markdown]
# # Train model

# %%
from keras.models import Model, Sequential
from keras.layers import Dense, BatchNormalization, Dropout, InputLayer
from keras.optimizers import SGD, Adam

# %%
def addDenseBlock(model, units, **params):
    model.add(Dense(units=units, activation=params['hidden_activation'], input_dim=x_train_res.shape[1]))
    if params['batch_normalization']: model.add(BatchNormalization())
    if params['dropout_rate'] > 0: model.add(Dropout(params['dropout_rate']))

def createModel(**in_params):
    """
    Supported parameters:
    batch_normalization - True or False
    dropout_rate - 0 to 1
    num_units - integer
    learning_rate - float
    activation_function - string
    """
    
    model = Sequential()

    # Set default values
    params = {
        'batch_normalization': True,
        'dropout_rate': 0.3,
        'num_layers': 6,
        'num_units': 128,
        'learning_rate': 0.001,
        'hidden_activation': 'relu',
        'final_activation': 'sigmoid'
    }
    
    # Replace defaults with specified parameters
    for param in in_params:
        params[param] = in_params[param]    
    
    # InputLayer causes serialization issues
#     model.add( InputLayer(input_shape = (x_train.shape[1],) ) )
    
#     for i in range(params['num_layers']):
#         addDenseBlock(model, params['num_units'], **params)

    addDenseBlock(model, 128, **params)
    addDenseBlock(model, 128, **params)
    addDenseBlock(model, 256, **params)
    addDenseBlock(model, 256, **params)
    addDenseBlock(model, 128, **params)
    addDenseBlock(model, 128, **params)

    model.add(Dense(units=1, activation=params['final_activation']))

    # optim = SGD(lr=0.001, nesterov=True)
    optim = Adam(lr=params['learning_rate'])

    model.compile(loss='binary_crossentropy', optimizer=optim, metrics=['accuracy'])
    
#     print(params)
    
    return model

# %% [markdown]
# ### Callbacks

# %%
from keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint

def timestamp():
    return time.strftime("%m-%d-%Y, %I%M%p")

csv_callback = CSVLogger(NOTEBOOK_PATH + 'Loss Logs/%s (%s)' % (model_id, timestamp()), append=True)
early_stop = EarlyStopping(monitor = 'val_loss', min_delta=0.0001, patience=5)

savedir = NOTEBOOK_PATH + "Models/%s/" % model_id
if not os.path.exists(savedir):
    os.makedirs(savedir)
    print("Created " + savedir)
else:
    print("Using " + savedir)
# Out:
# Using C:/Users/Xetrov/Desktop/SciFair20/Code/Models/dnn9-featureselection2drop-regular/

# %% [markdown]
# ### Training

# %%
import itertools

trainEpochs = 200

parameters = {'batch_size': 1000, 'batch_normalization':True,'dropout_rate':0.3, 'final_activation':'sigmoid'}

# %%
# %%time
print(model_id)
model = createModel(**parameters)
model.summary()
model_checkpoint = ModelCheckpoint(NOTEBOOK_PATH + "Models/%s/dnn({epoch}).h5" % (model_id), monitor='val_loss')
model.fit(x_train_res, y_train_res, validation_data=(x_val, y_val), 
          batch_size=parameters['batch_size'], 
          epochs=trainEpochs, 
          verbose=2, 
          callbacks=[csv_callback, model_checkpoint]
         )
# Out:
# dnn9-featureselection2drop-regular
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               3584
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               33024
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               16512
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 172,545
# Trainable params: 170,497
# Non-trainable params: 2,048
# _________________________________________________________________
# Train on 2727615 samples, validate on 566149 samples
# Epoch 1/200
#  - 37s - loss: 0.0848 - acc: 0.9691 - val_loss: 0.0568 - val_acc: 0.9758
# Epoch 2/200
#  - 33s - loss: 0.0540 - acc: 0.9806 - val_loss: 0.0547 - val_acc: 0.9853
# Epoch 3/200
#  - 33s - loss: 0.0468 - acc: 0.9843 - val_loss: 0.0416 - val_acc: 0.9868
# Epoch 4/200
#  - 33s - loss: 0.0425 - acc: 0.9863 - val_loss: 0.0368 - val_acc: 0.9883
# Epoch 5/200
#  - 33s - loss: 0.0395 - acc: 0.9876 - val_loss: 0.0372 - val_acc: 0.9899
# Epoch 6/200
#  - 33s - loss: 0.0377 - acc: 0.9883 - val_loss: 0.0358 - val_acc: 0.9895
# Epoch 7/200
#  - 33s - loss: 0.0363 - acc: 0.9888 - val_loss: 0.0331 - val_acc: 0.9899
# Epoch 8/200
#  - 33s - loss: 0.0349 - acc: 0.9894 - val_loss: 0.0323 - val_acc: 0.9908
# Epoch 9/200
#  - 33s - loss: 0.0343 - acc: 0.9896 - val_loss: 0.0339 - val_acc: 0.9898
# Epoch 10/200
#  - 33s - loss: 0.0334 - acc: 0.9899 - val_loss: 0.0320 - val_acc: 0.9907
# Epoch 11/200
#  - 33s - loss: 0.0331 - acc: 0.9900 - val_loss: 0.0312 - val_acc: 0.9904
# Epoch 12/200
#  - 33s - loss: 0.0327 - acc: 0.9902 - val_loss: 0.0303 - val_acc: 0.9911
# Epoch 13/200
#  - 33s - loss: 0.0322 - acc: 0.9904 - val_loss: 0.0348 - val_acc: 0.9901
# Epoch 14/200
#  - 33s - loss: 0.0317 - acc: 0.9905 - val_loss: 0.0305 - val_acc: 0.9913
# Epoch 15/200
#  - 33s - loss: 0.0314 - acc: 0.9906 - val_loss: 0.0305 - val_acc: 0.9908
# Epoch 16/200
#  - 33s - loss: 0.0309 - acc: 0.9909 - val_loss: 0.0303 - val_acc: 0.9908
# Epoch 17/200
#  - 33s - loss: 0.0305 - acc: 0.9909 - val_loss: 0.0319 - val_acc: 0.9907
# Epoch 18/200
#  - 33s - loss: 0.0303 - acc: 0.9910 - val_loss: 0.0308 - val_acc: 0.9914
# Epoch 19/200
#  - 33s - loss: 0.0301 - acc: 0.9911 - val_loss: 0.0280 - val_acc: 0.9917
# Epoch 20/200
#  - 33s - loss: 0.0298 - acc: 0.9912 - val_loss: 0.0294 - val_acc: 0.9912
# Epoch 21/200
#  - 33s - loss: 0.0294 - acc: 0.9913 - val_loss: 0.0310 - val_acc: 0.9907
# Epoch 22/200
#  - 33s - loss: 0.0297 - acc: 0.9912 - val_loss: 0.0268 - val_acc: 0.9920
# Epoch 23/200
#  - 33s - loss: 0.0291 - acc: 0.9914 - val_loss: 0.0276 - val_acc: 0.9920
# Epoch 24/200
#  - 33s - loss: 0.0291 - acc: 0.9914 - val_loss: 0.0287 - val_acc: 0.9913
# Epoch 25/200
#  - 33s - loss: 0.0290 - acc: 0.9914 - val_loss: 0.0314 - val_acc: 0.9902
# Epoch 26/200
#  - 33s - loss: 0.0287 - acc: 0.9915 - val_loss: 0.0281 - val_acc: 0.9915
# Epoch 27/200
#  - 33s - loss: 0.0288 - acc: 0.9915 - val_loss: 0.0288 - val_acc: 0.9920
# Epoch 28/200
#  - 33s - loss: 0.0285 - acc: 0.9916 - val_loss: 0.0297 - val_acc: 0.9913
# Epoch 29/200
#  - 33s - loss: 0.0284 - acc: 0.9917 - val_loss: 0.0276 - val_acc: 0.9920
# Epoch 30/200
#  - 33s - loss: 0.0282 - acc: 0.9917 - val_loss: 0.0284 - val_acc: 0.9919
# Epoch 31/200
#  - 33s - loss: 0.0280 - acc: 0.9918 - val_loss: 0.0287 - val_acc: 0.9912
# Epoch 32/200
#  - 33s - loss: 0.0278 - acc: 0.9919 - val_loss: 0.0287 - val_acc: 0.9922
# Epoch 33/200
#  - 33s - loss: 0.0275 - acc: 0.9919 - val_loss: 0.0273 - val_acc: 0.9919
# Epoch 34/200
#  - 33s - loss: 0.0277 - acc: 0.9919 - val_loss: 0.0287 - val_acc: 0.9909
# Epoch 35/200
#  - 33s - loss: 0.0275 - acc: 0.9920 - val_loss: 0.0287 - val_acc: 0.9917
# Epoch 36/200
#  - 34s - loss: 0.0273 - acc: 0.9920 - val_loss: 0.0269 - val_acc: 0.9923
# Epoch 37/200
#  - 33s - loss: 0.0270 - acc: 0.9921 - val_loss: 0.0288 - val_acc: 0.9920
# Epoch 38/200
#  - 33s - loss: 0.0272 - acc: 0.9921 - val_loss: 0.0284 - val_acc: 0.9919
# Epoch 39/200
#  - 33s - loss: 0.0269 - acc: 0.9922 - val_loss: 0.0293 - val_acc: 0.9911
# Epoch 40/200
#  - 33s - loss: 0.0268 - acc: 0.9922 - val_loss: 0.0278 - val_acc: 0.9928
# Epoch 41/200
#  - 33s - loss: 0.0268 - acc: 0.9922 - val_loss: 0.0283 - val_acc: 0.9920
# Epoch 42/200
#  - 33s - loss: 0.0266 - acc: 0.9923 - val_loss: 0.0290 - val_acc: 0.9921
# Epoch 43/200
#  - 33s - loss: 0.0267 - acc: 0.9923 - val_loss: 0.0273 - val_acc: 0.9916
# Epoch 44/200
#  - 33s - loss: 0.0266 - acc: 0.9923 - val_loss: 0.0288 - val_acc: 0.9921
# Epoch 45/200
#  - 33s - loss: 0.0265 - acc: 0.9923 - val_loss: 0.0261 - val_acc: 0.9927
# Epoch 46/200
#  - 33s - loss: 0.0263 - acc: 0.9924 - val_loss: 0.0250 - val_acc: 0.9926
# Epoch 47/200
#  - 33s - loss: 0.0263 - acc: 0.9924 - val_loss: 0.0256 - val_acc: 0.9926
# Epoch 48/200
#  - 33s - loss: 0.0264 - acc: 0.9924 - val_loss: 0.0261 - val_acc: 0.9925
# Epoch 49/200
#  - 33s - loss: 0.0262 - acc: 0.9925 - val_loss: 0.0267 - val_acc: 0.9918
# Epoch 50/200
#  - 33s - loss: 0.0262 - acc: 0.9924 - val_loss: 0.0285 - val_acc: 0.9919
# Epoch 51/200
#  - 33s - loss: 0.0262 - acc: 0.9924 - val_loss: 0.0257 - val_acc: 0.9930
# Epoch 52/200
#  - 33s - loss: 0.0259 - acc: 0.9925 - val_loss: 0.0275 - val_acc: 0.9919
# Epoch 53/200
#  - 33s - loss: 0.0258 - acc: 0.9925 - val_loss: 0.0273 - val_acc: 0.9925
# Epoch 54/200
#  - 33s - loss: 0.0256 - acc: 0.9926 - val_loss: 0.0273 - val_acc: 0.9924
# Epoch 55/200
#  - 33s - loss: 0.0257 - acc: 0.9927 - val_loss: 0.0253 - val_acc: 0.9922
# Epoch 56/200
#  - 33s - loss: 0.0257 - acc: 0.9926 - val_loss: 0.0269 - val_acc: 0.9923
# Epoch 57/200
#  - 33s - loss: 0.0256 - acc: 0.9927 - val_loss: 0.0264 - val_acc: 0.9925
# Epoch 58/200
#  - 33s - loss: 0.0257 - acc: 0.9926 - val_loss: 0.0256 - val_acc: 0.9926
# Epoch 59/200
#  - 33s - loss: 0.0255 - acc: 0.9926 - val_loss: 0.0260 - val_acc: 0.9930
# Epoch 60/200
#  - 33s - loss: 0.0253 - acc: 0.9927 - val_loss: 0.0246 - val_acc: 0.9928
# Epoch 61/200
#  - 33s - loss: 0.0257 - acc: 0.9926 - val_loss: 0.0269 - val_acc: 0.9925
# Epoch 62/200
#  - 33s - loss: 0.0254 - acc: 0.9927 - val_loss: 0.0248 - val_acc: 0.9929
# Epoch 63/200
#  - 33s - loss: 0.0253 - acc: 0.9927 - val_loss: 0.0267 - val_acc: 0.9925
# Epoch 64/200
#  - 33s - loss: 0.0253 - acc: 0.9927 - val_loss: 0.0245 - val_acc: 0.9928
# Epoch 65/200
#  - 33s - loss: 0.0253 - acc: 0.9928 - val_loss: 0.0264 - val_acc: 0.9923
# Epoch 66/200
#  - 33s - loss: 0.0252 - acc: 0.9928 - val_loss: 0.0260 - val_acc: 0.9926
# Epoch 67/200
#  - 33s - loss: 0.0251 - acc: 0.9928 - val_loss: 0.0247 - val_acc: 0.9928
# Epoch 68/200
#  - 33s - loss: 0.0251 - acc: 0.9928 - val_loss: 0.0263 - val_acc: 0.9926
# Epoch 69/200
#  - 33s - loss: 0.0251 - acc: 0.9927 - val_loss: 0.0266 - val_acc: 0.9924
# Epoch 70/200
#  - 33s - loss: 0.0249 - acc: 0.9929 - val_loss: 0.0251 - val_acc: 0.9924
# Epoch 71/200
#  - 33s - loss: 0.0249 - acc: 0.9929 - val_loss: 0.0264 - val_acc: 0.9914
# Epoch 72/200
#  - 33s - loss: 0.0248 - acc: 0.9929 - val_loss: 0.0251 - val_acc: 0.9928
# Epoch 73/200
#  - 33s - loss: 0.0248 - acc: 0.9929 - val_loss: 0.0248 - val_acc: 0.9928
# Epoch 74/200
#  - 33s - loss: 0.0248 - acc: 0.9929 - val_loss: 0.0276 - val_acc: 0.9921
# Epoch 75/200
#  - 33s - loss: 0.0247 - acc: 0.9929 - val_loss: 0.0238 - val_acc: 0.9930
# Epoch 76/200
#  - 33s - loss: 0.0246 - acc: 0.9929 - val_loss: 0.0252 - val_acc: 0.9926
# Epoch 77/200
#  - 33s - loss: 0.0248 - acc: 0.9928 - val_loss: 0.0270 - val_acc: 0.9923
# Epoch 78/200
#  - 33s - loss: 0.0246 - acc: 0.9929 - val_loss: 0.0254 - val_acc: 0.9926
# Epoch 79/200
#  - 33s - loss: 0.0246 - acc: 0.9929 - val_loss: 0.0251 - val_acc: 0.9925
# Epoch 80/200
#  - 33s - loss: 0.0245 - acc: 0.9930 - val_loss: 0.0264 - val_acc: 0.9925
# Epoch 81/200
#  - 33s - loss: 0.0246 - acc: 0.9930 - val_loss: 0.0256 - val_acc: 0.9923
# Epoch 82/200
#  - 33s - loss: 0.0243 - acc: 0.9930 - val_loss: 0.0276 - val_acc: 0.9912
# Epoch 83/200
#  - 33s - loss: 0.0244 - acc: 0.9930 - val_loss: 0.0264 - val_acc: 0.9915
# Epoch 84/200
#  - 33s - loss: 0.0244 - acc: 0.9930 - val_loss: 0.0242 - val_acc: 0.9928
# Epoch 85/200
#  - 33s - loss: 0.0243 - acc: 0.9930 - val_loss: 0.0270 - val_acc: 0.9916
# Epoch 86/200
#  - 33s - loss: 0.0242 - acc: 0.9931 - val_loss: 0.0253 - val_acc: 0.9925
# Epoch 87/200
#  - 33s - loss: 0.0243 - acc: 0.9930 - val_loss: 0.0253 - val_acc: 0.9917
# Epoch 88/200
#  - 33s - loss: 0.0242 - acc: 0.9931 - val_loss: 0.0253 - val_acc: 0.9930
# Epoch 89/200
#  - 33s - loss: 0.0243 - acc: 0.9930 - val_loss: 0.0257 - val_acc: 0.9930
# Epoch 90/200
#  - 33s - loss: 0.0240 - acc: 0.9931 - val_loss: 0.0271 - val_acc: 0.9922
# Epoch 91/200
#  - 33s - loss: 0.0241 - acc: 0.9931 - val_loss: 0.0340 - val_acc: 0.9900
# Epoch 92/200
#  - 33s - loss: 0.0241 - acc: 0.9931 - val_loss: 0.0256 - val_acc: 0.9921
# Epoch 93/200
#  - 33s - loss: 0.0240 - acc: 0.9931 - val_loss: 0.0251 - val_acc: 0.9919
# Epoch 94/200
#  - 33s - loss: 0.0239 - acc: 0.9932 - val_loss: 0.0246 - val_acc: 0.9922
# Epoch 95/200
#  - 33s - loss: 0.0238 - acc: 0.9931 - val_loss: 0.0241 - val_acc: 0.9920
# Epoch 96/200
#  - 33s - loss: 0.0239 - acc: 0.9931 - val_loss: 0.0252 - val_acc: 0.9925
# Epoch 97/200
#  - 33s - loss: 0.0237 - acc: 0.9932 - val_loss: 0.0255 - val_acc: 0.9919
# Epoch 98/200
#  - 33s - loss: 0.0237 - acc: 0.9932 - val_loss: 0.0266 - val_acc: 0.9923
# Epoch 99/200
#  - 33s - loss: 0.0238 - acc: 0.9932 - val_loss: 0.0259 - val_acc: 0.9927
# Epoch 100/200
#  - 33s - loss: 0.0237 - acc: 0.9932 - val_loss: 0.0257 - val_acc: 0.9920
# Epoch 101/200
#  - 33s - loss: 0.0236 - acc: 0.9933 - val_loss: 0.0249 - val_acc: 0.9926
# Epoch 102/200
#  - 33s - loss: 0.0236 - acc: 0.9932 - val_loss: 0.0247 - val_acc: 0.9922
# Epoch 103/200
#  - 33s - loss: 0.0234 - acc: 0.9933 - val_loss: 0.0241 - val_acc: 0.9925
# Epoch 104/200
#  - 33s - loss: 0.0236 - acc: 0.9932 - val_loss: 0.0256 - val_acc: 0.9925
# Epoch 105/200
#  - 33s - loss: 0.0237 - acc: 0.9932 - val_loss: 0.0247 - val_acc: 0.9927
# Epoch 106/200
#  - 33s - loss: 0.0236 - acc: 0.9933 - val_loss: 0.0229 - val_acc: 0.9934
# Epoch 107/200
#  - 33s - loss: 0.0235 - acc: 0.9933 - val_loss: 0.0237 - val_acc: 0.9926
# Epoch 108/200
#  - 33s - loss: 0.0235 - acc: 0.9932 - val_loss: 0.0267 - val_acc: 0.9925
# Epoch 109/200
#  - 34s - loss: 0.0234 - acc: 0.9933 - val_loss: 0.0262 - val_acc: 0.9924
# Epoch 110/200
#  - 33s - loss: 0.0233 - acc: 0.9933 - val_loss: 0.0238 - val_acc: 0.9927
# Epoch 111/200
#  - 33s - loss: 0.0232 - acc: 0.9933 - val_loss: 0.0248 - val_acc: 0.9929
# Epoch 112/200
#  - 33s - loss: 0.0233 - acc: 0.9934 - val_loss: 0.0253 - val_acc: 0.9930
# Epoch 113/200
#  - 33s - loss: 0.0233 - acc: 0.9933 - val_loss: 0.0236 - val_acc: 0.9931
# Epoch 114/200
#  - 33s - loss: 0.0233 - acc: 0.9933 - val_loss: 0.0256 - val_acc: 0.9927
# Epoch 115/200
#  - 33s - loss: 0.0234 - acc: 0.9933 - val_loss: 0.0249 - val_acc: 0.9926
# Epoch 116/200
#  - 33s - loss: 0.0233 - acc: 0.9933 - val_loss: 0.0252 - val_acc: 0.9930
# Epoch 117/200
#  - 33s - loss: 0.0233 - acc: 0.9933 - val_loss: 0.0241 - val_acc: 0.9927
# Epoch 118/200
#  - 33s - loss: 0.0231 - acc: 0.9934 - val_loss: 0.0258 - val_acc: 0.9925
# Epoch 119/200
#  - 33s - loss: 0.0232 - acc: 0.9933 - val_loss: 0.0243 - val_acc: 0.9931
# Epoch 120/200
#  - 33s - loss: 0.0233 - acc: 0.9933 - val_loss: 0.0266 - val_acc: 0.9924
# Epoch 121/200
#  - 33s - loss: 0.0232 - acc: 0.9934 - val_loss: 0.0261 - val_acc: 0.9923
# Epoch 122/200
#  - 33s - loss: 0.0231 - acc: 0.9934 - val_loss: 0.0257 - val_acc: 0.9926
# Epoch 123/200
#  - 33s - loss: 0.0231 - acc: 0.9934 - val_loss: 0.0255 - val_acc: 0.9927
# Epoch 124/200
#  - 33s - loss: 0.0232 - acc: 0.9934 - val_loss: 0.0244 - val_acc: 0.9923
# Epoch 125/200
#  - 33s - loss: 0.0231 - acc: 0.9934 - val_loss: 0.0255 - val_acc: 0.9926
# Epoch 126/200
#  - 33s - loss: 0.0229 - acc: 0.9934 - val_loss: 0.0246 - val_acc: 0.9919
# Epoch 127/200
#  - 33s - loss: 0.0231 - acc: 0.9934 - val_loss: 0.0247 - val_acc: 0.9929
# Epoch 128/200
#  - 33s - loss: 0.0232 - acc: 0.9934 - val_loss: 0.0236 - val_acc: 0.9928
# Epoch 129/200
#  - 33s - loss: 0.0230 - acc: 0.9935 - val_loss: 0.0237 - val_acc: 0.9930
# Epoch 130/200
#  - 33s - loss: 0.0230 - acc: 0.9935 - val_loss: 0.0268 - val_acc: 0.9925
# Epoch 131/200
#  - 33s - loss: 0.0229 - acc: 0.9935 - val_loss: 0.0244 - val_acc: 0.9931
# Epoch 132/200
#  - 33s - loss: 0.0230 - acc: 0.9934 - val_loss: 0.0242 - val_acc: 0.9927
# Epoch 133/200
#  - 33s - loss: 0.0228 - acc: 0.9935 - val_loss: 0.0246 - val_acc: 0.9920
# Epoch 134/200
#  - 33s - loss: 0.0229 - acc: 0.9935 - val_loss: 0.0237 - val_acc: 0.9927
# Epoch 135/200
#  - 33s - loss: 0.0229 - acc: 0.9934 - val_loss: 0.0248 - val_acc: 0.9929
# Epoch 136/200
#  - 33s - loss: 0.0229 - acc: 0.9934 - val_loss: 0.0241 - val_acc: 0.9925
# Epoch 137/200
#  - 33s - loss: 0.0227 - acc: 0.9935 - val_loss: 0.0252 - val_acc: 0.9920
# Epoch 138/200
#  - 33s - loss: 0.0227 - acc: 0.9935 - val_loss: 0.0238 - val_acc: 0.9924
# Epoch 139/200
#  - 33s - loss: 0.0226 - acc: 0.9935 - val_loss: 0.0231 - val_acc: 0.9933
# Epoch 140/200
#  - 33s - loss: 0.0229 - acc: 0.9935 - val_loss: 0.0226 - val_acc: 0.9933
# Epoch 141/200
#  - 33s - loss: 0.0226 - acc: 0.9936 - val_loss: 0.0242 - val_acc: 0.9929
# Epoch 142/200
#  - 33s - loss: 0.0227 - acc: 0.9935 - val_loss: 0.0247 - val_acc: 0.9926
# Epoch 143/200
#  - 33s - loss: 0.0226 - acc: 0.9935 - val_loss: 0.0234 - val_acc: 0.9929
# Epoch 144/200
#  - 33s - loss: 0.0225 - acc: 0.9936 - val_loss: 0.0235 - val_acc: 0.9937
# Epoch 145/200
#  - 33s - loss: 0.0227 - acc: 0.9935 - val_loss: 0.0243 - val_acc: 0.9931
# Epoch 146/200
#  - 33s - loss: 0.0226 - acc: 0.9935 - val_loss: 0.0224 - val_acc: 0.9934
# Epoch 147/200
#  - 33s - loss: 0.0227 - acc: 0.9936 - val_loss: 0.0229 - val_acc: 0.9933
# Epoch 148/200
#  - 33s - loss: 0.0225 - acc: 0.9936 - val_loss: 0.0235 - val_acc: 0.9932
# Epoch 149/200
#  - 33s - loss: 0.0225 - acc: 0.9936 - val_loss: 0.0238 - val_acc: 0.9926
# Epoch 150/200
#  - 33s - loss: 0.0225 - acc: 0.9935 - val_loss: 0.0252 - val_acc: 0.9921
# Epoch 151/200
#  - 33s - loss: 0.0224 - acc: 0.9936 - val_loss: 0.0239 - val_acc: 0.9928
# Epoch 152/200
#  - 33s - loss: 0.0222 - acc: 0.9936 - val_loss: 0.0250 - val_acc: 0.9925
# Epoch 153/200
#  - 33s - loss: 0.0225 - acc: 0.9936 - val_loss: 0.0240 - val_acc: 0.9929
# Epoch 154/200
#  - 33s - loss: 0.0223 - acc: 0.9936 - val_loss: 0.0233 - val_acc: 0.9929
# Epoch 155/200
#  - 33s - loss: 0.0223 - acc: 0.9936 - val_loss: 0.0238 - val_acc: 0.9928
# Epoch 156/200
#  - 33s - loss: 0.0223 - acc: 0.9936 - val_loss: 0.0220 - val_acc: 0.9935
# Epoch 157/200
#  - 33s - loss: 0.0222 - acc: 0.9936 - val_loss: 0.0257 - val_acc: 0.9924
# Epoch 158/200
#  - 33s - loss: 0.0222 - acc: 0.9936 - val_loss: 0.0230 - val_acc: 0.9935
# Epoch 159/200
#  - 33s - loss: 0.0224 - acc: 0.9936 - val_loss: 0.0231 - val_acc: 0.9931
# Epoch 160/200
#  - 33s - loss: 0.0221 - acc: 0.9936 - val_loss: 0.0242 - val_acc: 0.9921
# Epoch 161/200
#  - 33s - loss: 0.0222 - acc: 0.9937 - val_loss: 0.0235 - val_acc: 0.9931
# Epoch 162/200
#  - 33s - loss: 0.0221 - acc: 0.9936 - val_loss: 0.0236 - val_acc: 0.9926
# Epoch 163/200
#  - 33s - loss: 0.0222 - acc: 0.9936 - val_loss: 0.0239 - val_acc: 0.9926
# Epoch 164/200
#  - 33s - loss: 0.0222 - acc: 0.9936 - val_loss: 0.0255 - val_acc: 0.9928
# Epoch 165/200
#  - 33s - loss: 0.0221 - acc: 0.9937 - val_loss: 0.0238 - val_acc: 0.9928
# Epoch 166/200
#  - 33s - loss: 0.0223 - acc: 0.9936 - val_loss: 0.0237 - val_acc: 0.9928
# Epoch 167/200
#  - 33s - loss: 0.0222 - acc: 0.9936 - val_loss: 0.0259 - val_acc: 0.9922
# Epoch 168/200
#  - 33s - loss: 0.0222 - acc: 0.9937 - val_loss: 0.0252 - val_acc: 0.9925
# Epoch 169/200
#  - 33s - loss: 0.0221 - acc: 0.9937 - val_loss: 0.0247 - val_acc: 0.9927
# Epoch 170/200
#  - 33s - loss: 0.0220 - acc: 0.9937 - val_loss: 0.0261 - val_acc: 0.9915
# Epoch 171/200
#  - 33s - loss: 0.0219 - acc: 0.9937 - val_loss: 0.0230 - val_acc: 0.9930
# Epoch 172/200
#  - 33s - loss: 0.0221 - acc: 0.9937 - val_loss: 0.0230 - val_acc: 0.9929
# Epoch 173/200
#  - 33s - loss: 0.0220 - acc: 0.9937 - val_loss: 0.0226 - val_acc: 0.9929
# Epoch 174/200
#  - 33s - loss: 0.0221 - acc: 0.9936 - val_loss: 0.0250 - val_acc: 0.9925
# Epoch 175/200
#  - 33s - loss: 0.0221 - acc: 0.9937 - val_loss: 0.0232 - val_acc: 0.9928
# Epoch 176/200
#  - 33s - loss: 0.0220 - acc: 0.9937 - val_loss: 0.0226 - val_acc: 0.9931
# Epoch 177/200
#  - 33s - loss: 0.0219 - acc: 0.9937 - val_loss: 0.0218 - val_acc: 0.9934
# Epoch 178/200
#  - 33s - loss: 0.0220 - acc: 0.9937 - val_loss: 0.0244 - val_acc: 0.9923
# Epoch 179/200
#  - 33s - loss: 0.0219 - acc: 0.9937 - val_loss: 0.0236 - val_acc: 0.9929
# Epoch 180/200
#  - 33s - loss: 0.0218 - acc: 0.9937 - val_loss: 0.0242 - val_acc: 0.9927
# Epoch 181/200
#  - 33s - loss: 0.0218 - acc: 0.9937 - val_loss: 0.0242 - val_acc: 0.9929
# Epoch 182/200
#  - 33s - loss: 0.0219 - acc: 0.9937 - val_loss: 0.0239 - val_acc: 0.9931
# Epoch 183/200
#  - 33s - loss: 0.0216 - acc: 0.9938 - val_loss: 0.0236 - val_acc: 0.9930
# Epoch 184/200
#  - 33s - loss: 0.0219 - acc: 0.9937 - val_loss: 0.0233 - val_acc: 0.9927
# Epoch 185/200
#  - 33s - loss: 0.0217 - acc: 0.9937 - val_loss: 0.0229 - val_acc: 0.9932
# Epoch 186/200
#  - 33s - loss: 0.0217 - acc: 0.9937 - val_loss: 0.0232 - val_acc: 0.9930
# Epoch 187/200
#  - 33s - loss: 0.0217 - acc: 0.9937 - val_loss: 0.0233 - val_acc: 0.9932
# Epoch 188/200
#  - 33s - loss: 0.0219 - acc: 0.9937 - val_loss: 0.0232 - val_acc: 0.9921
# Epoch 189/200
#  - 33s - loss: 0.0219 - acc: 0.9937 - val_loss: 0.0231 - val_acc: 0.9923
# Epoch 190/200
#  - 33s - loss: 0.0218 - acc: 0.9937 - val_loss: 0.0234 - val_acc: 0.9930
# Epoch 191/200
#  - 33s - loss: 0.0219 - acc: 0.9937 - val_loss: 0.0220 - val_acc: 0.9936
# Epoch 192/200
#  - 33s - loss: 0.0217 - acc: 0.9937 - val_loss: 0.0239 - val_acc: 0.9931
# Epoch 193/200
#  - 33s - loss: 0.0217 - acc: 0.9938 - val_loss: 0.0253 - val_acc: 0.9931
# Epoch 194/200
#  - 33s - loss: 0.0213 - acc: 0.9938 - val_loss: 0.0237 - val_acc: 0.9931
# Epoch 195/200
#  - 33s - loss: 0.0215 - acc: 0.9938 - val_loss: 0.0239 - val_acc: 0.9924
# Epoch 196/200
#  - 33s - loss: 0.0218 - acc: 0.9937 - val_loss: 0.0247 - val_acc: 0.9927
# Epoch 197/200
#  - 33s - loss: 0.0215 - acc: 0.9938 - val_loss: 0.0249 - val_acc: 0.9927
# Epoch 198/200
#  - 33s - loss: 0.0216 - acc: 0.9938 - val_loss: 0.0243 - val_acc: 0.9927
# Epoch 199/200
#  - 33s - loss: 0.0215 - acc: 0.9938 - val_loss: 0.0229 - val_acc: 0.9934
# Epoch 200/200
#  - 34s - loss: 0.0215 - acc: 0.9938 - val_loss: 0.0242 - val_acc: 0.9928
# Wall time: 1h 49min 57s

# %% [markdown]
# # Graph the losses

# %%
def most_recent_file(pattern):
    return max(glob.iglob(pattern, recursive=True), key=os.path.getctime)

logpath = most_recent_file(NOTEBOOK_PATH + "Loss Logs/%s**" % model_id)
log_df = pd.read_csv(logpath)
log_df['epoch'] += 1

print(logpath)
# Out:
# C:/Users/Xetrov/Desktop/SciFair20/Code/Loss Logs\dnn9-featureselection2drop-regular (11-03-2019, 0535PM)

# %%
plot_df = log_df[:]

metric = 'loss'

plt.figure(figsize=(12,6))
sns.lineplot(x='epoch', y=metric, data=plot_df, label=metric)
sns.lineplot(x='epoch', y='val_'+metric, data=plot_df, label='val_'+metric)
plt.legend()

minEpoch = plot_df.loc[plot_df.idxmin()[metric]]
plt.plot((minEpoch['epoch']), (minEpoch[metric]), 'go', markersize=8)
minEpoch = plot_df.loc[plot_df.idxmin()['val_'+metric]]
plt.plot((minEpoch['epoch']), (minEpoch['val_'+metric]), 'ro', markersize=8)

plt.xticks(list(range(0, plot_df['epoch'].max()+1, 5)))
# plt.yticks(list(np.arange(0.0,0.4,0.05)))

plt.grid(True)

# %% [markdown]
# # View confusion matrix

# %%
print("Loading...")
model = keras.models.load_model(NOTEBOOK_PATH + "Models/%s/dnn(163).h5" % model_id)
# Out:
# Loading...

# %%
print("Predicting...")
pred = model.predict(x_val)

print("Plotting...")
pred_series = pd.Series(pred.round().astype('int').ravel(), name="Pred").replace({0: 'Benign', 1: 'Attack'})
y_series = pd.Series(y_val.to_numpy().ravel(), name="Actual").replace({0: 'Benign', 1: 'Attack'})

matrix = pd.crosstab(pred_series, y_series, margins=True)
print("Done!")
matrix
# Out:
# Predicting...
# Plotting...
# Done!
# Actual  Attack  Benign     All
# Pred
# Attack  111884    4132  116016
# Benign      58  450075  450133
# All     111942  454207  566149

# %% [markdown]
# # F1 Score

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

# %%
pred = model.predict(x_test).round().astype('int').ravel()
y_test_npy = y_test.to_numpy().ravel()

precision = precision_score(y_test_npy, pred)
print("Precision:", precision)

recall = recall_score(y_test_npy, pred)
print("Recall:", recall)

f1 = f1_score(y_test_npy, pred)
print("F1:", f1)
# Out:
# Precision: 0.9649279483933619
# Recall: 0.9993714024012428
# F1: 0.9818476971057774

# %%
pred_series = pd.Series(pred, name="Pred").replace({0: 'Benign', 1: 'Attack'})
y_series = pd.Series(y_test.to_numpy().ravel(), name="Actual").replace({0: 'Benign', 1: 'Attack'})

matrix = pd.crosstab(pred_series, y_series, margins=True)
matrix
# Out:
# Actual  Attack  Benign     All
# Pred
# Attack  111289    4045  115334
# Benign      70  450745  450815
# All     111359  454790  566149

# %% [markdown]
# # Log results

# %%
model_log = open(NOTEBOOK_PATH + "model_log.txt", "a")

model_log.write("\n" + model_id)
model_log.write("\n\tF1 Micro: " + str(f1_micro))
model_log.write("\n\tF1 Macro: " + str(f1_macro))

model_log.close()
