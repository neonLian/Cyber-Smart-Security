# %% [markdown]
# # CSE-CIC-IDS 2017

# %%
model_id = "dnn7-autoencodershape"

# %%
import numpy as np
np.random.seed(42)
np.set_printoptions(suppress=True)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

import glob, time, os

import keras
# Out:
# Using TensorFlow backend.
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Xetrov\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
NOTEBOOK_PATH = "C:/Users/Xetrov/Desktop/SciFair20/Code/"

# %%
x_scaled = pd.read_csv(NOTEBOOK_PATH + "IDS2017/x_scaled_powertransform.csv")

# %%
y_df_enc = pd.read_csv(NOTEBOOK_PATH + "IDS2017/y_all_binary.csv")

# %% [markdown]
# # Split data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_valtest, y_train, y_valtest = train_test_split(x_scaled, y_df_enc, test_size = 0.4, random_state = 42)

# %%
x_val, x_test, y_val, y_test = train_test_split(x_valtest, y_valtest, test_size = 0.5, random_state = 42)

# %%
del x_train
del y_train
del x_valtest 
del y_valtest

# %% [markdown]
# # Oversampling

# %%
x_train_res = pd.read_csv(NOTEBOOK_PATH + "IDS2017/x_adasyn_binary.csv")

# %%
y_train_res = pd.read_csv(NOTEBOOK_PATH + "IDS2017/y_adasyn_binary.csv")['IsAttack']

# %% [markdown]
# # Train model

# %%
from keras.models import Model, Sequential
from keras.layers import Dense, BatchNormalization, Dropout, InputLayer
from keras.optimizers import SGD, Adam

# %%
def addDenseBlock(model, units, **params):
    model.add(Dense(units=units, activation=params['hidden_activation'], input_dim=x_train_res.shape[1]))
    if params['batch_normalization']: model.add(BatchNormalization())
    if params['dropout_rate'] > 0: model.add(Dropout(params['dropout_rate']))

def createModel(**in_params):
    """
    Supported parameters:
    batch_normalization - True or False
    dropout_rate - 0 to 1
    num_units - integer
    learning_rate - float
    activation_function - string
    """
    
    model = Sequential()

    # Set default values
    params = {
        'batch_normalization': True,
        'dropout_rate': 0,
        'num_layers': 6,
        'num_units': 128,
        'learning_rate': 0.001,
        'hidden_activation': 'relu',
        'final_activation': 'sigmoid'
    }
    
    # Replace defaults with specified parameters
    for param in in_params:
        params[param] = in_params[param]    
    
    # InputLayer causes serialization issues
#     model.add( InputLayer(input_shape = (x_train.shape[1],) ) )
    
#     for i in range(params['num_layers']):
#         addDenseBlock(model, params['num_units'], **params)

    addDenseBlock(model, 256, **params)
    addDenseBlock(model, 128, **params)
    addDenseBlock(model, 64, **params)
    addDenseBlock(model, 32, **params)
    addDenseBlock(model, 64, **params)
    addDenseBlock(model, 128, **params)
    addDenseBlock(model, 256, **params)

    model.add(Dense(units=1, activation=params['final_activation']))

    # optim = SGD(lr=0.001, nesterov=True)
    optim = Adam(lr=params['learning_rate'])

    model.compile(loss='binary_crossentropy', optimizer=optim, metrics=['accuracy'])
    
#     print(params)
    
    return model

# %% [markdown]
# ### Callbacks

# %%
from keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint

def timestamp():
    return time.strftime("%m-%d-%Y, %I%M%p")

csv_callback = CSVLogger(NOTEBOOK_PATH + 'Loss Logs/%s (%s)' % (model_id, timestamp()), append=True)
early_stop = EarlyStopping(monitor = 'val_loss', min_delta=0.0001, patience=5)

# %% [markdown]
# ### Model Saving

# %%
savedir = NOTEBOOK_PATH + "Models/%s/" % model_id
if not os.path.exists(savedir):
    os.makedirs(savedir)
    print("Created " + savedir)
else:
    print("Using " + savedir)
# Out:
# Created C:/Users/Xetrov/Desktop/SciFair20/Code/Models/dnn7-autoencodershape/

# %% [markdown]
# Ensure a GPU is available

# %%
import keras.backend as K

K.tensorflow_backend._get_available_gpus()
# Out:
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %% [markdown]
# ### Training

# %%
import itertools

trainEpochs = 500

parameters = {'batch_size': 1000, 'batch_normalization':True,'dropout_rate':0, 'final_activation':'sigmoid'}

# %%
# %%time
print(model_id)
model = createModel(**parameters)
model.summary()
model_checkpoint = ModelCheckpoint(NOTEBOOK_PATH + "Models/%s/dnn({epoch}).h5" % (model_id), monitor='val_loss')
model.fit(x_train_res, y_train_res, validation_data=(x_val, y_val), 
          batch_size=parameters['batch_size'], 
          epochs=trainEpochs, 
          verbose=2, 
          callbacks=[csv_callback, model_checkpoint]
         )
# Out:
# dnn7-autoencodershape
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 256)               17664
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128)               512
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 64)                256
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                2080
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 32)                128
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 64)                256
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               8320
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 128)               512
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               33024
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 108,321
# Trainable params: 106,465
# Non-trainable params: 1,856
# _________________________________________________________________
# Train on 2727615 samples, validate on 566149 samples
# Epoch 1/500
#  - 40s - loss: 0.0355 - acc: 0.9885 - val_loss: 0.0337 - val_acc: 0.9872
# Epoch 2/500
#  - 38s - loss: 0.0217 - acc: 0.9939 - val_loss: 0.0380 - val_acc: 0.9873
# Epoch 3/500
#  - 38s - loss: 0.0196 - acc: 0.9947 - val_loss: 0.0183 - val_acc: 0.9947
# Epoch 4/500
#  - 38s - loss: 0.0182 - acc: 0.9951 - val_loss: 0.0311 - val_acc: 0.9906
# Epoch 5/500
#  - 38s - loss: 0.0182 - acc: 0.9951 - val_loss: 0.0245 - val_acc: 0.9921
# Epoch 6/500
#  - 38s - loss: 0.0168 - acc: 0.9955 - val_loss: 0.0264 - val_acc: 0.9914
# Epoch 7/500
#  - 38s - loss: 0.0159 - acc: 0.9958 - val_loss: 0.0297 - val_acc: 0.9921
# Epoch 8/500
#  - 38s - loss: 0.0153 - acc: 0.9960 - val_loss: 0.0155 - val_acc: 0.9960
# Epoch 9/500
#  - 38s - loss: 0.0150 - acc: 0.9961 - val_loss: 0.0223 - val_acc: 0.9930
# Epoch 10/500
#  - 38s - loss: 0.0140 - acc: 0.9964 - val_loss: 0.0216 - val_acc: 0.9934
# Epoch 11/500
#  - 38s - loss: 0.0138 - acc: 0.9965 - val_loss: 0.0998 - val_acc: 0.9868
# Epoch 12/500
#  - 38s - loss: 0.0136 - acc: 0.9966 - val_loss: 0.0154 - val_acc: 0.9962
# Epoch 13/500
#  - 38s - loss: 0.0143 - acc: 0.9964 - val_loss: 0.0188 - val_acc: 0.9949
# Epoch 14/500
#  - 38s - loss: 0.0138 - acc: 0.9966 - val_loss: 0.0375 - val_acc: 0.9927
# Epoch 15/500
- loss: 0.0066 - acc: 0.9986 - val_loss: 0.0108 - val_acc: 0.9974
# Epoch 179/500
#  - 38s - loss: 0.0065 - acc: 0.9986 - val_loss: 0.0351 - val_acc: 0.9954
# Epoch 180/500
#  - 38s - loss: 0.0064 - acc: 0.9987 - val_loss: 0.0122 - val_acc: 0.9979
# Epoch 181/500
#  - 38s - loss: 0.0063 - acc: 0.9987 - val_loss: 0.0170 - val_acc: 0.9968
# Epoch 182/500
#  - 38s - loss: 0.0063 - acc: 0.9987 - val_loss: 0.0240 - val_acc: 0.9955
# Epoch 183/500
#  - 38s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0181 - val_acc: 0.9952
# Epoch 184/500
#  - 38s - loss: 0.0064 - acc: 0.9986 - val_loss: 0.0094 - val_acc: 0.9978
# Epoch 185/500
#  - 38s - loss: 0.0063 - acc: 0.9987 - val_loss: 0.0492 - val_acc: 0.9952
# Epoch 186/500
#  - 38s - loss: 0.0065 - acc: 0.9986 - val_loss: 0.0085 - val_acc: 0.9981
# Epoch 187/500
#  - 38s - loss: 0.0063 - acc: 0.9986 - val_loss: 0.0496 - val_acc: 0.9952
# Epoch 188/500
#  - 38s - loss: 0.0064 - acc: 0.9986 - val_loss: 0.0243 - val_acc: 0.9961
# Epoch 189/500
#  - 38s - loss: 0.0066 - acc: 0.9986 - val_loss: 0.0094 - val_acc: 0.9979
# Epoch 190/500
#  - 38s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0086 - val_acc: 0.9981
# Epoch 191/500
#  - 38s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0223 - val_acc: 0.9960
# Epoch 192/500
#  - 38s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0160 - val_acc: 0.9958
# Epoch 193/500
#  - 38s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0190 - val_acc: 0.9959
# Epoch 194/500
#  - 38s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0205 - val_acc: 0.9963
# Epoch 195/500
#  - 38s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0201 - val_acc: 0.9960
# Epoch 196/500
#  - 38s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0523 - val_acc: 0.9953
# Epoch 197/500
#  - 38s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0108 - val_acc: 0.9981
# Epoch 198/500
#  - 38s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.1845 - val_acc: 0.9840
# Epoch 199/500
#  - 38s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0120 - val_acc: 0.9965
# Epoch 200/500
#  - 38s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0301 - val_acc: 0.9957
# Epoch 201/500
#  - 38s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0154 - val_acc: 0.9969
# Epoch 202/500
#  - 38s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0090 - val_acc: 0.9978
# Epoch 203/500
#  - 38s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0093 - val_acc: 0.9985
# Epoch 204/500
#  - 38s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0543 - val_acc: 0.9954
# Epoch 205/500
#  - 38s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0314 - val_acc: 0.9964
# Epoch 206/500
#  - 38s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0231 - val_acc: 0.9962
# Epoch 207/500
#  - 38s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0089 - val_acc: 0.9983
# Epoch 208/500
#  - 38s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0105 - val_acc: 0.9981
# Epoch 209/500
#  - 38s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0147 - val_acc: 0.9969
# Epoch 210/500
#  - 38s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0311 - val_acc: 0.9960
# Epoch 211/500
#  - 38s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0109 - val_acc: 0.9972
# Epoch 212/500
#  - 38s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0324 - val_acc: 0.9963
# Epoch 213/500
#  - 38s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0089 - val_acc: 0.9981
# Epoch 214/500
#  - 38s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0550 - val_acc: 0.9954
# Epoch 215/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0200 - val_acc: 0.9963
# Epoch 216/500
#  - 38s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0130 - val_acc: 0.9965
# Epoch 217/500
#  - 38s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0084 - val_acc: 0.9982
# Epoch 218/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0282 - val_acc: 0.9963
# Epoch 219/500
#  - 38s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0092 - val_acc: 0.9984
# Epoch 220/500
#  - 38s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0167 - val_acc: 0.9960
# Epoch 221/500
#  - 38s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0558 - val_acc: 0.9946
# Epoch 222/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0418 - val_acc: 0.9958
# Epoch 223/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0080 - val_acc: 0.9983
# Epoch 224/500
#  - 38s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0106 - val_acc: 0.9974
# Epoch 225/500
#  - 38s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0104 - val_acc: 0.9983
# Epoch 226/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0541 - val_acc: 0.9956
# Epoch 227/500
#  - 38s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0125 - val_acc: 0.9976
# Epoch 228/500
#  - 38s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0505 - val_acc: 0.9953
# Epoch 229/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0139 - val_acc: 0.9974
# Epoch 230/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0232 - val_acc: 0.9962
# Epoch 231/500
#  - 38s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0187 - val_acc: 0.9963
# Epoch 232/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0095 - val_acc: 0.9982
# Epoch 233/500
#  - 38s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.2298 - val_acc: 0.9836
# Epoch 234/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0422 - val_acc: 0.9951
# Epoch 235/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0127 - val_acc: 0.9957
# Epoch 236/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0165 - val_acc: 0.9964
# Epoch 237/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0382 - val_acc: 0.9947
# Epoch 238/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0096 - val_acc: 0.9981
# Epoch 239/500
#  - 38s - loss: 0.0058 - acc: 0.9989 - val_loss: 0.0517 - val_acc: 0.9956
# Epoch 240/500
#  - 38s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0190 - val_acc: 0.9957
# Epoch 241/500
#  - 38s - loss: 0.0070 - acc: 0.9985 - val_loss: 0.0163 - val_acc: 0.9961
# Epoch 242/500
#  - 38s - loss: 0.0066 - acc: 0.9986 - val_loss: 0.0259 - val_acc: 0.9960
# Epoch 243/500
#  - 38s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0541 - val_acc: 0.9950
# Epoch 244/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0294 - val_acc: 0.9958
# Epoch 245/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0106 - val_acc: 0.9977
# Epoch 246/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0118 - val_acc: 0.9978
# Epoch 247/500
#  - 38s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.1402 - val_acc: 0.9850
# Epoch 248/500
#  - 38s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.2442 - val_acc: 0.9838
# Epoch 249/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0128 - val_acc: 0.9975
# Epoch 250/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0175 - val_acc: 0.9962
# Epoch 251/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0716 - val_acc: 0.9942
# Epoch 252/500
#  - 38s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0083 - val_acc: 0.9978
# Epoch 253/500
#  - 38s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0533 - val_acc: 0.9956
# Epoch 254/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0544 - val_acc: 0.9956
# Epoch 255/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0093 - val_acc: 0.9983
# Epoch 256/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0080 - val_acc: 0.9983
# Epoch 257/500
#  - 38s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0520 - val_acc: 0.9945
# Epoch 258/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0242 - val_acc: 0.9957
# Epoch 259/500
#  - 38s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0181 - val_acc: 0.9965
# Epoch 260/500
#  - 38s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0165 - val_acc: 0.9966
# Epoch 261/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0112 - val_acc: 0.9971
# Epoch 262/500
#  - 38s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0530 - val_acc: 0.9955
# Epoch 263/500
#  - 38s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0093 - val_acc: 0.9981
# Epoch 264/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0094 - val_acc: 0.9984
# Epoch 265/500
#  - 38s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0177 - val_acc: 0.9961
# Epoch 266/500
#  - 38s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0249 - val_acc: 0.9956
# Epoch 267/500
#  - 38s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0125 - val_acc: 0.9977
# Epoch 268/500
#  - 38s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0082 - val_acc: 0.9982
# Epoch 269/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0506 - val_acc: 0.9947
# Epoch 270/500
#  - 38s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.1705 - val_acc: 0.9853
# Epoch 271/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0529 - val_acc: 0.9955
# Epoch 272/500
#  - 38s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0109 - val_acc: 0.9972
# Epoch 273/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0529 - val_acc: 0.9955
# Epoch 274/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0082 - val_acc: 0.9984
# Epoch 275/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0098 - val_acc: 0.9980
# Epoch 276/500
#  - 38s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0537 - val_acc: 0.9953
# Epoch 277/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0532 - val_acc: 0.9956
# Epoch 278/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0127 - val_acc: 0.9977
# Epoch 279/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0095 - val_acc: 0.9981
# Epoch 280/500
#  - 38s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0164 - val_acc: 0.9950
# Epoch 281/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0248 - val_acc: 0.9948
# Epoch 282/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.1311 - val_acc: 0.9857
# Epoch 283/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0246 - val_acc: 0.9961
# Epoch 284/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0137 - val_acc: 0.9979
# Epoch 285/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0095 - val_acc: 0.9982
# Epoch 286/500
#  - 38s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0101 - val_acc: 0.9981
# Epoch 287/500
#  - 38s - loss: 0.0063 - acc: 0.9987 - val_loss: 0.0506 - val_acc: 0.9956
# Epoch 288/500
#  - 38s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0271 - val_acc: 0.9954
# Epoch 289/500
#  - 38s - loss: 0.0063 - acc: 0.9987 - val_loss: 0.0139 - val_acc: 0.9974
# Epoch 290/500
#  - 38s - loss: 0.0062 - acc: 0.9987 - val_loss: 0.0194 - val_acc: 0.9955
# Epoch 291/500
#  - 38s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0136 - val_acc: 0.9975
# Epoch 292/500
#  - 38s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0106 - val_acc: 0.9964
# Epoch 293/500
#  - 38s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0086 - val_acc: 0.9982
# Epoch 294/500
#  - 38s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0287 - val_acc: 0.9960
# Epoch 295/500
#  - 38s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0092 - val_acc: 0.9981
# Epoch 296/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.2201 - val_acc: 0.9853
# Epoch 297/500
#  - 38s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0106 - val_acc: 0.9983
# Epoch 298/500
#  - 38s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0278 - val_acc: 0.9962
# Epoch 299/500
#  - 38s - loss: 0.0058 - acc: 0.9988 - val_loss: 0.0529 - val_acc: 0.9944
# Epoch 300/500
#  - 38s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0382 - val_acc: 0.9958
# Epoch 301/500
#  - 38s - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0474 - val_acc: 0.9954
# Epoch 302/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0305 - val_acc: 0.9956
# Epoch 303/500
#  - 38s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0142 - val_acc: 0.9975
# Epoch 304/500
#  - 38s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0523 - val_acc: 0.9955
# Epoch 305/500
#  - 38s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.1516 - val_acc: 0.9853
# Epoch 306/500
#  - 38s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0207 - val_acc: 0.9967
# Epoch 307/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0154 - val_acc: 0.9969
# Epoch 308/500
#  - 38s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0212 - val_acc: 0.9965
# Epoch 309/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0106 - val_acc: 0.9979
# Epoch 310/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.2347 - val_acc: 0.9838
# Epoch 311/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0520 - val_acc: 0.9955
# Epoch 312/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0097 - val_acc: 0.9982
# Epoch 313/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0140 - val_acc: 0.9972
# Epoch 314/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0464 - val_acc: 0.9901
# Epoch 315/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0544 - val_acc: 0.9952
# Epoch 316/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0600 - val_acc: 0.9941
# Epoch 317/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0112 - val_acc: 0.9978
# Epoch 318/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.3390 - val_acc: 0.9749
# Epoch 319/500
#  - 38s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.1431 - val_acc: 0.9850
# Epoch 320/500
#  - 38s - loss: 0.0057 - acc: 0.9989 - val_loss: 0.0115 - val_acc: 0.9979
# Epoch 321/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0140 - val_acc: 0.9978
# Epoch 322/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0101 - val_acc: 0.9984
# Epoch 323/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0184 - val_acc: 0.9956
# Epoch 324/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0173 - val_acc: 0.9958
# Epoch 325/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0098 - val_acc: 0.9984
# Epoch 326/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0229 - val_acc: 0.9956
# Epoch 327/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0127 - val_acc: 0.9971
# Epoch 328/500
#  - 38s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0514 - val_acc: 0.9955
# Epoch 329/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0153 - val_acc: 0.9965
# Epoch 330/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0127 - val_acc: 0.9976
# Epoch 331/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0241 - val_acc: 0.9963
# Epoch 332/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0290 - val_acc: 0.9956
# Epoch 333/500
#  - 38s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0114 - val_acc: 0.9978
# Epoch 334/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.1291 - val_acc: 0.9861
# Epoch 335/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0219 - val_acc: 0.9959
# Epoch 336/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0198 - val_acc: 0.9969
# Epoch 337/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0115 - val_acc: 0.9976
# Epoch 338/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0256 - val_acc: 0.9963
# Epoch 339/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0081 - val_acc: 0.9984
# Epoch 340/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0078 - val_acc: 0.9984
# Epoch 341/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0129 - val_acc: 0.9978
# Epoch 342/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0535 - val_acc: 0.9956
# Epoch 343/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.2208 - val_acc: 0.9852
# Epoch 344/500
#  - 38s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.1159 - val_acc: 0.9848
# Epoch 345/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0082 - val_acc: 0.9984
# Epoch 346/500
#  - 38s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0185 - val_acc: 0.9970
# Epoch 347/500
#  - 38s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0177 - val_acc: 0.9965
# Epoch 348/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0306 - val_acc: 0.9943
# Epoch 349/500
#  - 38s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0230 - val_acc: 0.9961
# Epoch 350/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0536 - val_acc: 0.9954
# Epoch 351/500
#  - 38s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0555 - val_acc: 0.9953
# Epoch 352/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0084 - val_acc: 0.9982
# Epoch 353/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0076 - val_acc: 0.9984
# Epoch 354/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0534 - val_acc: 0.9957
# Epoch 355/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0264 - val_acc: 0.9962
# Epoch 356/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0234 - val_acc: 0.9960
# Epoch 357/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0111 - val_acc: 0.9981
# Epoch 358/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0136 - val_acc: 0.9979
# Epoch 359/500
#  - 38s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0531 - val_acc: 0.9956
# Epoch 360/500
#  - 38s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0196 - val_acc: 0.9960
# Epoch 361/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0470 - val_acc: 0.9955
# Epoch 362/500
#  - 38s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0541 - val_acc: 0.9945
# Epoch 363/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0090 - val_acc: 0.9984
# Epoch 364/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0189 - val_acc: 0.9963
# Epoch 365/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0121 - val_acc: 0.9980
# Epoch 366/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0170 - val_acc: 0.9959
# Epoch 367/500
#  - 38s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0089 - val_acc: 0.9982
# Epoch 368/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0276 - val_acc: 0.9962
# Epoch 369/500
#  - 38s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0175 - val_acc: 0.9962
# Epoch 370/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0110 - val_acc: 0.9983
# Epoch 371/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0530 - val_acc: 0.9951
# Epoch 372/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.2050 - val_acc: 0.9839
# Epoch 373/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.1450 - val_acc: 0.9865
# Epoch 374/500
#  - 38s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0498 - val_acc: 0.9955
# Epoch 375/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0454 - val_acc: 0.9947
# Epoch 376/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0079 - val_acc: 0.9984
# Epoch 377/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0494 - val_acc: 0.9952
# Epoch 378/500
#  - 38s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0496 - val_acc: 0.9955
# Epoch 379/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0316 - val_acc: 0.9964
# Epoch 380/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0085 - val_acc: 0.9983
# Epoch 381/500
#  - 38s - loss: 0.0052 - acc: 0.9990 - val_loss: 0.0523 - val_acc: 0.9957
# Epoch 382/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0508 - val_acc: 0.9959
# Epoch 383/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0111 - val_acc: 0.9982
# Epoch 384/500
#  - 38s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0209 - val_acc: 0.9953
# Epoch 385/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.2273 - val_acc: 0.9842
# Epoch 386/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0531 - val_acc: 0.9957
# Epoch 387/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0100 - val_acc: 0.9975
# Epoch 388/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0090 - val_acc: 0.9981
# Epoch 389/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0100 - val_acc: 0.9983
# Epoch 390/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0101 - val_acc: 0.9981
# Epoch 391/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0104 - val_acc: 0.9983
# Epoch 392/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0539 - val_acc: 0.9956
# Epoch 393/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.2286 - val_acc: 0.9847
# Epoch 394/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0081 - val_acc: 0.9983
# Epoch 395/500
#  - 38s - loss: 0.0052 - acc: 0.9990 - val_loss: 0.0106 - val_acc: 0.9982
# Epoch 396/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0101 - val_acc: 0.9982
# Epoch 397/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0108 - val_acc: 0.9982
# Epoch 398/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0164 - val_acc: 0.9970
# Epoch 399/500
#  - 38s - loss: 0.0052 - acc: 0.9990 - val_loss: 0.0111 - val_acc: 0.9975
# Epoch 400/500
#  - 38s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0155 - val_acc: 0.9974
# Epoch 401/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0210 - val_acc: 0.9967
# Epoch 402/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0181 - val_acc: 0.9967
# Epoch 403/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0080 - val_acc: 0.9983
# Epoch 404/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0097 - val_acc: 0.9983
# Epoch 405/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0150 - val_acc: 0.9966
# Epoch 406/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0100 - val_acc: 0.9978
# Epoch 407/500
#  - 38s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.0515 - val_acc: 0.9952
# Epoch 408/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0498 - val_acc: 0.9954
# Epoch 409/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0145 - val_acc: 0.9973
# Epoch 410/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0335 - val_acc: 0.9877
# Epoch 411/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0539 - val_acc: 0.9954
# Epoch 412/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0317 - val_acc: 0.9954
# Epoch 413/500
#  - 38s - loss: 0.0056 - acc: 0.9989 - val_loss: 0.0081 - val_acc: 0.9984
# Epoch 414/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0087 - val_acc: 0.9982
# Epoch 415/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0221 - val_acc: 0.9961
# Epoch 416/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0077 - val_acc: 0.9984
# Epoch 417/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0111 - val_acc: 0.9979
# Epoch 418/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0096 - val_acc: 0.9982
# Epoch 419/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0798 - val_acc: 0.9870
# Epoch 420/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0244 - val_acc: 0.9955
# Epoch 421/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0226 - val_acc: 0.9965
# Epoch 422/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0531 - val_acc: 0.9955
# Epoch 423/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0247 - val_acc: 0.9964
# Epoch 424/500
#  - 38s - loss: 0.0055 - acc: 0.9989 - val_loss: 0.0158 - val_acc: 0.9973
# Epoch 425/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0124 - val_acc: 0.9978
# Epoch 426/500
#  - 38s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0148 - val_acc: 0.9970
# Epoch 427/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0366 - val_acc: 0.9960
# Epoch 428/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0191 - val_acc: 0.9959
# Epoch 429/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0498 - val_acc: 0.9954
# Epoch 430/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0091 - val_acc: 0.9981
# Epoch 431/500
#  - 38s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0092 - val_acc: 0.9984
# Epoch 432/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0088 - val_acc: 0.9983
# Epoch 433/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0255 - val_acc: 0.9963
# Epoch 434/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0450 - val_acc: 0.9957
# Epoch 435/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0161 - val_acc: 0.9966
# Epoch 436/500
#  - 38s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0078 - val_acc: 0.9985
# Epoch 437/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0331 - val_acc: 0.9950
# Epoch 438/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0408 - val_acc: 0.9942
# Epoch 439/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0145 - val_acc: 0.9978
# Epoch 440/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0533 - val_acc: 0.9954
# Epoch 441/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0071 - val_acc: 0.9985
# Epoch 442/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0103 - val_acc: 0.9982
# Epoch 443/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0120 - val_acc: 0.9978
# Epoch 444/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0158 - val_acc: 0.9976
# Epoch 445/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0083 - val_acc: 0.9984
# Epoch 446/500
#  - 38s - loss: 0.0052 - acc: 0.9990 - val_loss: 0.0103 - val_acc: 0.9984
# Epoch 447/500
#  - 38s - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0200 - val_acc: 0.9965
# Epoch 448/500
#  - 38s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0114 - val_acc: 0.9975
# Epoch 449/500
#  - 39s - loss: 0.0061 - acc: 0.9987 - val_loss: 0.0096 - val_acc: 0.9981
# Epoch 450/500
#  - 39s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0536 - val_acc: 0.9953
# Epoch 451/500
#  - 39s - loss: 0.0052 - acc: 0.9990 - val_loss: 0.0159 - val_acc: 0.9968
# Epoch 452/500
#  - 38s - loss: 0.0054 - acc: 0.9989 - val_loss: 0.0496 - val_acc: 0.9954
# Epoch 453/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.0246 - val_acc: 0.9961
# Epoch 454/500
#  - 38s - loss: 0.0053 - acc: 0.9990 - val_loss: 0.
500
#  - 38s - loss: 0.0052 - acc: 0.9990 - val_loss: 0.0097 - val_acc: 0.9985
# Epoch 500/500
#  - 38s - loss: 0.0052 - acc: 0.9990 - val_loss: 0.0523 - val_acc: 0.9955
# Wall time: 5h 16min 35s

# %% [markdown]
# # Graph the losses

# %%
def most_recent_file(pattern):
    return max(glob.iglob(pattern, recursive=True), key=os.path.getctime)

logpath = most_recent_file(NOTEBOOK_PATH + "Loss Logs/%s**" % model_id)
log_df = pd.read_csv(logpath)
log_df['epoch'] += 1

print(logpath)
# Out:
# C:/Users/Xetrov/Desktop/SciFair20/Code/Loss Logs\dnn7-autoencodershape (11-01-2019, 1139PM)

# %%
plot_df = log_df[:]

metric = 'loss'

plt.figure(figsize=(12,6))
sns.lineplot(x='epoch', y=metric, data=plot_df, label=metric)
sns.lineplot(x='epoch', y='val_'+metric, data=plot_df, label='val_'+metric)
plt.legend()

minEpoch = plot_df.loc[plot_df.idxmin()[metric]]
plt.plot((minEpoch['epoch']), (minEpoch[metric]), 'go', markersize=8)
minEpoch = plot_df.loc[plot_df.idxmin()['val_'+metric]]
plt.plot((minEpoch['epoch']), (minEpoch['val_'+metric]), 'ro', markersize=8)
print(minEpoch)

plt.xticks(list(range(0, plot_df['epoch'].max()+1, 5)))
# plt.yticks(list(np.arange(0.0,0.4,0.05)))

plt.grid(True)
# Out:
# epoch       441.000000
# acc           0.998982
# loss          0.005273
# val_acc       0.998502
# val_loss      0.007121
# Name: 441, dtype: float64

# %% [markdown]
# # View confusion matrix

# %%
print("Loading...")
model = keras.models.load_model(NOTEBOOK_PATH + "Models/%s/dnn(441).h5" % model_id)
# Out:
# Loading...

# %%
print("Predicting...")
pred = model.predict(x_val)

print("Plotting...")
pred_series = pd.Series(pred.round().astype('int').ravel(), name="Pred").replace({0: 'Benign', 1: 'Attack'})
y_series = pd.Series(y_val.to_numpy().ravel(), name="Actual").replace({0: 'Benign', 1: 'Attack'})

matrix = pd.crosstab(pred_series, y_series, margins=True)
print("Done!")
matrix
# Out:
# Predicting...
# Plotting...
# Done!
# Actual  Attack  Benign     All
# Pred
# Attack  111921     827  112748
# Benign      21  453380  453401
# All     111942  454207  566149

# %% [markdown]
# # F1 Score

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

# %%
pred = model.predict(x_test).round().astype('int').ravel()
y_test_npy = y_test.to_numpy().ravel()

precision = precision_score(y_test_npy, pred)
print("Precision:", precision)

recall = recall_score(y_test_npy, pred)
print("Recall:", recall)

f1 = f1_score(y_test_npy, pred)
print("F1:", f1)
# Out:
# Precision: 0.9928126198268251
# Recall: 0.9997844808232833
# F1: 0.9962863534675616

# %%
pred_series = pd.Series(pred, name="Pred").replace({0: 'Benign', 1: 'Attack'})
y_series = pd.Series(y_test.to_numpy().ravel(), name="Actual").replace({0: 'Benign', 1: 'Attack'})

matrix = pd.crosstab(pred_series, y_series, margins=True)
matrix
# Out:
# Actual  Attack  Benign     All
# Pred
# Attack  111335     806  112141
# Benign      24  453984  454008
# All     111359  454790  566149

# %% [markdown]
# # Log results

# %%
model_log = open(NOTEBOOK_PATH + "model_log.txt", "a")

model_log.write("\n" + model_id)
model_log.write("\n\tF1 Micro: " + str(f1_micro))
model_log.write("\n\tF1 Macro: " + str(f1_macro))

model_log.close()
